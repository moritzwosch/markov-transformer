# %% [markdown]
# # Markov-Transformer
# ## About
# This notebook outlines experimentation regarding the Bachelor Thesis "On Markov Sequence Compression and Summarization in Transformers and Large Language Models" at the Goethe-University, Frankfurt (Semester 24/25).
# It consists of a simple binary Transformer model (based on "Attention is All You Need" by Vaswani et al., 2017) that is trained on binary Markov-generated sequences. The Markov-sequences are randomly created from Markov chains of order 1-6. Each Markov chain is defined as a transition matrix with dimensions (2^k * 2) with k being the order of the chain.

# %%
import numpy as np
import json
import torch
import random
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns

# %%
# I used mps as a device for faster training. Alternatively, CUDA or CPU (not recommended) are possible
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device {device}")
# Out:
# Using device mps

# %% [markdown]
# ## Parameters
# The training parameters are oriented on "Transformer Models on Markov Data: Constant Depth Suffices" (Rajaraman et al., 2024). It has been shown that Transformer models with constant depth of 3 layers and only one head per leayer are able to perform low test loss on Markov sequences of order up to 8. These fixed parameters were chosen to best combine simplicitly and performance across the Markov orders 1 to 6.

# %%
block_size = 512
batch_size = 16
learning_rate = 0.001
weight_decay = 1e-3
dropout = 0.0

# %%
# binary vocabulary
vocabulary_size = 2
chars = [0, 1] # notice how there es no encoding (string to integer) needed because the index is the token (0 and 1)

# %% [markdown]
# ## Markov Chains
# These functions are needed to create transition matrices and generate and estimate Markov sequences:

# %%
def generate_transition_matrix(order: int, seed: int):
    """
    generate a random transition matrix for a given order
    """
    if seed is not None:
        torch.manual_seed(seed)
        
    # calculate number of states (2^order)
    n_states = 2 ** order
    
    # generate random probabilities
    matrix = torch.rand((n_states, 2))
    
    # normalize rows to sum to 1
    row_sums = matrix.sum(dim=1, keepdim=True)
    matrix = matrix / row_sums
    
    return matrix

def generate_sequence(transition_matrix: torch.tensor, order: int, length: int, seed: int = None) -> list:
    """
    generate a binary sequence (array) from a given Markov transition matrix
    """
    if seed is not None:
        torch.manual_seed(seed)
    
    sequence = torch.zeros(length, dtype=torch.long)
    
    # Generate first 'order' elements randomly (starting point)
    for i in range(order):
        sequence[i] = torch.randint(0, 2, (1,))
    
    # generate remaining sequence using transition probabilities
    for i in range(order, length):
        # calculate current state index from previous 'order' elements
        state_idx = 0
        for j in range(order):
            state_idx = state_idx * 2 + sequence[i-order+j]
            
        # generate next bit based on transition probabilities
        probs = transition_matrix[int(state_idx)]
        sequence[i] = torch.bernoulli(probs[1])
    
    return sequence.tolist()

def estimate_matrix(sequence: list, 
                      order: int) -> torch.Tensor:
    """
    estimate a Markov transition matrix from a given binary sequence
    """
    num_states = 2 ** order
    counts = torch.zeros((num_states, 2))
    
    # count transitions
    for i in range(len(sequence) - order):
        # get current state (last k bits)
        state = sequence[i:i+order]
        state_idx = int(''.join(map(str, state)), 2)
        
        # get next bit
        next_bit = sequence[i+order]
        
        # update counts
        counts[state_idx, next_bit] += 1
    
    # convert counts to probabilities
    row_sums = counts.sum(dim=1, keepdim=True)
    # handle zero counts by setting uniform probabilities
    row_sums[row_sums == 0] = 2
    transition_matrix = counts / row_sums
    
    return transition_matrix

# %% [markdown]
# ## Training and Validation data
# We can now generate binary sequences for the training and split these sequences into batches for training and validation.

# %%
def generate_training_data(transition_matrix, order, sequence_length, num_sequences):
    """
    generate a number sequences of a given length for a transition matrix
    """
    sequences = []
    for i in range(num_sequences):
        sequence = generate_sequence(transition_matrix, order, sequence_length, i)
        sequences.append(torch.tensor(sequence, dtype=torch.long))
    return sequences

def get_batch(sequences, split='train'):
    """
    split sequences into batches for training and validation
    """
    n = int(0.9 * len(sequences)) # 90% training - 10% validation
    data = sequences[:n] if split == 'train' else sequences[n:]
    
    while True:  # keep trying until we get a valid batch
        seq_indices = torch.randint(len(data), (batch_size,))
        x_batch = []
        y_batch = []
        
        for idx in seq_indices:
            sequence = data[idx]
            if len(sequence) >= block_size + 1:
                start_idx = torch.randint(0, len(sequence) - block_size, (1,))
                x = sequence[start_idx:start_idx + block_size]
                y = sequence[start_idx + 1:start_idx + block_size + 1]
                x_batch.append(x)
                y_batch.append(y)
        
        if len(x_batch) > 0:  # only proceed if there is at least one valid sequence
            x_batch = torch.stack(x_batch)
            y_batch = torch.stack(y_batch)
            return x_batch.to(device), y_batch.to(device)

# %%
@torch.no_grad()
def estimate_loss(model, sequences):
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(sequences, split)
            logits = model(X)
            loss = model.compute_loss(logits, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %% [markdown]
# ## Model
# We can now define the Transformer model that consists of layers of Self-Attention Heads and a Multi-Layer-Perceptron (Feed-Forward):

# %%
class Head(nn.Module):
    """
    A single self-attention head
    """
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   
        q = self.query(x)  
        v = self.value(x)  
        
        att = q @ k.transpose(-2,-1) * C**-0.5
        att = att.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        
        out = att @ v
        return out

# %%
class MultiHeadAttention(nn.Module):
    """
    Multiple attention-heads in parallel
    """
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

# %%
class FeedForward(nn.Module):
    """
    A linear layer followed by a non-linear layer
    """
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

# %%
class Block(nn.Module):
    """
    Transformer block: communication followed by computation
    """
    
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        
    def forward(self, x):
        # add residual connections around both layers
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# %%
class BinaryTransformer(nn.Module):
    """
    Our transformer model for binary sequence prediction. 
    This model implements a transformer architecture designed for binary sequences, using token and positional embeddings followed by transformer 
    blocks with self-attention mechanisms.
    """
    
    def __init__(self):
        super().__init__()
        # create embedding tables for tokens and positions
        self.token_embedding_table = nn.Embedding(vocabulary_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        
        # create transformer blocks
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) 
                                    for _ in range(n_layer)])
        # final layer normalization and prediction head
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocabulary_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        # get token and position embeddings
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        
        # combine embeddings and process through transformer blocks
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        return logits  # return only the logits, no loss calculation here
    
    def compute_loss(self, logits, targets):
        """compute cross entropy loss"""
        B, T, C = logits.shape
        logits = logits.view(B*T, C)
        targets = targets.view(B*T)
        loss = F.cross_entropy(logits, targets, reduction='mean')
        return loss
    
    def generate(self, idx, max_new_tokens):
        """
        Generate new tokens based on a context sequence.
        """
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %% [markdown]
# ## Training
# Now that the model is defined we can script the training. The models will be saved as .pt files while their parameters (order, number, Markov chain, training history, etc.) will be saved in a json file.

# %%
def train_model(order, number, num_iterations, seed, sequence_length, num_sequences):
    """
    Initializes and trains a Transformer model using the above methods
    """
    model = BinaryTransformer()
    m = model.to(device)
    print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters') # size of the model

    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_iterations)

    training_history = { # for easier interpretation later
        'train_losses': [],
        'val_losses': [],
        'iterations': []
    }

    transition_matrix = generate_transition_matrix(order, seed)
    print("Transition Matrix: \n", transition_matrix)
    data = generate_training_data(transition_matrix, order, sequence_length, num_sequences)

    for iter in range(num_iterations):

        if iter % eval_interval == 0 or iter == num_iterations-1:
            losses = estimate_loss(model, data)
            training_history['train_losses'].append(losses['train'])
            training_history['val_losses'].append(losses['val'])
            training_history['iterations'].append(iter)
            print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        # get batch
        xb, yb = get_batch(data, 'train')
        
        # forward pass
        logits = model(xb)
        loss = model.compute_loss(logits, yb)
        
        # backward pass
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()
        scheduler.step()

    # save the model info
    model_info = {
        'order': order,
        'number': number,
        'seed': seed,
        'num_iterations': num_iterations,
        'training_history': training_history,
        'transition_matrix': transition_matrix,
        'final_loss': loss.item()
    }

    # save checkpoint to access the model later
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict(),
        'loss': loss,
        'iter': iter,
        'model_info': model_info
    }, f'models2/model{order}_{number}.pt')

    return model_info

# %% [markdown]
# ## Training the models
# Now, the models can be trained. We will train models from Markov order 1 to 6 with 5 models per order (= 30 models in total) to ensure quantitative robustness of the experiments. Every model will be trained on an individual seed to ensure reproducability. The variable parameters for different orders (e.g. n_heads, n_layers) have been chosen experimentally.

# %%
my_models = [] # the models will be stored here for easier evaluation later

# %%
def tensor_to_serializable(obj):
    """
    Convert tensors and other objects to JSON serializable format. Tensors cannot be saved in json files.
    """
    if isinstance(obj, dict):
        return {key: tensor_to_serializable(value) for key, value in obj.items()}
    elif isinstance(obj, list):
        return [tensor_to_serializable(item) for item in obj]
    elif isinstance(obj, torch.Tensor):
        return obj.tolist()
    elif isinstance(obj, (int, float, str, bool)):
        return obj
    elif obj is None:
        return None
    else:
        return str(obj)

# %% [markdown]
# For order 1:

# %%
n_head = 1
n_layer = 2
n_embd = 16
sequence_length = 1000
num_sequences = 500
num_iterations = 5000
seeds = [87, 88, 89, 90, 91]
idx = 0
for number in range(1, 6): # 5 models per order
    try:
        print(f"Training model order=1 number={number}")
        model_info = train_model(1, number, num_iterations, seeds[idx], sequence_length, num_sequences)
        my_models.append(model_info)
        idx += 1
        
        if device.type == "mps":
            torch.mps.empty_cache() # cleanup (due to issues that might have been connected to cache overflow)
            
    except Exception as e:
        print(f"Failed training model number={number}: {e}")
        continue
# Out:
# Training model order=1 number=1
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.0040, 0.9960],
#         [0.3166, 0.6834]])
# step 0: train loss 0.7233, val loss 0.7238
# step 100: train loss 0.4993, val loss 0.4998
# step 200: train loss 0.4821, val loss 0.4826
# step 300: train loss 0.4804, val loss 0.4805
# step 400: train loss 0.4797, val loss 0.4803
# step 500: train loss 0.4800, val loss 0.4803
# step 600: train loss 0.4800, val loss 0.4805
# step 700: train loss 0.4797, val loss 0.4800
# step 800: train loss 0.4797, val loss 0.4802
# step 900: train loss 0.4795, val loss 0.4800
# step 1000: train loss 0.4798, val loss 0.4799
# step 1100: train loss 0.4799, val loss 0.4800
# step 1200: train loss 0.4799, val loss 0.4803
# step 1300: train loss 0.4798, val loss 0.4801
# step 1400: train loss 0.4800, val loss 0.4802
# step 1500: train loss 0.4798, val loss 0.4801
# step 1600: train loss 0.4796, val loss 0.4801
# step 1700: train loss 0.4799, val loss 0.4801
# step 1800: train loss 0.4798, val loss 0.4802
# step 1900: train loss 0.4799, val loss 0.4802
# step 2000: train loss 0.4799, val loss 0.4802
# step 2100: train loss 0.4800, val loss 0.4803
# step 2200: train loss 0.4798, val loss 0.4798
# step 2300: train loss 0.4797, val loss 0.4800
# step 2400: train loss 0.4799, val loss 0.4797
# step 2500: train loss 0.4799, val loss 0.4800
# step 2600: train loss 0.4797, val loss 0.4799
# step 2700: train loss 0.4799, val loss 0.4802
# step 2800: train loss 0.4800, val loss 0.4802
# step 2900: train loss 0.4798, val loss 0.4801
# step 3000: train loss 0.4798, val loss 0.4798
# step 3100: train loss 0.4800, val loss 0.4803
# step 3200: train loss 0.4797, val loss 0.4804
# step 3300: train loss 0.4799, val loss 0.4797
# step 3400: train loss 0.4797, val loss 0.4801
# step 3500: train loss 0.4800, val loss 0.4802
# step 3600: train loss 0.4800, val loss 0.4802
# step 3700: train loss 0.4796, val loss 0.4800
# step 3800: train loss 0.4796, val loss 0.4798
# step 3900: train loss 0.4801, val loss 0.4805
# step 4000: train loss 0.4800, val loss 0.4803
# step 4100: train loss 0.4799, val loss 0.4801
# step 4200: train loss 0.4797, val loss 0.4803
# step 4300: train loss 0.4799, val loss 0.4801
# step 4400: train loss 0.4799, val loss 0.4798
# step 4500: train loss 0.4800, val loss 0.4799
# step 4600: train loss 0.4799, val loss 0.4803
# step 4700: train loss 0.4798, val loss 0.4802
# step 4800: train loss 0.4802, val loss 0.4802
# step 4900: train loss 0.4796, val loss 0.4798
# step 4999: train loss 0.4798, val loss 0.4800
# Training model order=1 number=2
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.5270, 0.4730],
#         [0.6672, 0.3328]])
# step 0: train loss 0.8393, val loss 0.8394
# step 100: train loss 0.6709, val loss 0.6709
# step 200: train loss 0.6699, val loss 0.6692
# step 300: train loss 0.6699, val loss 0.6696
# step 400: train loss 0.6695, val loss 0.6690
# step 500: train loss 0.6696, val loss 0.6692
# step 600: train loss 0.6692, val loss 0.6691
# step 700: train loss 0.6696, val loss 0.6690
# step 800: train loss 0.6693, val loss 0.6691
# step 900: train loss 0.6694, val loss 0.6694
# step 1000: train loss 0.6694, val loss 0.6690
# step 1100: train loss 0.6692, val loss 0.6688
# step 1200: train loss 0.6692, val loss 0.6691
# step 1300: train loss 0.6693, val loss 0.6689
# step 1400: train loss 0.6693, val loss 0.6689
# step 1500: train loss 0.6691, val loss 0.6690
# step 1600: train loss 0.6691, val loss 0.6689
# step 1700: train loss 0.6690, val loss 0.6690
# step 1800: train loss 0.6690, val loss 0.6687
# step 1900: train loss 0.6692, val loss 0.6686
# step 2000: train loss 0.6692, val loss 0.6689
# step 2100: train loss 0.6691, val loss 0.6689
# step 2200: train loss 0.6693, val loss 0.6691
# step 2300: train loss 0.6691, val loss 0.6687
# step 2400: train loss 0.6689, val loss 0.6688
# step 2500: train loss 0.6688, val loss 0.6690
# step 2600: train loss 0.6693, val loss 0.6689
# step 2700: train loss 0.6691, val loss 0.6689
# step 2800: train loss 0.6692, val loss 0.6687
# step 2900: train loss 0.6692, val loss 0.6686
# step 3000: train loss 0.6690, val loss 0.6688
# step 3100: train loss 0.6691, val loss 0.6688
# step 3200: train loss 0.6689, val loss 0.6689
# step 3300: train loss 0.6691, val loss 0.6692
# step 3400: train loss 0.6694, val loss 0.6687
# step 3500: train loss 0.6690, val loss 0.6687
# step 3600: train loss 0.6691, val loss 0.6685
# step 3700: train loss 0.6690, val loss 0.6687
# step 3800: train loss 0.6691, val loss 0.6691
# step 3900: train loss 0.6689, val loss 0.6686
# step 4000: train loss 0.6689, val loss 0.6688
# step 4100: train loss 0.6691, val loss 0.6686
# step 4200: train loss 0.6692, val loss 0.6686
# step 4300: train loss 0.6689, val loss 0.6687
# step 4400: train loss 0.6690, val loss 0.6689
# step 4500: train loss 0.6689, val loss 0.6689
# step 4600: train loss 0.6689, val loss 0.6687
# step 4700: train loss 0.6693, val loss 0.6687
# step 4800: train loss 0.6689, val loss 0.6687
# step 4900: train loss 0.6691, val loss 0.6687
# step 4999: train loss 0.6692, val loss 0.6689
# Training model order=1 number=3
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.7640, 0.2360],
#         [0.4623, 0.5377]])
# step 0: train loss 0.8741, val loss 0.8753
# step 100: train loss 0.6026, val loss 0.6018
# step 200: train loss 0.5987, val loss 0.5982
# step 300: train loss 0.5977, val loss 0.5972
# step 400: train loss 0.5970, val loss 0.5967
# step 500: train loss 0.5967, val loss 0.5960
# step 600: train loss 0.5968, val loss 0.5965
# step 700: train loss 0.5970, val loss 0.5968
# step 800: train loss 0.5971, val loss 0.5969
# step 900: train loss 0.5968, val loss 0.5960
# step 1000: train loss 0.5965, val loss 0.5964
# step 1100: train loss 0.5959, val loss 0.5965
# step 1200: train loss 0.5968, val loss 0.5961
# step 1300: train loss 0.5963, val loss 0.5961
# step 1400: train loss 0.5962, val loss 0.5965
# step 1500: train loss 0.5961, val loss 0.5965
# step 1600: train loss 0.5965, val loss 0.5960
# step 1700: train loss 0.5967, val loss 0.5959
# step 1800: train loss 0.5957, val loss 0.5963
# step 1900: train loss 0.5963, val loss 0.5958
# step 2000: train loss 0.5963, val loss 0.5965
# step 2100: train loss 0.5964, val loss 0.5964
# step 2200: train loss 0.5963, val loss 0.5965
# step 2300: train loss 0.5963, val loss 0.5960
# step 2400: train loss 0.5956, val loss 0.5967
# step 2500: train loss 0.5966, val loss 0.5959
# step 2600: train loss 0.5968, val loss 0.5963
# step 2700: train loss 0.5962, val loss 0.5962
# step 2800: train loss 0.5966, val loss 0.5961
# step 2900: train loss 0.5961, val loss 0.5958
# step 3000: train loss 0.5964, val loss 0.5955
# step 3100: train loss 0.5962, val loss 0.5960
# step 3200: train loss 0.5965, val loss 0.5960
# step 3300: train loss 0.5972, val loss 0.5966
# step 3400: train loss 0.5963, val loss 0.5959
# step 3500: train loss 0.5961, val loss 0.5959
# step 3600: train loss 0.5959, val loss 0.5960
# step 3700: train loss 0.5960, val loss 0.5964
# step 3800: train loss 0.5960, val loss 0.5965
# step 3900: train loss 0.5962, val loss 0.5952
# step 4000: train loss 0.5959, val loss 0.5960
# step 4100: train loss 0.5957, val loss 0.5961
# step 4200: train loss 0.5968, val loss 0.5959
# step 4300: train loss 0.5959, val loss 0.5961
# step 4400: train loss 0.5956, val loss 0.5966
# step 4500: train loss 0.5961, val loss 0.5960
# step 4600: train loss 0.5966, val loss 0.5960
# step 4700: train loss 0.5963, val loss 0.5963
# step 4800: train loss 0.5962, val loss 0.5965
# step 4900: train loss 0.5963, val loss 0.5970
# step 4999: train loss 0.5969, val loss 0.5962
# Training model order=1 number=4
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.1997, 0.8003],
#         [0.3548, 0.6452]])
# step 0: train loss 0.6830, val loss 0.6841
# step 100: train loss 0.6060, val loss 0.6070
# step 200: train loss 0.6051, val loss 0.6067
# step 300: train loss 0.6052, val loss 0.6059
# step 400: train loss 0.6041, val loss 0.6055
# step 500: train loss 0.6045, val loss 0.6061
# step 600: train loss 0.6045, val loss 0.6057
# step 700: train loss 0.6039, val loss 0.6056
# step 800: train loss 0.6042, val loss 0.6051
# step 900: train loss 0.6045, val loss 0.6057
# step 1000: train loss 0.6046, val loss 0.6058
# step 1100: train loss 0.6044, val loss 0.6056
# step 1200: train loss 0.6045, val loss 0.6057
# step 1300: train loss 0.6043, val loss 0.6054
# step 1400: train loss 0.6048, val loss 0.6059
# step 1500: train loss 0.6044, val loss 0.6055
# step 1600: train loss 0.6039, val loss 0.6053
# step 1700: train loss 0.6051, val loss 0.6057
# step 1800: train loss 0.6049, val loss 0.6050
# step 1900: train loss 0.6042, val loss 0.6054
# step 2000: train loss 0.6040, val loss 0.6054
# step 2100: train loss 0.6044, val loss 0.6054
# step 2200: train loss 0.6044, val loss 0.6051
# step 2300: train loss 0.6039, val loss 0.6053
# step 2400: train loss 0.6044, val loss 0.6050
# step 2500: train loss 0.6045, val loss 0.6052
# step 2600: train loss 0.6043, val loss 0.6059
# step 2700: train loss 0.6046, val loss 0.6054
# step 2800: train loss 0.6042, val loss 0.6055
# step 2900: train loss 0.6046, val loss 0.6053
# step 3000: train loss 0.6045, val loss 0.6056
# step 3100: train loss 0.6042, val loss 0.6058
# step 3200: train loss 0.6042, val loss 0.6054
# step 3300: train loss 0.6041, val loss 0.6050
# step 3400: train loss 0.6043, val loss 0.6055
# step 3500: train loss 0.6047, val loss 0.6055
# step 3600: train loss 0.6044, val loss 0.6053
# step 3700: train loss 0.6043, val loss 0.6055
# step 3800: train loss 0.6044, val loss 0.6050
# step 3900: train loss 0.6050, val loss 0.6057
# step 4000: train loss 0.6047, val loss 0.6054
# step 4100: train loss 0.6047, val loss 0.6054
# step 4200: train loss 0.6040, val loss 0.6055
# step 4300: train loss 0.6044, val loss 0.6054
# step 4400: train loss 0.6043, val loss 0.6049
# step 4500: train loss 0.6044, val loss 0.6051
# step 4600: train loss 0.6046, val loss 0.6056
# step 4700: train loss 0.6046, val loss 0.6054
# step 4800: train loss 0.6043, val loss 0.6054
# step 4900: train loss 0.6044, val loss 0.6053
# step 4999: train loss 0.6041, val loss 0.6056
# Training model order=1 number=5
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.4163, 0.5837],
#         [0.3710, 0.6290]])
# step 0: train loss 0.7262, val loss 0.7275
# step 100: train loss 0.6675, val loss 0.6685
# step 200: train loss 0.6671, val loss 0.6681
# step 300: train loss 0.6672, val loss 0.6678
# step 400: train loss 0.6667, val loss 0.6679
# step 500: train loss 0.6670, val loss 0.6678
# step 600: train loss 0.6671, val loss 0.6678
# step 700: train loss 0.6666, val loss 0.6675
# step 800: train loss 0.6670, val loss 0.6675
# step 900: train loss 0.6668, val loss 0.6675
# step 1000: train loss 0.6671, val loss 0.6675
# step 1100: train loss 0.6670, val loss 0.6679
# step 1200: train loss 0.6669, val loss 0.6678
# step 1300: train loss 0.6668, val loss 0.6676
# step 1400: train loss 0.6671, val loss 0.6678
# step 1500: train loss 0.6671, val loss 0.6677
# step 1600: train loss 0.6668, val loss 0.6675
# step 1700: train loss 0.6669, val loss 0.6677
# step 1800: train loss 0.6671, val loss 0.6676
# step 1900: train loss 0.6669, val loss 0.6677
# step 2000: train loss 0.6666, val loss 0.6676
# step 2100: train loss 0.6670, val loss 0.6679
# step 2200: train loss 0.6668, val loss 0.6673
# step 2300: train loss 0.6667, val loss 0.6675
# step 2400: train loss 0.6671, val loss 0.6674
# step 2500: train loss 0.6672, val loss 0.6677
# step 2600: train loss 0.6669, val loss 0.6675
# step 2700: train loss 0.6670, val loss 0.6677
# step 2800: train loss 0.6670, val loss 0.6679
# step 2900: train loss 0.6670, val loss 0.6678
# step 3000: train loss 0.6668, val loss 0.6675
# step 3100: train loss 0.6669, val loss 0.6678
# step 3200: train loss 0.6667, val loss 0.6676
# step 3300: train loss 0.6668, val loss 0.6672
# step 3400: train loss 0.6667, val loss 0.6675
# step 3500: train loss 0.6672, val loss 0.6678
# step 3600: train loss 0.6667, val loss 0.6679
# step 3700: train loss 0.6669, val loss 0.6678
# step 3800: train loss 0.6670, val loss 0.6673
# step 3900: train loss 0.6673, val loss 0.6680
# step 4000: train loss 0.6672, val loss 0.6677
# step 4100: train loss 0.6671, val loss 0.6677
# step 4200: train loss 0.6669, val loss 0.6679
# step 4300: train loss 0.6670, val loss 0.6678
# step 4400: train loss 0.6667, val loss 0.6675
# step 4500: train loss 0.6670, val loss 0.6673
# step 4600: train loss 0.6671, val loss 0.6678
# step 4700: train loss 0.6670, val loss 0.6677
# step 4800: train loss 0.6668, val loss 0.6674
# step 4900: train loss 0.6668, val loss 0.6676
# step 4999: train loss 0.6668, val loss 0.6674
# Training model order=2 number=1
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.4424, 0.5576],
#         [0.8116, 0.1884],
#         [0.9809, 0.0191],
#         [0.9278, 0.0722]])
# step 0: train loss 0.9005, val loss 0.9004
# step 100: train loss 0.5988, val loss 0.5978
# step 200: train loss 0.5967, val loss 0.5951
# step 300: train loss 0.5960, val loss 0.5949
# step 400: train loss 0.5950, val loss 0.5942
# step 500: train loss 0.5951, val loss 0.5937
# step 600: train loss 0.5951, val loss 0.5938
# step 700: train loss 0.5945, val loss 0.5939
# step 800: train loss 0.5942, val loss 0.5933
# step 900: train loss 0.5939, val loss 0.5929
# step 1000: train loss 0.5935, val loss 0.5925
# step 1100: train loss 0.5924, val loss 0.5915
# step 1200: train loss 0.5924, val loss 0.5911
# step 1300: train loss 0.5916, val loss 0.5907
# step 1400: train loss 0.5913, val loss 0.5901
# step 1500: train loss 0.5911, val loss 0.5903
# step 1600: train loss 0.5901, val loss 0.5892
# step 1700: train loss 0.5898, val loss 0.5889
# step 1800: train loss 0.5890, val loss 0.5878
# step 1900: train loss 0.5883, val loss 0.5871
# step 2000: train loss 0.5872, val loss 0.5866
# step 2100: train loss 0.5863, val loss 0.5857
# step 2200: train loss 0.5854, val loss 0.5845
# step 2300: train loss 0.5841, val loss 0.5828
# step 2400: train loss 0.5822, val loss 0.5815
# step 2500: train loss 0.5802, val loss 0.5793
# step 2600: train loss 0.5788, val loss 0.5779
# step 2700: train loss 0.5763, val loss 0.5750
# step 2800: train loss 0.5738, val loss 0.5729
# step 2900: train loss 0.5712, val loss 0.5704
# step 3000: train loss 0.5690, val loss 0.5678
# step 3100: train loss 0.5660, val loss 0.5649
# step 3200: train loss 0.5639, val loss 0.5624
# step 3300: train loss 0.5614, val loss 0.5603
# step 3400: train loss 0.5595, val loss 0.5581
# step 3500: train loss 0.5572, val loss 0.5570
# step 3600: train loss 0.5557, val loss 0.5549
# step 3700: train loss 0.5542, val loss 0.5538
# step 3800: train loss 0.5536, val loss 0.5530
# step 3900: train loss 0.5519, val loss 0.5520
# step 4000: train loss 0.5513, val loss 0.5508
# step 4100: train loss 0.5509, val loss 0.5503
# step 4200: train loss 0.5505, val loss 0.5497
# step 4300: train loss 0.5498, val loss 0.5495
# step 4400: train loss 0.5493, val loss 0.5491
# step 4500: train loss 0.5494, val loss 0.5489
# step 4600: train loss 0.5493, val loss 0.5487
# step 4700: train loss 0.5496, val loss 0.5482
# step 4800: train loss 0.5490, val loss 0.5485
# step 4900: train loss 0.5491, val loss 0.5486
# step 4999: train loss 0.5495, val loss 0.5484
# Training model order=2 number=2
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.4291, 0.5709],
#         [0.3349, 0.6651],
#         [0.4038, 0.5962],
#         [0.2353, 0.7647]])
# step 0: train loss 0.6775, val loss 0.6783
# step 100: train loss 0.6077, val loss 0.6084
# step 200: train loss 0.6073, val loss 0.6083
# step 300: train loss 0.6068, val loss 0.6074
# step 400: train loss 0.6059, val loss 0.6073
# step 500: train loss 0.6067, val loss 0.6076
# step 600: train loss 0.6064, val loss 0.6074
# step 700: train loss 0.6054, val loss 0.6067
# step 800: train loss 0.6067, val loss 0.6072
# step 900: train loss 0.6060, val loss 0.6067
# step 1000: train loss 0.6069, val loss 0.6069
# step 1100: train loss 0.6059, val loss 0.6069
# step 1200: train loss 0.6057, val loss 0.6073
# step 1300: train loss 0.6059, val loss 0.6069
# step 1400: train loss 0.6066, val loss 0.6074
# step 1500: train loss 0.6067, val loss 0.6071
# step 1600: train loss 0.6059, val loss 0.6070
# step 1700: train loss 0.6062, val loss 0.6068
# step 1800: train loss 0.6067, val loss 0.6071
# step 1900: train loss 0.6063, val loss 0.6069
# step 2000: train loss 0.6052, val loss 0.6069
# step 2100: train loss 0.6064, val loss 0.6074
# step 2200: train loss 0.6059, val loss 0.6062
# step 2300: train loss 0.6058, val loss 0.6070
# step 2400: train loss 0.6063, val loss 0.6065
# step 2500: train loss 0.6066, val loss 0.6071
# step 2600: train loss 0.6059, val loss 0.6070
# step 2700: train loss 0.6064, val loss 0.6070
# step 2800: train loss 0.6066, val loss 0.6069
# step 2900: train loss 0.6068, val loss 0.6071
# step 3000: train loss 0.6060, val loss 0.6072
# step 3100: train loss 0.6058, val loss 0.6071
# step 3200: train loss 0.6060, val loss 0.6073
# step 3300: train loss 0.6061, val loss 0.6066
# step 3400: train loss 0.6055, val loss 0.6069
# step 3500: train loss 0.6069, val loss 0.6069
# step 3600: train loss 0.6058, val loss 0.6071
# step 3700: train loss 0.6064, val loss 0.6071
# step 3800: train loss 0.6063, val loss 0.6063
# step 3900: train loss 0.6067, val loss 0.6078
# step 4000: train loss 0.6068, val loss 0.6074
# step 4100: train loss 0.6063, val loss 0.6069
# step 4200: train loss 0.6059, val loss 0.6075
# step 4300: train loss 0.6067, val loss 0.6073
# step 4400: train loss 0.6064, val loss 0.6071
# step 4500: train loss 0.6065, val loss 0.6066
# step 4600: train loss 0.6065, val loss 0.6071
# step 4700: train loss 0.6060, val loss 0.6068
# step 4800: train loss 0.6068, val loss 0.6071
# step 4900: train loss 0.6062, val loss 0.6068
# step 4999: train loss 0.6054, val loss 0.6068
# Training model order=2 number=3
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.9976, 0.0024],
#         [0.3374, 0.6626],
#         [0.9203, 0.0797],
#         [0.4960, 0.5040]])
# step 0: train loss 1.0586, val loss 1.0583
# step 100: train loss 0.0300, val loss 0.0319
# step 200: train loss 0.0236, val loss 0.0253
# step 300: train loss 0.0224, val loss 0.0237
# step 400: train loss 0.0217, val loss 0.0238
# step 500: train loss 0.0215, val loss 0.0238
# step 600: train loss 0.0216, val loss 0.0239
# step 700: train loss 0.0216, val loss 0.0232
# step 800: train loss 0.0210, val loss 0.0238
# step 900: train loss 0.0219, val loss 0.0239
# step 1000: train loss 0.0216, val loss 0.0237
# step 1100: train loss 0.0211, val loss 0.0241
# step 1200: train loss 0.0216, val loss 0.0233
# step 1300: train loss 0.0212, val loss 0.0239
# step 1400: train loss 0.0213, val loss 0.0241
# step 1500: train loss 0.0218, val loss 0.0238
# step 1600: train loss 0.0215, val loss 0.0235
# step 1700: train loss 0.0212, val loss 0.0234
# step 1800: train loss 0.0212, val loss 0.0235
# step 1900: train loss 0.0211, val loss 0.0241
# step 2000: train loss 0.0213, val loss 0.0234
# step 2100: train loss 0.0220, val loss 0.0237
# step 2200: train loss 0.0217, val loss 0.0238
# step 2300: train loss 0.0212, val loss 0.0237
# step 2400: train loss 0.0211, val loss 0.0240
# step 2500: train loss 0.0212, val loss 0.0239
# step 2600: train loss 0.0216, val loss 0.0234
# step 2700: train loss 0.0217, val loss 0.0238
# step 2800: train loss 0.0216, val loss 0.0239
# step 2900: train loss 0.0213, val loss 0.0231
# step 3000: train loss 0.0211, val loss 0.0241
# step 3100: train loss 0.0216, val loss 0.0236
# step 3200: train loss 0.0226, val loss 0.0239
# step 3300: train loss 0.0216, val loss 0.0235
# step 3400: train loss 0.0212, val loss 0.0238
# step 3500: train loss 0.0215, val loss 0.0238
# step 3600: train loss 0.0216, val loss 0.0233
# step 3700: train loss 0.0223, val loss 0.0242
# step 3800: train loss 0.0217, val loss 0.0237
# step 3900: train loss 0.0217, val loss 0.0233
# step 4000: train loss 0.0213, val loss 0.0236
# step 4100: train loss 0.0216, val loss 0.0233
# step 4200: train loss 0.0215, val loss 0.0233
# step 4300: train loss 0.0211, val loss 0.0232
# step 4400: train loss 0.0217, val loss 0.0235
# step 4500: train loss 0.0213, val loss 0.0239
# step 4600: train loss 0.0213, val loss 0.0235
# step 4700: train loss 0.0214, val loss 0.0235
# step 4800: train loss 0.0210, val loss 0.0238
# step 4900: train loss 0.0216, val loss 0.0239
# step 4999: train loss 0.0210, val loss 0.0234
# Training model order=2 number=4
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.8026, 0.1974],
#         [0.4930, 0.5070],
#         [0.5017, 0.4983],
#         [0.0944, 0.9056]])
# step 0: train loss 0.6972, val loss 0.6937
# step 100: train loss 0.4959, val loss 0.4921
# step 200: train loss 0.4937, val loss 0.4903
# step 300: train loss 0.4933, val loss 0.4892
# step 400: train loss 0.4925, val loss 0.4892
# step 500: train loss 0.4919, val loss 0.4886
# step 600: train loss 0.4921, val loss 0.4877
# step 700: train loss 0.4929, val loss 0.4881
# step 800: train loss 0.4926, val loss 0.4878
# step 900: train loss 0.4924, val loss 0.4862
# step 1000: train loss 0.4926, val loss 0.4855
# step 1100: train loss 0.4916, val loss 0.4877
# step 1200: train loss 0.4913, val loss 0.4868
# step 1300: train loss 0.4912, val loss 0.4864
# step 1400: train loss 0.4921, val loss 0.4865
# step 1500: train loss 0.4906, val loss 0.4864
# step 1600: train loss 0.4900, val loss 0.4851
# step 1700: train loss 0.4906, val loss 0.4857
# step 1800: train loss 0.4901, val loss 0.4848
# step 1900: train loss 0.4901, val loss 0.4844
# step 2000: train loss 0.4877, val loss 0.4842
# step 2100: train loss 0.4890, val loss 0.4834
# step 2200: train loss 0.4863, val loss 0.4804
# step 2300: train loss 0.4866, val loss 0.4811
# step 2400: train loss 0.4852, val loss 0.4802
# step 2500: train loss 0.4860, val loss 0.4784
# step 2600: train loss 0.4834, val loss 0.4773
# step 2700: train loss 0.4829, val loss 0.4765
# step 2800: train loss 0.4830, val loss 0.4769
# step 2900: train loss 0.4827, val loss 0.4769
# step 3000: train loss 0.4819, val loss 0.4769
# step 3100: train loss 0.4815, val loss 0.4744
# step 3200: train loss 0.4814, val loss 0.4754
# step 3300: train loss 0.4812, val loss 0.4739
# step 3400: train loss 0.4782, val loss 0.4745
# step 3500: train loss 0.4801, val loss 0.4741
# step 3600: train loss 0.4801, val loss 0.4743
# step 3700: train loss 0.4808, val loss 0.4745
# step 3800: train loss 0.4782, val loss 0.4731
# step 3900: train loss 0.4805, val loss 0.4735
# step 4000: train loss 0.4807, val loss 0.4730
# step 4100: train loss 0.4788, val loss 0.4732
# step 4200: train loss 0.4801, val loss 0.4739
# step 4300: train loss 0.4795, val loss 0.4730
# step 4400: train loss 0.4801, val loss 0.4731
# step 4500: train loss 0.4801, val loss 0.4729
# step 4600: train loss 0.4790, val loss 0.4721
# step 4700: train loss 0.4789, val loss 0.4741
# step 4800: train loss 0.4806, val loss 0.4739
# step 4900: train loss 0.4784, val loss 0.4734
# step 4999: train loss 0.4780, val loss 0.4723
# Training model order=2 number=5
# 0.014754 M parameters
# Transition Matrix:
#  tensor([[0.5933, 0.4067],
#         [0.6894, 0.3106],
#         [0.1793, 0.8207],
#         [0.3185, 0.6815]])
# step 0: train loss 0.7501, val loss 0.7518
# step 100: train loss 0.6615, val loss 0.6639
# step 200: train loss 0.6607, val loss 0.6633
# step 300: train loss 0.6599, val loss 0.6618
# step 400: train loss 0.6592, val loss 0.6614
# step 500: train loss 0.6593, val loss 0.6619
# step 600: train loss 0.6588, val loss 0.6611
# step 700: train loss 0.6581, val loss 0.6609
# step 800: train loss 0.6581, val loss 0.6604
# step 900: train loss 0.6584, val loss 0.6612
# step 1000: train loss 0.6581, val loss 0.6601
# step 1100: train loss 0.6577, val loss 0.6600
# step 1200: train loss 0.6575, val loss 0.6603
# step 1300: train loss 0.6571, val loss 0.6598
# step 1400: train loss 0.6572, val loss 0.6595
# step 1500: train loss 0.6564, val loss 0.6584
# step 1600: train loss 0.6558, val loss 0.6590
# step 1700: train loss 0.6556, val loss 0.6586
# step 1800: train loss 0.6549, val loss 0.6571
# step 1900: train loss 0.6540, val loss 0.6565
# step 2000: train loss 0.6529, val loss 0.6557
# step 2100: train loss 0.6525, val loss 0.6546
# step 2200: train loss 0.6513, val loss 0.6539
# step 2300: train loss 0.6496, val loss 0.6529
# step 2400: train loss 0.6493, val loss 0.6516
# step 2500: train loss 0.6475, val loss 0.6506
# step 2600: train loss 0.6472, val loss 0.6496
# step 2700: train loss 0.6462, val loss 0.6486
# step 2800: train loss 0.6455, val loss 0.6483
# step 2900: train loss 0.6453, val loss 0.6472
# step 3000: train loss 0.6438, val loss 0.6476
# step 3100: train loss 0.6435, val loss 0.6463
# step 3200: train loss 0.6426, val loss 0.6461
# step 3300: train loss 0.6423, val loss 0.6459
# step 3400: train loss 0.6426, val loss 0.6452
# step 3500: train loss 0.6422, val loss 0.6443
# step 3600: train loss 0.6417, val loss 0.6439
# step 3700: train loss 0.6416, val loss 0.6444
# step 3800: train loss 0.6411, val loss 0.6437
# step 3900: train loss 0.6418, val loss 0.6437
# step 4000: train loss 0.6411, val loss 0.6438
# step 4100: train loss 0.6411, val loss 0.6433
# step 4200: train loss 0.6404, val loss 0.6434
# step 4300: train loss 0.6408, val loss 0.6435
# step 4400: train loss 0.6401, val loss 0.6434
# step 4500: train loss 0.6405, val loss 0.6434
# step 4600: train loss 0.6403, val loss 0.6434
# step 4700: train loss 0.6402, val loss 0.6428
# step 4800: train loss 0.6404, val loss 0.6433
# step 4900: train loss 0.6404, val loss 0.6432
# step 4999: train loss 0.6403, val loss 0.6434

# %%
base_path = Path("models")
base_path.mkdir(exist_ok=True)
# convert and save
serializable_models = tensor_to_serializable(my_models)
filename = f"my_models_saved.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(serializable_models, f, indent=2)

print(f"Saved models to {filepath}")
# Out:
# Saved models to models2/my_models_saved.json

# %% [markdown]
# Order 2:

# %%
n_head = 1
n_layer = 2
n_embd = 64
sequence_length = 1000
num_sequences = 500
num_iterations = 5000
seeds = [92, 93, 94, 95, 96]
idx = 0
for number in range(1, 6): # 5 models per order
    try:
        print(f"Training model order=2 number={number}")
        model_info = train_model(2, number, num_iterations, seeds[idx], sequence_length, num_sequences)
        my_models.append(model_info)
        idx += 1
        
        if device.type == "mps":
            torch.mps.empty_cache() # cleanup
            
    except Exception as e:
        print(f"Failed training model number={number}: {e}")
        continue
# Out:
# Training model order=2 number=1
# 0.132738 M parameters
# Transition Matrix:
#  tensor([[0.4424, 0.5576],
#         [0.8116, 0.1884],
#         [0.9809, 0.0191],
#         [0.9278, 0.0722]])
# step 0: train loss 0.8664, val loss 0.8662
# step 100: train loss 0.5956, val loss 0.5944
# step 200: train loss 0.5951, val loss 0.5935
# step 300: train loss 0.5922, val loss 0.5911
# step 400: train loss 0.5844, val loss 0.5835
# step 500: train loss 0.5749, val loss 0.5736
# step 600: train loss 0.5645, val loss 0.5635
# step 700: train loss 0.5528, val loss 0.5527
# step 800: train loss 0.5458, val loss 0.5453
# step 900: train loss 0.5406, val loss 0.5402
# step 1000: train loss 0.5351, val loss 0.5342
# step 1100: train loss 0.5310, val loss 0.5305
# step 1200: train loss 0.5272, val loss 0.5268
# step 1300: train loss 0.5240, val loss 0.5235
# step 1400: train loss 0.5215, val loss 0.5204
# step 1500: train loss 0.5177, val loss 0.5178
# step 1600: train loss 0.5103, val loss 0.5103
# step 1700: train loss 0.5054, val loss 0.5048
# step 1800: train loss 0.4999, val loss 0.4986
# step 1900: train loss 0.4947, val loss 0.4943
# step 2000: train loss 0.4909, val loss 0.4908
# step 2100: train loss 0.4884, val loss 0.4884
# step 2200: train loss 0.4855, val loss 0.4847
# step 2300: train loss 0.4843, val loss 0.4836
# step 2400: train loss 0.4833, val loss 0.4828
# step 2500: train loss 0.4820, val loss 0.4816
# step 2600: train loss 0.4817, val loss 0.4806
# step 2700: train loss 0.4809, val loss 0.4800
# step 2800: train loss 0.4809, val loss 0.4802
# step 2900: train loss 0.4800, val loss 0.4796
# step 3000: train loss 0.4802, val loss 0.4791
# step 3100: train loss 0.4796, val loss 0.4792
# step 3200: train loss 0.4799, val loss 0.4788
# step 3300: train loss 0.4793, val loss 0.4784
# step 3400: train loss 0.4788, val loss 0.4779
# step 3500: train loss 0.4777, val loss 0.4784
# step 3600: train loss 0.4780, val loss 0.4779
# step 3700: train loss 0.4781, val loss 0.4774
# step 3800: train loss 0.4778, val loss 0.4772
# step 3900: train loss 0.4770, val loss 0.4775
# step 4000: train loss 0.4774, val loss 0.4764
# step 4100: train loss 0.4772, val loss 0.4764
# step 4200: train loss 0.4778, val loss 0.4770
# step 4300: train loss 0.4772, val loss 0.4769
# step 4400: train loss 0.4767, val loss 0.4771
# step 4500: train loss 0.4769, val loss 0.4770
# step 4600: train loss 0.4772, val loss 0.4767
# step 4700: train loss 0.4775, val loss 0.4764
# step 4800: train loss 0.4767, val loss 0.4767
# step 4900: train loss 0.4770, val loss 0.4766
# step 4999: train loss 0.4776, val loss 0.4764
# Training model order=2 number=2
# 0.132738 M parameters
# Transition Matrix:
#  tensor([[0.4291, 0.5709],
#         [0.3349, 0.6651],
#         [0.4038, 0.5962],
#         [0.2353, 0.7647]])
# step 0: train loss 0.6920, val loss 0.6927
# step 100: train loss 0.6069, val loss 0.6077
# step 200: train loss 0.6065, val loss 0.6075
# step 300: train loss 0.6065, val loss 0.6071
# step 400: train loss 0.6059, val loss 0.6072
# step 500: train loss 0.6066, val loss 0.6076
# step 600: train loss 0.6066, val loss 0.6076
# step 700: train loss 0.6054, val loss 0.6067
# step 800: train loss 0.6068, val loss 0.6073
# step 900: train loss 0.6060, val loss 0.6068
# step 1000: train loss 0.6069, val loss 0.6069
# step 1100: train loss 0.6059, val loss 0.6069
# step 1200: train loss 0.6056, val loss 0.6072
# step 1300: train loss 0.6057, val loss 0.6068
# step 1400: train loss 0.6066, val loss 0.6074
# step 1500: train loss 0.6066, val loss 0.6070
# step 1600: train loss 0.6058, val loss 0.6070
# step 1700: train loss 0.6062, val loss 0.6068
# step 1800: train loss 0.6067, val loss 0.6071
# step 1900: train loss 0.6062, val loss 0.6068
# step 2000: train loss 0.6052, val loss 0.6069
# step 2100: train loss 0.6063, val loss 0.6073
# step 2200: train loss 0.6058, val loss 0.6061
# step 2300: train loss 0.6056, val loss 0.6069
# step 2400: train loss 0.6062, val loss 0.6065
# step 2500: train loss 0.6064, val loss 0.6069
# step 2600: train loss 0.6057, val loss 0.6069
# step 2700: train loss 0.6063, val loss 0.6070
# step 2800: train loss 0.6064, val loss 0.6068
# step 2900: train loss 0.6066, val loss 0.6069
# step 3000: train loss 0.6058, val loss 0.6071
# step 3100: train loss 0.6056, val loss 0.6070
# step 3200: train loss 0.6058, val loss 0.6071
# step 3300: train loss 0.6059, val loss 0.6066
# step 3400: train loss 0.6054, val loss 0.6068
# step 3500: train loss 0.6067, val loss 0.6067
# step 3600: train loss 0.6056, val loss 0.6070
# step 3700: train loss 0.6062, val loss 0.6070
# step 3800: train loss 0.6060, val loss 0.6061
# step 3900: train loss 0.6065, val loss 0.6076
# step 4000: train loss 0.6065, val loss 0.6072
# step 4100: train loss 0.6060, val loss 0.6067
# step 4200: train loss 0.6056, val loss 0.6073
# step 4300: train loss 0.6064, val loss 0.6071
# step 4400: train loss 0.6061, val loss 0.6069
# step 4500: train loss 0.6062, val loss 0.6064
# step 4600: train loss 0.6062, val loss 0.6069
# step 4700: train loss 0.6057, val loss 0.6066
# step 4800: train loss 0.6065, val loss 0.6068
# step 4900: train loss 0.6059, val loss 0.6065
# step 4999: train loss 0.6051, val loss 0.6066
# Training model order=2 number=3
# 0.132738 M parameters
# Transition Matrix:
#  tensor([[0.9976, 0.0024],
#         [0.3374, 0.6626],
#         [0.9203, 0.0797],
#         [0.4960, 0.5040]])
# step 0: train loss 0.5489, val loss 0.5492
# step 100: train loss 0.0211, val loss 0.0235
# step 200: train loss 0.0219, val loss 0.0239
# step 300: train loss 0.0219, val loss 0.0232
# step 400: train loss 0.0214, val loss 0.0235
# step 500: train loss 0.0213, val loss 0.0236
# step 600: train loss 0.0215, val loss 0.0238
# step 700: train loss 0.0215, val loss 0.0231
# step 800: train loss 0.0210, val loss 0.0237
# step 900: train loss 0.0218, val loss 0.0238
# step 1000: train loss 0.0216, val loss 0.0237
# step 1100: train loss 0.0211, val loss 0.0240
# step 1200: train loss 0.0215, val loss 0.0233
# step 1300: train loss 0.0212, val loss 0.0239
# step 1400: train loss 0.0213, val loss 0.0240
# step 1500: train loss 0.0217, val loss 0.0238
# step 1600: train loss 0.0215, val loss 0.0235
# step 1700: train loss 0.0212, val loss 0.0234
# step 1800: train loss 0.0212, val loss 0.0235
# step 1900: train loss 0.0211, val loss 0.0241
# step 2000: train loss 0.0213, val loss 0.0234
# step 2100: train loss 0.0220, val loss 0.0236
# step 2200: train loss 0.0217, val loss 0.0238
# step 2300: train loss 0.0212, val loss 0.0237
# step 2400: train loss 0.0210, val loss 0.0240
# step 2500: train loss 0.0212, val loss 0.0239
# step 2600: train loss 0.0216, val loss 0.0234
# step 2700: train loss 0.0217, val loss 0.0239
# step 2800: train loss 0.0215, val loss 0.0240
# step 2900: train loss 0.0212, val loss 0.0231
# step 3000: train loss 0.0210, val loss 0.0241
# step 3100: train loss 0.0216, val loss 0.0236
# step 3200: train loss 0.0225, val loss 0.0239
# step 3300: train loss 0.0216, val loss 0.0235
# step 3400: train loss 0.0212, val loss 0.0237
# step 3500: train loss 0.0214, val loss 0.0237
# step 3600: train loss 0.0215, val loss 0.0233
# step 3700: train loss 0.0223, val loss 0.0242
# step 3800: train loss 0.0217, val loss 0.0237
# step 3900: train loss 0.0217, val loss 0.0233
# step 4000: train loss 0.0212, val loss 0.0236
# step 4100: train loss 0.0215, val loss 0.0233
# step 4200: train loss 0.0214, val loss 0.0233
# step 4300: train loss 0.0211, val loss 0.0232
# step 4400: train loss 0.0217, val loss 0.0234
# step 4500: train loss 0.0213, val loss 0.0239
# step 4600: train loss 0.0212, val loss 0.0235
# step 4700: train loss 0.0213, val loss 0.0235
# step 4800: train loss 0.0210, val loss 0.0238
# step 4900: train loss 0.0216, val loss 0.0239
# step 4999: train loss 0.0210, val loss 0.0234
# Training model order=2 number=4
# 0.132738 M parameters
# Transition Matrix:
#  tensor([[0.8026, 0.1974],
#         [0.4930, 0.5070],
#         [0.5017, 0.4983],
#         [0.0944, 0.9056]])
# step 0: train loss 0.6394, val loss 0.6390
# step 100: train loss 0.4932, val loss 0.4893
# step 200: train loss 0.4925, val loss 0.4889
# step 300: train loss 0.4924, val loss 0.4881
# step 400: train loss 0.4904, val loss 0.4870
# step 500: train loss 0.4877, val loss 0.4843
# step 600: train loss 0.4858, val loss 0.4810
# step 700: train loss 0.4834, val loss 0.4780
# step 800: train loss 0.4800, val loss 0.4745
# step 900: train loss 0.4764, val loss 0.4700
# step 1000: train loss 0.4755, val loss 0.4676
# step 1100: train loss 0.4700, val loss 0.4655
# step 1200: train loss 0.4658, val loss 0.4604
# step 1300: train loss 0.4612, val loss 0.4558
# step 1400: train loss 0.4584, val loss 0.4520
# step 1500: train loss 0.4549, val loss 0.4501
# step 1600: train loss 0.4525, val loss 0.4474
# step 1700: train loss 0.4520, val loss 0.4476
# step 1800: train loss 0.4517, val loss 0.4461
# step 1900: train loss 0.4514, val loss 0.4453
# step 2000: train loss 0.4488, val loss 0.4457
# step 2100: train loss 0.4500, val loss 0.4447
# step 2200: train loss 0.4485, val loss 0.4425
# step 2300: train loss 0.4480, val loss 0.4435
# step 2400: train loss 0.4481, val loss 0.4436
# step 2500: train loss 0.4492, val loss 0.4427
# step 2600: train loss 0.4477, val loss 0.4420
# step 2700: train loss 0.4479, val loss 0.4419
# step 2800: train loss 0.4480, val loss 0.4427
# step 2900: train loss 0.4476, val loss 0.4429
# step 3000: train loss 0.4475, val loss 0.4437
# step 3100: train loss 0.4476, val loss 0.4413
# step 3200: train loss 0.4475, val loss 0.4430
# step 3300: train loss 0.4475, val loss 0.4411
# step 3400: train loss 0.4454, val loss 0.4424
# step 3500: train loss 0.4469, val loss 0.4420
# step 3600: train loss 0.4470, val loss 0.4422
# step 3700: train loss 0.4475, val loss 0.4425
# step 3800: train loss 0.4456, val loss 0.4408
# step 3900: train loss 0.4471, val loss 0.4414
# step 4000: train loss 0.4479, val loss 0.4412
# step 4100: train loss 0.4462, val loss 0.4415
# step 4200: train loss 0.4475, val loss 0.4423
# step 4300: train loss 0.4470, val loss 0.4416
# step 4400: train loss 0.4474, val loss 0.4416
# step 4500: train loss 0.4473, val loss 0.4412
# step 4600: train loss 0.4467, val loss 0.4405
# step 4700: train loss 0.4461, val loss 0.4424
# step 4800: train loss 0.4479, val loss 0.4423
# step 4900: train loss 0.4458, val loss 0.4414
# step 4999: train loss 0.4456, val loss 0.4408
# Training model order=2 number=5
# 0.132738 M parameters
# Transition Matrix:
#  tensor([[0.5933, 0.4067],
#         [0.6894, 0.3106],
#         [0.1793, 0.8207],
#         [0.3185, 0.6815]])
# step 0: train loss 0.7625, val loss 0.7618
# step 100: train loss 0.6605, val loss 0.6630
# step 200: train loss 0.6592, val loss 0.6619
# step 300: train loss 0.6564, val loss 0.6584
# step 400: train loss 0.6539, val loss 0.6561
# step 500: train loss 0.6500, val loss 0.6524
# step 600: train loss 0.6447, val loss 0.6474
# step 700: train loss 0.6391, val loss 0.6422
# step 800: train loss 0.6369, val loss 0.6398
# step 900: train loss 0.6349, val loss 0.6377
# step 1000: train loss 0.6319, val loss 0.6343
# step 1100: train loss 0.6292, val loss 0.6327
# step 1200: train loss 0.6278, val loss 0.6311
# step 1300: train loss 0.6270, val loss 0.6296
# step 1400: train loss 0.6267, val loss 0.6292
# step 1500: train loss 0.6257, val loss 0.6282
# step 1600: train loss 0.6237, val loss 0.6278
# step 1700: train loss 0.6237, val loss 0.6273
# step 1800: train loss 0.6230, val loss 0.6256
# step 1900: train loss 0.6222, val loss 0.6250
# step 2000: train loss 0.6206, val loss 0.6243
# step 2100: train loss 0.6204, val loss 0.6230
# step 2200: train loss 0.6186, val loss 0.6219
# step 2300: train loss 0.6152, val loss 0.6194
# step 2400: train loss 0.6122, val loss 0.6154
# step 2500: train loss 0.6073, val loss 0.6110
# step 2600: train loss 0.6049, val loss 0.6085
# step 2700: train loss 0.6017, val loss 0.6052
# step 2800: train loss 0.5995, val loss 0.6030
# step 2900: train loss 0.5984, val loss 0.6016
# step 3000: train loss 0.5969, val loss 0.6008
# step 3100: train loss 0.5953, val loss 0.5998
# step 3200: train loss 0.5941, val loss 0.5990
# step 3300: train loss 0.5939, val loss 0.5980
# step 3400: train loss 0.5935, val loss 0.5966
# step 3500: train loss 0.5930, val loss 0.5963
# step 3600: train loss 0.5927, val loss 0.5958
# step 3700: train loss 0.5921, val loss 0.5968
# step 3800: train loss 0.5921, val loss 0.5955
# step 3900: train loss 0.5928, val loss 0.5955
# step 4000: train loss 0.5919, val loss 0.5956
# step 4100: train loss 0.5920, val loss 0.5949
# step 4200: train loss 0.5911, val loss 0.5953
# step 4300: train loss 0.5912, val loss 0.5948
# step 4400: train loss 0.5910, val loss 0.5949
# step 4500: train loss 0.5909, val loss 0.5948
# step 4600: train loss 0.5912, val loss 0.5950
# step 4700: train loss 0.5912, val loss 0.5942
# step 4800: train loss 0.5910, val loss 0.5944
# step 4900: train loss 0.5911, val loss 0.5948
# step 4999: train loss 0.5907, val loss 0.5951

# %%
base_path = Path("models")
base_path.mkdir(exist_ok=True)
# convert and save
serializable_models = tensor_to_serializable(my_models)
filename = f"my_models_saved.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(serializable_models, f, indent=2)

print(f"Saved models to {filepath}")
# Out:
# Saved models to models2/my_models_saved2.json

# %% [markdown]
# Order 3:

# %%
n_head = 1
n_layer = 3
n_embd = 64
sequence_length = 1000
num_sequences = 1000
num_iterations = 10000
seeds = [97, 98, 99, 100, 101]
idx = 0
for number in range(1, 6): # 5 models per order
    try:
        print(f"Training model order=3 number={number}")
        model_info = train_model(3, number, num_iterations, seeds[idx], sequence_length, num_sequences)
        my_models.append(model_info)
        idx += 1
        
        if device.type == "mps":
            torch.mps.empty_cache() # cleanup
            
    except Exception as e:
        print(f"Failed training model number={number}: {e}")
        continue
# Out:
# Training model order=3 number=1
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.4146, 0.5854],
#         [0.2918, 0.7082],
#         [0.3577, 0.6423],
#         [0.5404, 0.4596],
#         [0.8489, 0.1511],
#         [0.5691, 0.4309],
#         [0.5103, 0.4897],
#         [0.6480, 0.3520]])
# step 0: train loss 0.7743, val loss 0.7743
# step 100: train loss 0.6929, val loss 0.6932
# step 200: train loss 0.6928, val loss 0.6931
# step 300: train loss 0.6924, val loss 0.6926
# step 400: train loss 0.6924, val loss 0.6927
# step 500: train loss 0.6921, val loss 0.6923
# step 600: train loss 0.6923, val loss 0.6926
# step 700: train loss 0.6914, val loss 0.6916
# step 800: train loss 0.6909, val loss 0.6910
# step 900: train loss 0.6896, val loss 0.6898
# step 1000: train loss 0.6883, val loss 0.6885
# step 1100: train loss 0.6860, val loss 0.6861
# step 1200: train loss 0.6837, val loss 0.6838
# step 1300: train loss 0.6801, val loss 0.6801
# step 1400: train loss 0.6778, val loss 0.6774
# step 1500: train loss 0.6755, val loss 0.6751
# step 1600: train loss 0.6739, val loss 0.6735
# step 1700: train loss 0.6728, val loss 0.6720
# step 1800: train loss 0.6722, val loss 0.6718
# step 1900: train loss 0.6711, val loss 0.6704
# step 2000: train loss 0.6701, val loss 0.6695
# step 2100: train loss 0.6695, val loss 0.6685
# step 2200: train loss 0.6675, val loss 0.6668
# step 2300: train loss 0.6666, val loss 0.6660
# step 2400: train loss 0.6662, val loss 0.6655
# step 2500: train loss 0.6635, val loss 0.6629
# step 2600: train loss 0.6615, val loss 0.6602
# step 2700: train loss 0.6582, val loss 0.6578
# step 2800: train loss 0.6562, val loss 0.6561
# step 2900: train loss 0.6539, val loss 0.6533
# step 3000: train loss 0.6520, val loss 0.6517
# step 3100: train loss 0.6506, val loss 0.6505
# step 3200: train loss 0.6497, val loss 0.6491
# step 3300: train loss 0.6493, val loss 0.6490
# step 3400: train loss 0.6488, val loss 0.6480
# step 3500: train loss 0.6482, val loss 0.6477
# step 3600: train loss 0.6481, val loss 0.6478
# step 3700: train loss 0.6476, val loss 0.6469
# step 3800: train loss 0.6473, val loss 0.6467
# step 3900: train loss 0.6468, val loss 0.6463
# step 4000: train loss 0.6465, val loss 0.6461
# step 4100: train loss 0.6464, val loss 0.6458
# step 4200: train loss 0.6462, val loss 0.6452
# step 4300: train loss 0.6457, val loss 0.6454
# step 4400: train loss 0.6453, val loss 0.6447
# step 4500: train loss 0.6449, val loss 0.6444
# step 4600: train loss 0.6451, val loss 0.6445
# step 4700: train loss 0.6447, val loss 0.6441
# step 4800: train loss 0.6449, val loss 0.6443
# step 4900: train loss 0.6444, val loss 0.6442
# step 5000: train loss 0.6447, val loss 0.6442
# step 5100: train loss 0.6441, val loss 0.6441
# step 5200: train loss 0.6436, val loss 0.6438
# step 5300: train loss 0.6436, val loss 0.6431
# step 5400: train loss 0.6438, val loss 0.6436
# step 5500: train loss 0.6437, val loss 0.6435
# step 5600: train loss 0.6441, val loss 0.6438
# step 5700: train loss 0.6439, val loss 0.6439
# step 5800: train loss 0.6440, val loss 0.6436
# step 5900: train loss 0.6438, val loss 0.6432
# step 6000: train loss 0.6435, val loss 0.6430
# step 6100: train loss 0.6435, val loss 0.6430
# step 6200: train loss 0.6434, val loss 0.6430
# step 6300: train loss 0.6435, val loss 0.6432
# step 6400: train loss 0.6433, val loss 0.6429
# step 6500: train loss 0.6433, val loss 0.6428
# step 6600: train loss 0.6431, val loss 0.6427
# step 6700: train loss 0.6428, val loss 0.6424
# step 6800: train loss 0.6429, val loss 0.6429
# step 6900: train loss 0.6426, val loss 0.6425
# step 7000: train loss 0.6427, val loss 0.6427
# step 7100: train loss 0.6427, val loss 0.6421
# step 7200: train loss 0.6427, val loss 0.6424
# step 7300: train loss 0.6424, val loss 0.6423
# step 7400: train loss 0.6424, val loss 0.6421
# step 7500: train loss 0.6426, val loss 0.6423
# step 7600: train loss 0.6425, val loss 0.6425
# step 7700: train loss 0.6429, val loss 0.6421
# step 7800: train loss 0.6423, val loss 0.6422
# step 7900: train loss 0.6426, val loss 0.6420
# step 8000: train loss 0.6426, val loss 0.6422
# step 8100: train loss 0.6424, val loss 0.6423
# step 8200: train loss 0.6425, val loss 0.6424
# step 8300: train loss 0.6423, val loss 0.6419
# step 8400: train loss 0.6421, val loss 0.6420
# step 8500: train loss 0.6424, val loss 0.6422
# step 8600: train loss 0.6426, val loss 0.6422
# step 8700: train loss 0.6425, val loss 0.6420
# step 8800: train loss 0.6426, val loss 0.6421
# step 8900: train loss 0.6424, val loss 0.6423
# step 9000: train loss 0.6423, val loss 0.6423
# step 9100: train loss 0.6424, val loss 0.6419
# step 9200: train loss 0.6427, val loss 0.6422
# step 9300: train loss 0.6425, val loss 0.6420
# step 9400: train loss 0.6429, val loss 0.6419
# step 9500: train loss 0.6426, val loss 0.6418
# step 9600: train loss 0.6425, val loss 0.6419
# step 9700: train loss 0.6425, val loss 0.6422
# step 9800: train loss 0.6429, val loss 0.6422
# step 9900: train loss 0.6429, val loss 0.6421
# step 9999: train loss 0.6424, val loss 0.6422
# Training model order=3 number=2
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.8199, 0.1801],
#         [0.6763, 0.3237],
#         [0.2683, 0.7317],
#         [0.4685, 0.5315],
#         [0.3292, 0.6708],
#         [0.7051, 0.2949],
#         [0.6873, 0.3127],
#         [0.0367, 0.9633]])
# step 0: train loss 0.7565, val loss 0.7564
# step 100: train loss 0.5133, val loss 0.5189
# step 200: train loss 0.4975, val loss 0.5004
# step 300: train loss 0.4590, val loss 0.4606
# step 400: train loss 0.4118, val loss 0.4142
# step 500: train loss 0.3888, val loss 0.3929
# step 600: train loss 0.3751, val loss 0.3814
# step 700: train loss 0.3698, val loss 0.3752
# step 800: train loss 0.3647, val loss 0.3704
# step 900: train loss 0.3618, val loss 0.3679
# step 1000: train loss 0.3617, val loss 0.3635
# step 1100: train loss 0.3578, val loss 0.3627
# step 1200: train loss 0.3564, val loss 0.3623
# step 1300: train loss 0.3572, val loss 0.3624
# step 1400: train loss 0.3546, val loss 0.3600
# step 1500: train loss 0.3525, val loss 0.3589
# step 1600: train loss 0.3585, val loss 0.3614
# step 1700: train loss 0.3515, val loss 0.3574
# step 1800: train loss 0.3515, val loss 0.3543
# step 1900: train loss 0.3501, val loss 0.3568
# step 2000: train loss 0.3516, val loss 0.3560
# step 2100: train loss 0.3509, val loss 0.3547
# step 2200: train loss 0.3522, val loss 0.3592
# step 2300: train loss 0.3510, val loss 0.3551
# step 2400: train loss 0.3490, val loss 0.3540
# step 2500: train loss 0.3513, val loss 0.3541
# step 2600: train loss 0.3487, val loss 0.3545
# step 2700: train loss 0.3502, val loss 0.3560
# step 2800: train loss 0.3478, val loss 0.3543
# step 2900: train loss 0.3504, val loss 0.3567
# step 3000: train loss 0.3488, val loss 0.3537
# step 3100: train loss 0.3502, val loss 0.3548
# step 3200: train loss 0.3484, val loss 0.3537
# step 3300: train loss 0.3488, val loss 0.3529
# step 3400: train loss 0.3481, val loss 0.3546
# step 3500: train loss 0.3470, val loss 0.3547
# step 3600: train loss 0.3491, val loss 0.3524
# step 3700: train loss 0.3477, val loss 0.3522
# step 3800: train loss 0.3479, val loss 0.3537
# step 3900: train loss 0.3471, val loss 0.3539
# step 4000: train loss 0.3469, val loss 0.3519
# step 4100: train loss 0.3476, val loss 0.3535
# step 4200: train loss 0.3490, val loss 0.3520
# step 4300: train loss 0.3483, val loss 0.3506
# step 4400: train loss 0.3494, val loss 0.3516
# step 4500: train loss 0.3512, val loss 0.3512
# step 4600: train loss 0.3477, val loss 0.3523
# step 4700: train loss 0.3487, val loss 0.3529
# step 4800: train loss 0.3479, val loss 0.3520
# step 4900: train loss 0.3481, val loss 0.3525
# step 5000: train loss 0.3487, val loss 0.3494
# step 5100: train loss 0.3479, val loss 0.3510
# step 5200: train loss 0.3479, val loss 0.3530
# step 5300: train loss 0.3484, val loss 0.3505
# step 5400: train loss 0.3472, val loss 0.3510
# step 5500: train loss 0.3461, val loss 0.3539
# step 5600: train loss 0.3480, val loss 0.3511
# step 5700: train loss 0.3458, val loss 0.3538
# step 5800: train loss 0.3459, val loss 0.3505
# step 5900: train loss 0.3465, val loss 0.3512
# step 6000: train loss 0.3456, val loss 0.3521
# step 6100: train loss 0.3458, val loss 0.3516
# step 6200: train loss 0.3451, val loss 0.3527
# step 6300: train loss 0.3492, val loss 0.3529
# step 6400: train loss 0.3463, val loss 0.3523
# step 6500: train loss 0.3459, val loss 0.3513
# step 6600: train loss 0.3481, val loss 0.3516
# step 6700: train loss 0.3463, val loss 0.3510
# step 6800: train loss 0.3454, val loss 0.3507
# step 6900: train loss 0.3480, val loss 0.3507
# step 7000: train loss 0.3470, val loss 0.3491
# step 7100: train loss 0.3474, val loss 0.3520
# step 7200: train loss 0.3464, val loss 0.3508
# step 7300: train loss 0.3459, val loss 0.3514
# step 7400: train loss 0.3471, val loss 0.3506
# step 7500: train loss 0.3475, val loss 0.3516
# step 7600: train loss 0.3461, val loss 0.3513
# step 7700: train loss 0.3471, val loss 0.3509
# step 7800: train loss 0.3460, val loss 0.3500
# step 7900: train loss 0.3463, val loss 0.3511
# step 8000: train loss 0.3455, val loss 0.3514
# step 8100: train loss 0.3463, val loss 0.3508
# step 8200: train loss 0.3467, val loss 0.3491
# step 8300: train loss 0.3462, val loss 0.3491
# step 8400: train loss 0.3450, val loss 0.3519
# step 8500: train loss 0.3443, val loss 0.3493
# step 8600: train loss 0.3461, val loss 0.3522
# step 8700: train loss 0.3487, val loss 0.3533
# step 8800: train loss 0.3469, val loss 0.3521
# step 8900: train loss 0.3467, val loss 0.3513
# step 9000: train loss 0.3458, val loss 0.3502
# step 9100: train loss 0.3453, val loss 0.3507
# step 9200: train loss 0.3460, val loss 0.3510
# step 9300: train loss 0.3461, val loss 0.3528
# step 9400: train loss 0.3455, val loss 0.3508
# step 9500: train loss 0.3482, val loss 0.3520
# step 9600: train loss 0.3474, val loss 0.3516
# step 9700: train loss 0.3450, val loss 0.3490
# step 9800: train loss 0.3446, val loss 0.3533
# step 9900: train loss 0.3461, val loss 0.3511
# step 9999: train loss 0.3472, val loss 0.3475
# Training model order=3 number=3
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.0962, 0.9038],
#         [0.4920, 0.5080],
#         [0.2621, 0.7379],
#         [0.0989, 0.9011],
#         [0.6381, 0.3619],
#         [0.7987, 0.2013],
#         [0.1757, 0.8243],
#         [0.6454, 0.3546]])
# step 0: train loss 0.7338, val loss 0.7340
# step 100: train loss 0.6401, val loss 0.6390
# step 200: train loss 0.6399, val loss 0.6385
# step 300: train loss 0.6399, val loss 0.6381
# step 400: train loss 0.6389, val loss 0.6377
# step 500: train loss 0.6393, val loss 0.6380
# step 600: train loss 0.6386, val loss 0.6373
# step 700: train loss 0.6376, val loss 0.6366
# step 800: train loss 0.6362, val loss 0.6346
# step 900: train loss 0.6349, val loss 0.6340
# step 1000: train loss 0.6330, val loss 0.6314
# step 1100: train loss 0.6313, val loss 0.6309
# step 1200: train loss 0.6287, val loss 0.6277
# step 1300: train loss 0.6239, val loss 0.6233
# step 1400: train loss 0.6190, val loss 0.6198
# step 1500: train loss 0.6159, val loss 0.6149
# step 1600: train loss 0.6119, val loss 0.6120
# step 1700: train loss 0.6091, val loss 0.6091
# step 1800: train loss 0.6048, val loss 0.6037
# step 1900: train loss 0.5967, val loss 0.5972
# step 2000: train loss 0.5888, val loss 0.5887
# step 2100: train loss 0.5798, val loss 0.5800
# step 2200: train loss 0.5710, val loss 0.5728
# step 2300: train loss 0.5645, val loss 0.5657
# step 2400: train loss 0.5614, val loss 0.5624
# step 2500: train loss 0.5589, val loss 0.5597
# step 2600: train loss 0.5562, val loss 0.5578
# step 2700: train loss 0.5539, val loss 0.5555
# step 2800: train loss 0.5518, val loss 0.5528
# step 2900: train loss 0.5504, val loss 0.5520
# step 3000: train loss 0.5490, val loss 0.5505
# step 3100: train loss 0.5476, val loss 0.5499
# step 3200: train loss 0.5461, val loss 0.5480
# step 3300: train loss 0.5458, val loss 0.5475
# step 3400: train loss 0.5440, val loss 0.5465
# step 3500: train loss 0.5434, val loss 0.5456
# step 3600: train loss 0.5428, val loss 0.5448
# step 3700: train loss 0.5416, val loss 0.5436
# step 3800: train loss 0.5419, val loss 0.5430
# step 3900: train loss 0.5410, val loss 0.5425
# step 4000: train loss 0.5402, val loss 0.5418
# step 4100: train loss 0.5407, val loss 0.5420
# step 4200: train loss 0.5403, val loss 0.5419
# step 4300: train loss 0.5401, val loss 0.5416
# step 4400: train loss 0.5402, val loss 0.5411
# step 4500: train loss 0.5387, val loss 0.5411
# step 4600: train loss 0.5388, val loss 0.5405
# step 4700: train loss 0.5389, val loss 0.5411
# step 4800: train loss 0.5392, val loss 0.5405
# step 4900: train loss 0.5392, val loss 0.5399
# step 5000: train loss 0.5389, val loss 0.5392
# step 5100: train loss 0.5386, val loss 0.5398
# step 5200: train loss 0.5380, val loss 0.5400
# step 5300: train loss 0.5380, val loss 0.5398
# step 5400: train loss 0.5379, val loss 0.5404
# step 5500: train loss 0.5380, val loss 0.5406
# step 5600: train loss 0.5378, val loss 0.5401
# step 5700: train loss 0.5381, val loss 0.5396
# step 5800: train loss 0.5384, val loss 0.5392
# step 5900: train loss 0.5373, val loss 0.5392
# step 6000: train loss 0.5376, val loss 0.5394
# step 6100: train loss 0.5376, val loss 0.5390
# step 6200: train loss 0.5370, val loss 0.5388
# step 6300: train loss 0.5369, val loss 0.5393
# step 6400: train loss 0.5369, val loss 0.5388
# step 6500: train loss 0.5375, val loss 0.5398
# step 6600: train loss 0.5378, val loss 0.5387
# step 6700: train loss 0.5370, val loss 0.5390
# step 6800: train loss 0.5371, val loss 0.5382
# step 6900: train loss 0.5371, val loss 0.5385
# step 7000: train loss 0.5371, val loss 0.5381
# step 7100: train loss 0.5367, val loss 0.5388
# step 7200: train loss 0.5368, val loss 0.5383
# step 7300: train loss 0.5369, val loss 0.5381
# step 7400: train loss 0.5366, val loss 0.5388
# step 7500: train loss 0.5370, val loss 0.5388
# step 7600: train loss 0.5365, val loss 0.5393
# step 7700: train loss 0.5366, val loss 0.5390
# step 7800: train loss 0.5365, val loss 0.5383
# step 7900: train loss 0.5366, val loss 0.5377
# step 8000: train loss 0.5368, val loss 0.5383
# step 8100: train loss 0.5365, val loss 0.5386
# step 8200: train loss 0.5363, val loss 0.5387
# step 8300: train loss 0.5368, val loss 0.5387
# step 8400: train loss 0.5357, val loss 0.5380
# step 8500: train loss 0.5364, val loss 0.5383
# step 8600: train loss 0.5366, val loss 0.5387
# step 8700: train loss 0.5368, val loss 0.5385
# step 8800: train loss 0.5368, val loss 0.5382
# step 8900: train loss 0.5365, val loss 0.5385
# step 9000: train loss 0.5368, val loss 0.5384
# step 9100: train loss 0.5363, val loss 0.5380
# step 9200: train loss 0.5371, val loss 0.5384
# step 9300: train loss 0.5365, val loss 0.5383
# step 9400: train loss 0.5362, val loss 0.5376
# step 9500: train loss 0.5363, val loss 0.5389
# step 9600: train loss 0.5368, val loss 0.5381
# step 9700: train loss 0.5362, val loss 0.5380
# step 9800: train loss 0.5367, val loss 0.5379
# step 9900: train loss 0.5375, val loss 0.5382
# step 9999: train loss 0.5369, val loss 0.5379
# Training model order=3 number=4
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.1204, 0.8796],
#         [0.3518, 0.6482],
#         [0.4729, 0.5271],
#         [0.8598, 0.1402],
#         [0.6380, 0.3620],
#         [0.1420, 0.8580],
#         [0.4747, 0.5253],
#         [0.3170, 0.6830]])
# step 0: train loss 0.7323, val loss 0.7325
# step 100: train loss 0.6907, val loss 0.6904
# step 200: train loss 0.6905, val loss 0.6902
# step 300: train loss 0.6904, val loss 0.6901
# step 400: train loss 0.6903, val loss 0.6899
# step 500: train loss 0.6900, val loss 0.6898
# step 600: train loss 0.6887, val loss 0.6886
# step 700: train loss 0.6845, val loss 0.6844
# step 800: train loss 0.6769, val loss 0.6767
# step 900: train loss 0.6677, val loss 0.6677
# step 1000: train loss 0.6517, val loss 0.6514
# step 1100: train loss 0.6379, val loss 0.6381
# step 1200: train loss 0.6254, val loss 0.6255
# step 1300: train loss 0.6147, val loss 0.6154
# step 1400: train loss 0.6064, val loss 0.6069
# step 1500: train loss 0.6005, val loss 0.6012
# step 1600: train loss 0.5973, val loss 0.5978
# step 1700: train loss 0.5944, val loss 0.5956
# step 1800: train loss 0.5915, val loss 0.5920
# step 1900: train loss 0.5885, val loss 0.5912
# step 2000: train loss 0.5889, val loss 0.5904
# step 2100: train loss 0.5882, val loss 0.5886
# step 2200: train loss 0.5860, val loss 0.5879
# step 2300: train loss 0.5860, val loss 0.5870
# step 2400: train loss 0.5841, val loss 0.5859
# step 2500: train loss 0.5836, val loss 0.5854
# step 2600: train loss 0.5828, val loss 0.5842
# step 2700: train loss 0.5818, val loss 0.5838
# step 2800: train loss 0.5814, val loss 0.5836
# step 2900: train loss 0.5813, val loss 0.5826
# step 3000: train loss 0.5798, val loss 0.5812
# step 3100: train loss 0.5787, val loss 0.5804
# step 3200: train loss 0.5778, val loss 0.5790
# step 3300: train loss 0.5774, val loss 0.5793
# step 3400: train loss 0.5766, val loss 0.5788
# step 3500: train loss 0.5764, val loss 0.5778
# step 3600: train loss 0.5763, val loss 0.5772
# step 3700: train loss 0.5747, val loss 0.5772
# step 3800: train loss 0.5756, val loss 0.5763
# step 3900: train loss 0.5742, val loss 0.5753
# step 4000: train loss 0.5732, val loss 0.5750
# step 4100: train loss 0.5733, val loss 0.5746
# step 4200: train loss 0.5723, val loss 0.5741
# step 4300: train loss 0.5721, val loss 0.5737
# step 4400: train loss 0.5725, val loss 0.5732
# step 4500: train loss 0.5712, val loss 0.5738
# step 4600: train loss 0.5716, val loss 0.5734
# step 4700: train loss 0.5716, val loss 0.5728
# step 4800: train loss 0.5712, val loss 0.5725
# step 4900: train loss 0.5709, val loss 0.5716
# step 5000: train loss 0.5713, val loss 0.5721
# step 5100: train loss 0.5704, val loss 0.5730
# step 5200: train loss 0.5706, val loss 0.5717
# step 5300: train loss 0.5704, val loss 0.5715
# step 5400: train loss 0.5702, val loss 0.5722
# step 5500: train loss 0.5707, val loss 0.5720
# step 5600: train loss 0.5705, val loss 0.5719
# step 5700: train loss 0.5696, val loss 0.5718
# step 5800: train loss 0.5697, val loss 0.5718
# step 5900: train loss 0.5696, val loss 0.5719
# step 6000: train loss 0.5698, val loss 0.5709
# step 6100: train loss 0.5702, val loss 0.5711
# step 6200: train loss 0.5693, val loss 0.5710
# step 6300: train loss 0.5693, val loss 0.5716
# step 6400: train loss 0.5695, val loss 0.5708
# step 6500: train loss 0.5700, val loss 0.5711
# step 6600: train loss 0.5689, val loss 0.5710
# step 6700: train loss 0.5688, val loss 0.5704
# step 6800: train loss 0.5689, val loss 0.5706
# step 6900: train loss 0.5689, val loss 0.5704
# step 7000: train loss 0.5686, val loss 0.5705
# step 7100: train loss 0.5688, val loss 0.5703
# step 7200: train loss 0.5688, val loss 0.5710
# step 7300: train loss 0.5684, val loss 0.5696
# step 7400: train loss 0.5676, val loss 0.5695
# step 7500: train loss 0.5683, val loss 0.5692
# step 7600: train loss 0.5681, val loss 0.5701
# step 7700: train loss 0.5680, val loss 0.5695
# step 7800: train loss 0.5685, val loss 0.5702
# step 7900: train loss 0.5680, val loss 0.5703
# step 8000: train loss 0.5680, val loss 0.5700
# step 8100: train loss 0.5684, val loss 0.5690
# step 8200: train loss 0.5675, val loss 0.5696
# step 8300: train loss 0.5676, val loss 0.5694
# step 8400: train loss 0.5681, val loss 0.5696
# step 8500: train loss 0.5687, val loss 0.5696
# step 8600: train loss 0.5676, val loss 0.5687
# step 8700: train loss 0.5679, val loss 0.5696
# step 8800: train loss 0.5677, val loss 0.5700
# step 8900: train loss 0.5681, val loss 0.5700
# step 9000: train loss 0.5676, val loss 0.5695
# step 9100: train loss 0.5677, val loss 0.5699
# step 9200: train loss 0.5680, val loss 0.5695
# step 9300: train loss 0.5676, val loss 0.5691
# step 9400: train loss 0.5680, val loss 0.5696
# step 9500: train loss 0.5678, val loss 0.5693
# step 9600: train loss 0.5679, val loss 0.5693
# step 9700: train loss 0.5678, val loss 0.5699
# step 9800: train loss 0.5676, val loss 0.5693
# step 9900: train loss 0.5678, val loss 0.5696
# step 9999: train loss 0.5678, val loss 0.5690
# Training model order=3 number=5
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.3055, 0.6945],
#         [0.0929, 0.9071],
#         [0.9396, 0.0604],
#         [0.7276, 0.2724],
#         [0.3704, 0.6296],
#         [0.8696, 0.1304],
#         [0.4368, 0.5632],
#         [0.8413, 0.1587]])
# step 0: train loss 0.7275, val loss 0.7275
# step 100: train loss 0.6904, val loss 0.6904
# step 200: train loss 0.6887, val loss 0.6886
# step 300: train loss 0.6819, val loss 0.6819
# step 400: train loss 0.6762, val loss 0.6770
# step 500: train loss 0.6596, val loss 0.6599
# step 600: train loss 0.6430, val loss 0.6435
# step 700: train loss 0.6166, val loss 0.6180
# step 800: train loss 0.5862, val loss 0.5880
# step 900: train loss 0.5605, val loss 0.5623
# step 1000: train loss 0.5448, val loss 0.5468
# step 1100: train loss 0.5401, val loss 0.5430
# step 1200: train loss 0.5308, val loss 0.5329
# step 1300: train loss 0.5262, val loss 0.5292
# step 1400: train loss 0.5176, val loss 0.5209
# step 1500: train loss 0.5157, val loss 0.5180
# step 1600: train loss 0.5150, val loss 0.5181
# step 1700: train loss 0.5145, val loss 0.5175
# step 1800: train loss 0.5140, val loss 0.5161
# step 1900: train loss 0.5122, val loss 0.5152
# step 2000: train loss 0.5126, val loss 0.5149
# step 2100: train loss 0.5120, val loss 0.5140
# step 2200: train loss 0.5115, val loss 0.5147
# step 2300: train loss 0.5106, val loss 0.5129
# step 2400: train loss 0.5122, val loss 0.5139
# step 2500: train loss 0.5126, val loss 0.5146
# step 2600: train loss 0.5102, val loss 0.5133
# step 2700: train loss 0.5101, val loss 0.5126
# step 2800: train loss 0.5104, val loss 0.5134
# step 2900: train loss 0.5110, val loss 0.5139
# step 3000: train loss 0.5109, val loss 0.5130
# step 3100: train loss 0.5104, val loss 0.5137
# step 3200: train loss 0.5106, val loss 0.5136
# step 3300: train loss 0.5099, val loss 0.5138
# step 3400: train loss 0.5105, val loss 0.5127
# step 3500: train loss 0.5106, val loss 0.5129
# step 3600: train loss 0.5103, val loss 0.5132
# step 3700: train loss 0.5103, val loss 0.5137
# step 3800: train loss 0.5098, val loss 0.5115
# step 3900: train loss 0.5161, val loss 0.5186
# step 4000: train loss 0.5109, val loss 0.5137
# step 4100: train loss 0.5104, val loss 0.5129
# step 4200: train loss 0.5105, val loss 0.5132
# step 4300: train loss 0.5099, val loss 0.5129
# step 4400: train loss 0.5100, val loss 0.5117
# step 4500: train loss 0.5097, val loss 0.5128
# step 4600: train loss 0.5098, val loss 0.5121
# step 4700: train loss 0.5099, val loss 0.5126
# step 4800: train loss 0.5103, val loss 0.5125
# step 4900: train loss 0.5102, val loss 0.5118
# step 5000: train loss 0.5098, val loss 0.5121
# step 5100: train loss 0.5100, val loss 0.5123
# step 5200: train loss 0.5099, val loss 0.5120
# step 5300: train loss 0.5092, val loss 0.5122
# step 5400: train loss 0.5099, val loss 0.5126
# step 5500: train loss 0.5095, val loss 0.5126
# step 5600: train loss 0.5093, val loss 0.5118
# step 5700: train loss 0.5092, val loss 0.5116
# step 5800: train loss 0.5090, val loss 0.5121
# step 5900: train loss 0.5093, val loss 0.5121
# step 6000: train loss 0.5097, val loss 0.5123
# step 6100: train loss 0.5094, val loss 0.5124
# step 6200: train loss 0.5088, val loss 0.5119
# step 6300: train loss 0.5090, val loss 0.5124
# step 6400: train loss 0.5090, val loss 0.5116
# step 6500: train loss 0.5096, val loss 0.5110
# step 6600: train loss 0.5088, val loss 0.5113
# step 6700: train loss 0.5090, val loss 0.5115
# step 6800: train loss 0.5092, val loss 0.5117
# step 6900: train loss 0.5093, val loss 0.5114
# step 7000: train loss 0.5096, val loss 0.5115
# step 7100: train loss 0.5085, val loss 0.5119
# step 7200: train loss 0.5093, val loss 0.5115
# step 7300: train loss 0.5084, val loss 0.5113
# step 7400: train loss 0.5085, val loss 0.5120
# step 7500: train loss 0.5090, val loss 0.5116
# step 7600: train loss 0.5090, val loss 0.5117
# step 7700: train loss 0.5086, val loss 0.5112
# step 7800: train loss 0.5091, val loss 0.5114
# step 7900: train loss 0.5087, val loss 0.5119
# step 8000: train loss 0.5089, val loss 0.5116
# step 8100: train loss 0.5093, val loss 0.5116
# step 8200: train loss 0.5092, val loss 0.5114
# step 8300: train loss 0.5095, val loss 0.5114
# step 8400: train loss 0.5089, val loss 0.5119
# step 8500: train loss 0.5083, val loss 0.5118
# step 8600: train loss 0.5084, val loss 0.5120
# step 8700: train loss 0.5089, val loss 0.5116
# step 8800: train loss 0.5085, val loss 0.5111
# step 8900: train loss 0.5085, val loss 0.5116
# step 9000: train loss 0.5095, val loss 0.5113
# step 9100: train loss 0.5087, val loss 0.5111
# step 9200: train loss 0.5087, val loss 0.5114
# step 9300: train loss 0.5088, val loss 0.5111
# step 9400: train loss 0.5087, val loss 0.5109
# step 9500: train loss 0.5098, val loss 0.5118
# step 9600: train loss 0.5094, val loss 0.5112
# step 9700: train loss 0.5088, val loss 0.5112
# step 9800: train loss 0.5086, val loss 0.5117
# step 9900: train loss 0.5095, val loss 0.5118
# step 9999: train loss 0.5086, val loss 0.5116

# %%
base_path = Path("models")
base_path.mkdir(exist_ok=True)
# convert and save
serializable_models = tensor_to_serializable(my_models)
filename = f"my_models_saved.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(serializable_models, f, indent=2)

print(f"Saved models to {filepath}")
# Out:
# Saved models to models2/my_models_saved2.json

# %% [markdown]
# Order 4:

# %%
n_head = 1
n_layer = 3
n_embd = 64
sequence_length = 2000
num_sequences = 1000
num_iterations = 10000
seeds = [102, 103, 104, 105, 106]
idx = 0
for number in range(1, 6): # 5 models per order
    try:
        print(f"Training model order=4 number={number}")
        model_info = train_model(4, number, num_iterations, seeds[idx], sequence_length, num_sequences)
        my_models.append(model_info)
        idx += 1
        
        if device.type == "mps":
            torch.mps.empty_cache() # cleanup
            
    except Exception as e:
        print(f"Failed training model number={number}: {e}")
        continue
# Out:
# Training model order=4 number=1
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.0083, 0.9917],
#         [0.1100, 0.8900],
#         [0.5988, 0.4012],
#         [0.1800, 0.8200],
#         [0.5873, 0.4127],
#         [0.2977, 0.7023],
#         [0.4502, 0.5498],
#         [0.8272, 0.1728],
#         [0.9822, 0.0178],
#         [0.7752, 0.2248],
#         [0.4257, 0.5743],
#         [0.8044, 0.1956],
#         [0.7702, 0.2298],
#         [0.5113, 0.4887],
#         [0.7706, 0.2294],
#         [0.9386, 0.0614]])
# step 0: train loss 0.7542, val loss 0.7536
# step 100: train loss 0.6822, val loss 0.6822
# step 200: train loss 0.6776, val loss 0.6775
# step 300: train loss 0.6702, val loss 0.6707
# step 400: train loss 0.6567, val loss 0.6572
# step 500: train loss 0.6356, val loss 0.6354
# step 600: train loss 0.6052, val loss 0.6054
# step 700: train loss 0.5736, val loss 0.5743
# step 800: train loss 0.5432, val loss 0.5443
# step 900: train loss 0.5260, val loss 0.5248
# step 1000: train loss 0.5049, val loss 0.5045
# step 1100: train loss 0.4891, val loss 0.4881
# step 1200: train loss 0.4811, val loss 0.4807
# step 1300: train loss 0.4714, val loss 0.4717
# step 1400: train loss 0.4654, val loss 0.4660
# step 1500: train loss 0.4628, val loss 0.4635
# step 1600: train loss 0.4619, val loss 0.4638
# step 1700: train loss 0.4578, val loss 0.4583
# step 1800: train loss 0.4598, val loss 0.4605
# step 1900: train loss 0.4568, val loss 0.4573
# step 2000: train loss 0.4562, val loss 0.4568
# step 2100: train loss 0.4548, val loss 0.4563
# step 2200: train loss 0.4552, val loss 0.4562
# step 2300: train loss 0.4533, val loss 0.4542
# step 2400: train loss 0.4548, val loss 0.4556
# step 2500: train loss 0.4554, val loss 0.4568
# step 2600: train loss 0.4541, val loss 0.4547
# step 2700: train loss 0.4525, val loss 0.4538
# step 2800: train loss 0.4520, val loss 0.4528
# step 2900: train loss 0.4518, val loss 0.4530
# step 3000: train loss 0.4522, val loss 0.4528
# step 3100: train loss 0.4511, val loss 0.4533
# step 3200: train loss 0.4515, val loss 0.4531
# step 3300: train loss 0.4510, val loss 0.4518
# step 3400: train loss 0.4513, val loss 0.4525
# step 3500: train loss 0.4513, val loss 0.4530
# step 3600: train loss 0.4515, val loss 0.4537
# step 3700: train loss 0.4504, val loss 0.4526
# step 3800: train loss 0.4518, val loss 0.4523
# step 3900: train loss 0.4512, val loss 0.4524
# step 4000: train loss 0.4515, val loss 0.4519
# step 4100: train loss 0.4599, val loss 0.4607
# step 4200: train loss 0.4509, val loss 0.4503
# step 4300: train loss 0.4505, val loss 0.4514
# step 4400: train loss 0.4507, val loss 0.4517
# step 4500: train loss 0.4500, val loss 0.4512
# step 4600: train loss 0.4503, val loss 0.4511
# step 4700: train loss 0.4499, val loss 0.4516
# step 4800: train loss 0.4500, val loss 0.4503
# step 4900: train loss 0.4500, val loss 0.4519
# step 5000: train loss 0.4502, val loss 0.4516
# step 5100: train loss 0.4497, val loss 0.4511
# step 5200: train loss 0.4501, val loss 0.4509
# step 5300: train loss 0.4497, val loss 0.4510
# step 5400: train loss 0.4506, val loss 0.4508
# step 5500: train loss 0.4507, val loss 0.4513
# step 5600: train loss 0.4501, val loss 0.4508
# step 5700: train loss 0.4496, val loss 0.4517
# step 5800: train loss 0.4497, val loss 0.4506
# step 5900: train loss 0.4505, val loss 0.4518
# step 6000: train loss 0.4497, val loss 0.4507
# step 6100: train loss 0.4500, val loss 0.4505
# step 6200: train loss 0.4502, val loss 0.4505
# step 6300: train loss 0.4493, val loss 0.4503
# step 6400: train loss 0.4484, val loss 0.4497
# step 6500: train loss 0.4503, val loss 0.4510
# step 6600: train loss 0.4499, val loss 0.4501
# step 6700: train loss 0.4498, val loss 0.4506
# step 6800: train loss 0.4485, val loss 0.4507
# step 6900: train loss 0.4488, val loss 0.4509
# step 7000: train loss 0.4497, val loss 0.4499
# step 7100: train loss 0.4494, val loss 0.4505
# step 7200: train loss 0.4492, val loss 0.4504
# step 7300: train loss 0.4495, val loss 0.4505
# step 7400: train loss 0.4488, val loss 0.4510
# step 7500: train loss 0.4491, val loss 0.4502
# step 7600: train loss 0.4492, val loss 0.4502
# step 7700: train loss 0.4497, val loss 0.4506
# step 7800: train loss 0.4490, val loss 0.4499
# step 7900: train loss 0.4489, val loss 0.4501
# step 8000: train loss 0.4494, val loss 0.4503
# step 8100: train loss 0.4483, val loss 0.4504
# step 8200: train loss 0.4491, val loss 0.4503
# step 8300: train loss 0.4497, val loss 0.4500
# step 8400: train loss 0.4492, val loss 0.4500
# step 8500: train loss 0.4491, val loss 0.4499
# step 8600: train loss 0.4488, val loss 0.4502
# step 8700: train loss 0.4494, val loss 0.4500
# step 8800: train loss 0.4491, val loss 0.4498
# step 8900: train loss 0.4490, val loss 0.4503
# step 9000: train loss 0.4488, val loss 0.4500
# step 9100: train loss 0.4498, val loss 0.4505
# step 9200: train loss 0.4493, val loss 0.4498
# step 9300: train loss 0.4485, val loss 0.4499
# step 9400: train loss 0.4492, val loss 0.4505
# step 9500: train loss 0.4493, val loss 0.4497
# step 9600: train loss 0.4478, val loss 0.4504
# step 9700: train loss 0.4490, val loss 0.4492
# step 9800: train loss 0.4492, val loss 0.4503
# step 9900: train loss 0.4494, val loss 0.4503
# step 9999: train loss 0.4493, val loss 0.4505
# Training model order=4 number=2
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.6541, 0.3459],
#         [0.7278, 0.2722],
#         [0.4887, 0.5113],
#         [0.8412, 0.1588],
#         [0.7104, 0.2896],
#         [0.4547, 0.5453],
#         [0.4210, 0.5790],
#         [0.6799, 0.3201],
#         [0.3945, 0.6055],
#         [0.4432, 0.5568],
#         [0.2513, 0.7487],
#         [0.5968, 0.4032],
#         [0.5027, 0.4973],
#         [0.9396, 0.0604],
#         [0.2054, 0.7946],
#         [0.3097, 0.6903]])
# step 0: train loss 0.7655, val loss 0.7655
# step 100: train loss 0.6764, val loss 0.6762
# step 200: train loss 0.6763, val loss 0.6758
# step 300: train loss 0.6757, val loss 0.6757
# step 400: train loss 0.6754, val loss 0.6758
# step 500: train loss 0.6746, val loss 0.6743
# step 600: train loss 0.6740, val loss 0.6742
# step 700: train loss 0.6735, val loss 0.6733
# step 800: train loss 0.6720, val loss 0.6722
# step 900: train loss 0.6720, val loss 0.6719
# step 1000: train loss 0.6688, val loss 0.6688
# step 1100: train loss 0.6660, val loss 0.6661
# step 1200: train loss 0.6616, val loss 0.6625
# step 1300: train loss 0.6581, val loss 0.6587
# step 1400: train loss 0.6531, val loss 0.6542
# step 1500: train loss 0.6505, val loss 0.6511
# step 1600: train loss 0.6460, val loss 0.6467
# step 1700: train loss 0.6426, val loss 0.6441
# step 1800: train loss 0.6414, val loss 0.6426
# step 1900: train loss 0.6415, val loss 0.6428
# step 2000: train loss 0.6361, val loss 0.6380
# step 2100: train loss 0.6349, val loss 0.6362
# step 2200: train loss 0.6333, val loss 0.6344
# step 2300: train loss 0.6339, val loss 0.6353
# step 2400: train loss 0.6314, val loss 0.6333
# step 2500: train loss 0.6302, val loss 0.6318
# step 2600: train loss 0.6307, val loss 0.6322
# step 2700: train loss 0.6269, val loss 0.6283
# step 2800: train loss 0.6263, val loss 0.6277
# step 2900: train loss 0.6244, val loss 0.6257
# step 3000: train loss 0.6236, val loss 0.6251
# step 3100: train loss 0.6222, val loss 0.6232
# step 3200: train loss 0.6216, val loss 0.6231
# step 3300: train loss 0.6181, val loss 0.6199
# step 3400: train loss 0.6200, val loss 0.6209
# step 3500: train loss 0.6177, val loss 0.6189
# step 3600: train loss 0.6171, val loss 0.6183
# step 3700: train loss 0.6126, val loss 0.6141
# step 3800: train loss 0.6153, val loss 0.6168
# step 3900: train loss 0.6105, val loss 0.6125
# step 4000: train loss 0.6113, val loss 0.6130
# step 4100: train loss 0.6125, val loss 0.6138
# step 4200: train loss 0.6092, val loss 0.6104
# step 4300: train loss 0.6085, val loss 0.6102
# step 4400: train loss 0.6088, val loss 0.6104
# step 4500: train loss 0.6079, val loss 0.6095
# step 4600: train loss 0.6089, val loss 0.6095
# step 4700: train loss 0.6084, val loss 0.6095
# step 4800: train loss 0.6082, val loss 0.6079
# step 4900: train loss 0.6070, val loss 0.6089
# step 5000: train loss 0.6080, val loss 0.6092
# step 5100: train loss 0.6068, val loss 0.6081
# step 5200: train loss 0.6069, val loss 0.6079
# step 5300: train loss 0.6082, val loss 0.6086
# step 5400: train loss 0.6062, val loss 0.6072
# step 5500: train loss 0.6064, val loss 0.6071
# step 5600: train loss 0.6060, val loss 0.6075
# step 5700: train loss 0.6067, val loss 0.6075
# step 5800: train loss 0.6062, val loss 0.6074
# step 5900: train loss 0.6062, val loss 0.6071
# step 6000: train loss 0.6058, val loss 0.6067
# step 6100: train loss 0.6063, val loss 0.6074
# step 6200: train loss 0.6065, val loss 0.6071
# step 6300: train loss 0.6062, val loss 0.6069
# step 6400: train loss 0.6055, val loss 0.6064
# step 6500: train loss 0.6054, val loss 0.6060
# step 6600: train loss 0.6052, val loss 0.6071
# step 6700: train loss 0.6054, val loss 0.6064
# step 6800: train loss 0.6055, val loss 0.6062
# step 6900: train loss 0.6053, val loss 0.6066
# step 7000: train loss 0.6048, val loss 0.6063
# step 7100: train loss 0.6047, val loss 0.6063
# step 7200: train loss 0.6053, val loss 0.6067
# step 7300: train loss 0.6051, val loss 0.6061
# step 7400: train loss 0.6047, val loss 0.6058
# step 7500: train loss 0.6051, val loss 0.6068
# step 7600: train loss 0.6049, val loss 0.6061
# step 7700: train loss 0.6044, val loss 0.6057
# step 7800: train loss 0.6048, val loss 0.6054
# step 7900: train loss 0.6046, val loss 0.6055
# step 8000: train loss 0.6049, val loss 0.6057
# step 8100: train loss 0.6048, val loss 0.6054
# step 8200: train loss 0.6049, val loss 0.6054
# step 8300: train loss 0.6040, val loss 0.6053
# step 8400: train loss 0.6044, val loss 0.6057
# step 8500: train loss 0.6041, val loss 0.6054
# step 8600: train loss 0.6051, val loss 0.6056
# step 8700: train loss 0.6042, val loss 0.6056
# step 8800: train loss 0.6046, val loss 0.6053
# step 8900: train loss 0.6043, val loss 0.6054
# step 9000: train loss 0.6041, val loss 0.6052
# step 9100: train loss 0.6042, val loss 0.6051
# step 9200: train loss 0.6045, val loss 0.6050
# step 9300: train loss 0.6046, val loss 0.6053
# step 9400: train loss 0.6042, val loss 0.6051
# step 9500: train loss 0.6041, val loss 0.6051
# step 9600: train loss 0.6039, val loss 0.6052
# step 9700: train loss 0.6048, val loss 0.6054
# step 9800: train loss 0.6044, val loss 0.6054
# step 9900: train loss 0.6044, val loss 0.6053
# step 9999: train loss 0.6044, val loss 0.6052
# Training model order=4 number=3
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.5107, 0.4893],
#         [0.5503, 0.4497],
#         [0.4312, 0.5688],
#         [0.8776, 0.1224],
#         [0.4187, 0.5813],
#         [0.4428, 0.5572],
#         [0.6448, 0.3552],
#         [0.7628, 0.2372],
#         [0.5971, 0.4029],
#         [0.7893, 0.2107],
#         [0.5464, 0.4536],
#         [0.5655, 0.4345],
#         [0.1147, 0.8853],
#         [0.5995, 0.4005],
#         [0.7318, 0.2682],
#         [0.7349, 0.2651]])
# step 0: train loss 0.7731, val loss 0.7728
# step 100: train loss 0.6725, val loss 0.6724
# step 200: train loss 0.6725, val loss 0.6723
# step 300: train loss 0.6726, val loss 0.6726
# step 400: train loss 0.6725, val loss 0.6728
# step 500: train loss 0.6720, val loss 0.6720
# step 600: train loss 0.6721, val loss 0.6719
# step 700: train loss 0.6722, val loss 0.6720
# step 800: train loss 0.6720, val loss 0.6720
# step 900: train loss 0.6723, val loss 0.6722
# step 1000: train loss 0.6716, val loss 0.6714
# step 1100: train loss 0.6716, val loss 0.6715
# step 1200: train loss 0.6719, val loss 0.6714
# step 1300: train loss 0.6721, val loss 0.6716
# step 1400: train loss 0.6712, val loss 0.6712
# step 1500: train loss 0.6709, val loss 0.6709
# step 1600: train loss 0.6711, val loss 0.6709
# step 1700: train loss 0.6704, val loss 0.6703
# step 1800: train loss 0.6703, val loss 0.6702
# step 1900: train loss 0.6699, val loss 0.6695
# step 2000: train loss 0.6693, val loss 0.6693
# step 2100: train loss 0.6691, val loss 0.6692
# step 2200: train loss 0.6687, val loss 0.6684
# step 2300: train loss 0.6684, val loss 0.6682
# step 2400: train loss 0.6678, val loss 0.6675
# step 2500: train loss 0.6679, val loss 0.6677
# step 2600: train loss 0.6676, val loss 0.6677
# step 2700: train loss 0.6671, val loss 0.6672
# step 2800: train loss 0.6670, val loss 0.6666
# step 2900: train loss 0.6660, val loss 0.6658
# step 3000: train loss 0.6657, val loss 0.6656
# step 3100: train loss 0.6652, val loss 0.6649
# step 3200: train loss 0.6641, val loss 0.6641
# step 3300: train loss 0.6636, val loss 0.6636
# step 3400: train loss 0.6624, val loss 0.6623
# step 3500: train loss 0.6619, val loss 0.6620
# step 3600: train loss 0.6611, val loss 0.6610
# step 3700: train loss 0.6607, val loss 0.6606
# step 3800: train loss 0.6598, val loss 0.6597
# step 3900: train loss 0.6594, val loss 0.6592
# step 4000: train loss 0.6589, val loss 0.6588
# step 4100: train loss 0.6584, val loss 0.6586
# step 4200: train loss 0.6575, val loss 0.6575
# step 4300: train loss 0.6567, val loss 0.6571
# step 4400: train loss 0.6562, val loss 0.6562
# step 4500: train loss 0.6556, val loss 0.6557
# step 4600: train loss 0.6550, val loss 0.6550
# step 4700: train loss 0.6542, val loss 0.6547
# step 4800: train loss 0.6541, val loss 0.6542
# step 4900: train loss 0.6536, val loss 0.6536
# step 5000: train loss 0.6533, val loss 0.6534
# step 5100: train loss 0.6526, val loss 0.6525
# step 5200: train loss 0.6525, val loss 0.6525
# step 5300: train loss 0.6525, val loss 0.6526
# step 5400: train loss 0.6520, val loss 0.6520
# step 5500: train loss 0.6519, val loss 0.6519
# step 5600: train loss 0.6519, val loss 0.6515
# step 5700: train loss 0.6511, val loss 0.6512
# step 5800: train loss 0.6512, val loss 0.6508
# step 5900: train loss 0.6506, val loss 0.6508
# step 6000: train loss 0.6506, val loss 0.6508
# step 6100: train loss 0.6505, val loss 0.6504
# step 6200: train loss 0.6504, val loss 0.6506
# step 6300: train loss 0.6504, val loss 0.6504
# step 6400: train loss 0.6498, val loss 0.6500
# step 6500: train loss 0.6498, val loss 0.6497
# step 6600: train loss 0.6498, val loss 0.6497
# step 6700: train loss 0.6497, val loss 0.6497
# step 6800: train loss 0.6497, val loss 0.6493
# step 6900: train loss 0.6492, val loss 0.6494
# step 7000: train loss 0.6490, val loss 0.6488
# step 7100: train loss 0.6490, val loss 0.6491
# step 7200: train loss 0.6487, val loss 0.6487
# step 7300: train loss 0.6491, val loss 0.6488
# step 7400: train loss 0.6484, val loss 0.6485
# step 7500: train loss 0.6483, val loss 0.6484
# step 7600: train loss 0.6485, val loss 0.6485
# step 7700: train loss 0.6484, val loss 0.6489
# step 7800: train loss 0.6486, val loss 0.6486
# step 7900: train loss 0.6481, val loss 0.6483
# step 8000: train loss 0.6482, val loss 0.6481
# step 8100: train loss 0.6482, val loss 0.6480
# step 8200: train loss 0.6482, val loss 0.6480
# step 8300: train loss 0.6481, val loss 0.6480
# step 8400: train loss 0.6478, val loss 0.6482
# step 8500: train loss 0.6478, val loss 0.6482
# step 8600: train loss 0.6480, val loss 0.6482
# step 8700: train loss 0.6476, val loss 0.6479
# step 8800: train loss 0.6476, val loss 0.6479
# step 8900: train loss 0.6479, val loss 0.6475
# step 9000: train loss 0.6480, val loss 0.6479
# step 9100: train loss 0.6478, val loss 0.6483
# step 9200: train loss 0.6476, val loss 0.6484
# step 9300: train loss 0.6479, val loss 0.6477
# step 9400: train loss 0.6479, val loss 0.6480
# step 9500: train loss 0.6478, val loss 0.6476
# step 9600: train loss 0.6481, val loss 0.6479
# step 9700: train loss 0.6482, val loss 0.6479
# step 9800: train loss 0.6479, val loss 0.6477
# step 9900: train loss 0.6479, val loss 0.6478
# step 9999: train loss 0.6477, val loss 0.6477
# Training model order=4 number=4
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.9241, 0.0759],
#         [0.3639, 0.6361],
#         [0.7782, 0.2218],
#         [0.0994, 0.9006],
#         [0.9152, 0.0848],
#         [0.4389, 0.5611],
#         [0.5935, 0.4065],
#         [0.4462, 0.5538],
#         [0.3397, 0.6603],
#         [0.4149, 0.5851],
#         [0.4445, 0.5555],
#         [0.8140, 0.1860],
#         [0.4119, 0.5881],
#         [0.9181, 0.0819],
#         [0.6800, 0.3200],
#         [0.4700, 0.5300]])
# step 0: train loss 0.7951, val loss 0.7945
# step 100: train loss 0.6097, val loss 0.6136
# step 200: train loss 0.6053, val loss 0.6089
# step 300: train loss 0.6010, val loss 0.6043
# step 400: train loss 0.5888, val loss 0.5939
# step 500: train loss 0.5775, val loss 0.5801
# step 600: train loss 0.5648, val loss 0.5699
# step 700: train loss 0.5537, val loss 0.5583
# step 800: train loss 0.5448, val loss 0.5497
# step 900: train loss 0.5359, val loss 0.5409
# step 1000: train loss 0.5307, val loss 0.5361
# step 1100: train loss 0.5265, val loss 0.5320
# step 1200: train loss 0.5256, val loss 0.5306
# step 1300: train loss 0.5209, val loss 0.5263
# step 1400: train loss 0.5188, val loss 0.5237
# step 1500: train loss 0.5138, val loss 0.5197
# step 1600: train loss 0.5131, val loss 0.5169
# step 1700: train loss 0.5078, val loss 0.5139
# step 1800: train loss 0.5099, val loss 0.5123
# step 1900: train loss 0.5052, val loss 0.5100
# step 2000: train loss 0.5041, val loss 0.5082
# step 2100: train loss 0.5049, val loss 0.5127
# step 2200: train loss 0.5035, val loss 0.5086
# step 2300: train loss 0.5034, val loss 0.5084
# step 2400: train loss 0.5026, val loss 0.5068
# step 2500: train loss 0.5008, val loss 0.5054
# step 2600: train loss 0.5000, val loss 0.5050
# step 2700: train loss 0.4997, val loss 0.5054
# step 2800: train loss 0.4990, val loss 0.5052
# step 2900: train loss 0.4985, val loss 0.5043
# step 3000: train loss 0.4985, val loss 0.5032
# step 3100: train loss 0.4966, val loss 0.5027
# step 3200: train loss 0.4966, val loss 0.5009
# step 3300: train loss 0.4975, val loss 0.5013
# step 3400: train loss 0.4956, val loss 0.5011
# step 3500: train loss 0.4944, val loss 0.4999
# step 3600: train loss 0.4967, val loss 0.5019
# step 3700: train loss 0.4990, val loss 0.5036
# step 3800: train loss 0.4955, val loss 0.5006
# step 3900: train loss 0.4950, val loss 0.5008
# step 4000: train loss 0.4963, val loss 0.5007
# step 4100: train loss 0.4947, val loss 0.5002
# step 4200: train loss 0.4932, val loss 0.4980
# step 4300: train loss 0.4935, val loss 0.4988
# step 4400: train loss 0.4928, val loss 0.4975
# step 4500: train loss 0.4942, val loss 0.5000
# step 4600: train loss 0.4929, val loss 0.4991
# step 4700: train loss 0.4925, val loss 0.4986
# step 4800: train loss 0.4927, val loss 0.4991
# step 4900: train loss 0.4935, val loss 0.4980
# step 5000: train loss 0.4931, val loss 0.4994
# step 5100: train loss 0.4918, val loss 0.4983
# step 5200: train loss 0.4914, val loss 0.4972
# step 5300: train loss 0.4922, val loss 0.4974
# step 5400: train loss 0.4924, val loss 0.4966
# step 5500: train loss 0.4921, val loss 0.4981
# step 5600: train loss 0.4932, val loss 0.4976
# step 5700: train loss 0.4932, val loss 0.4958
# step 5800: train loss 0.4915, val loss 0.4966
# step 5900: train loss 0.4918, val loss 0.4980
# step 6000: train loss 0.4918, val loss 0.4964
# step 6100: train loss 0.4929, val loss 0.4970
# step 6200: train loss 0.4923, val loss 0.4955
# step 6300: train loss 0.4888, val loss 0.4969
# step 6400: train loss 0.4906, val loss 0.4960
# step 6500: train loss 0.4909, val loss 0.4971
# step 6600: train loss 0.4907, val loss 0.4971
# step 6700: train loss 0.4924, val loss 0.4965
# step 6800: train loss 0.4907, val loss 0.4963
# step 6900: train loss 0.4912, val loss 0.4962
# step 7000: train loss 0.4895, val loss 0.4964
# step 7100: train loss 0.4884, val loss 0.4975
# step 7200: train loss 0.4904, val loss 0.4953
# step 7300: train loss 0.4893, val loss 0.4960
# step 7400: train loss 0.4920, val loss 0.4969
# step 7500: train loss 0.4907, val loss 0.4957
# step 7600: train loss 0.4904, val loss 0.4960
# step 7700: train loss 0.4906, val loss 0.4961
# step 7800: train loss 0.4904, val loss 0.4957
# step 7900: train loss 0.4918, val loss 0.4963
# step 8000: train loss 0.4904, val loss 0.4969
# step 8100: train loss 0.4906, val loss 0.4966
# step 8200: train loss 0.4913, val loss 0.4958
# step 8300: train loss 0.4901, val loss 0.4947
# step 8400: train loss 0.4909, val loss 0.4959
# step 8500: train loss 0.4917, val loss 0.4949
# step 8600: train loss 0.4903, val loss 0.4965
# step 8700: train loss 0.4898, val loss 0.4964
# step 8800: train loss 0.4899, val loss 0.4946
# step 8900: train loss 0.4906, val loss 0.4939
# step 9000: train loss 0.4910, val loss 0.4963
# step 9100: train loss 0.4914, val loss 0.4955
# step 9200: train loss 0.4903, val loss 0.4965
# step 9300: train loss 0.4902, val loss 0.4966
# step 9400: train loss 0.4896, val loss 0.4952
# step 9500: train loss 0.4894, val loss 0.4954
# step 9600: train loss 0.4895, val loss 0.4964
# step 9700: train loss 0.4902, val loss 0.4955
# step 9800: train loss 0.4899, val loss 0.4954
# step 9900: train loss 0.4912, val loss 0.4953
# step 9999: train loss 0.4897, val loss 0.4961
# Training model order=4 number=5
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.1923, 0.8077],
#         [0.2465, 0.7535],
#         [0.0986, 0.9014],
#         [0.2156, 0.7844],
#         [0.2740, 0.7260],
#         [0.3972, 0.6028],
#         [0.5715, 0.4285],
#         [0.3560, 0.6440],
#         [0.9351, 0.0649],
#         [0.0759, 0.9241],
#         [0.3381, 0.6619],
#         [0.2416, 0.7584],
#         [0.6099, 0.3901],
#         [0.5657, 0.4343],
#         [0.7782, 0.2218],
#         [0.5982, 0.4018]])
# step 0: train loss 0.7347, val loss 0.7351
# step 100: train loss 0.6642, val loss 0.6643
# step 200: train loss 0.6623, val loss 0.6626
# step 300: train loss 0.6608, val loss 0.6604
# step 400: train loss 0.6589, val loss 0.6585
# step 500: train loss 0.6559, val loss 0.6559
# step 600: train loss 0.6521, val loss 0.6517
# step 700: train loss 0.6427, val loss 0.6424
# step 800: train loss 0.6342, val loss 0.6339
# step 900: train loss 0.6235, val loss 0.6227
# step 1000: train loss 0.6160, val loss 0.6152
# step 1100: train loss 0.6090, val loss 0.6080
# step 1200: train loss 0.6064, val loss 0.6059
# step 1300: train loss 0.6016, val loss 0.6015
# step 1400: train loss 0.6013, val loss 0.6001
# step 1500: train loss 0.5952, val loss 0.5944
# step 1600: train loss 0.5920, val loss 0.5914
# step 1700: train loss 0.5830, val loss 0.5826
# step 1800: train loss 0.5789, val loss 0.5785
# step 1900: train loss 0.5757, val loss 0.5745
# step 2000: train loss 0.5744, val loss 0.5744
# step 2100: train loss 0.5721, val loss 0.5716
# step 2200: train loss 0.5706, val loss 0.5704
# step 2300: train loss 0.5697, val loss 0.5696
# step 2400: train loss 0.5679, val loss 0.5679
# step 2500: train loss 0.5665, val loss 0.5661
# step 2600: train loss 0.5658, val loss 0.5657
# step 2700: train loss 0.5641, val loss 0.5639
# step 2800: train loss 0.5646, val loss 0.5651
# step 2900: train loss 0.5625, val loss 0.5634
# step 3000: train loss 0.5631, val loss 0.5637
# step 3100: train loss 0.5648, val loss 0.5657
# step 3200: train loss 0.5631, val loss 0.5626
# step 3300: train loss 0.5625, val loss 0.5625
# step 3400: train loss 0.5617, val loss 0.5614
# step 3500: train loss 0.5620, val loss 0.5629
# step 3600: train loss 0.5617, val loss 0.5621
# step 3700: train loss 0.5613, val loss 0.5609
# step 3800: train loss 0.5608, val loss 0.5622
# step 3900: train loss 0.5607, val loss 0.5611
# step 4000: train loss 0.5623, val loss 0.5611
# step 4100: train loss 0.5612, val loss 0.5615
# step 4200: train loss 0.5611, val loss 0.5609
# step 4300: train loss 0.5602, val loss 0.5611
# step 4400: train loss 0.5607, val loss 0.5610
# step 4500: train loss 0.5610, val loss 0.5613
# step 4600: train loss 0.5607, val loss 0.5610
# step 4700: train loss 0.5597, val loss 0.5606
# step 4800: train loss 0.5603, val loss 0.5607
# step 4900: train loss 0.5613, val loss 0.5620
# step 5000: train loss 0.5605, val loss 0.5598
# step 5100: train loss 0.5603, val loss 0.5615
# step 5200: train loss 0.5600, val loss 0.5609
# step 5300: train loss 0.5600, val loss 0.5607
# step 5400: train loss 0.5606, val loss 0.5598
# step 5500: train loss 0.5606, val loss 0.5603
# step 5600: train loss 0.5601, val loss 0.5596
# step 5700: train loss 0.5597, val loss 0.5602
# step 5800: train loss 0.5595, val loss 0.5595
# step 5900: train loss 0.5584, val loss 0.5601
# step 6000: train loss 0.5597, val loss 0.5599
# step 6100: train loss 0.5598, val loss 0.5602
# step 6200: train loss 0.5592, val loss 0.5594
# step 6300: train loss 0.5590, val loss 0.5600
# step 6400: train loss 0.5591, val loss 0.5590
# step 6500: train loss 0.5597, val loss 0.5599
# step 6600: train loss 0.5600, val loss 0.5588
# step 6700: train loss 0.5588, val loss 0.5593
# step 6800: train loss 0.5592, val loss 0.5595
# step 6900: train loss 0.5589, val loss 0.5594
# step 7000: train loss 0.5592, val loss 0.5586
# step 7100: train loss 0.5582, val loss 0.5591
# step 7200: train loss 0.5587, val loss 0.5589
# step 7300: train loss 0.5591, val loss 0.5598
# step 7400: train loss 0.5586, val loss 0.5591
# step 7500: train loss 0.5589, val loss 0.5591
# step 7600: train loss 0.5590, val loss 0.5585
# step 7700: train loss 0.5589, val loss 0.5595
# step 7800: train loss 0.5588, val loss 0.5590
# step 7900: train loss 0.5586, val loss 0.5590
# step 8000: train loss 0.5587, val loss 0.5597
# step 8100: train loss 0.5580, val loss 0.5585
# step 8200: train loss 0.5581, val loss 0.5588
# step 8300: train loss 0.5582, val loss 0.5596
# step 8400: train loss 0.5589, val loss 0.5592
# step 8500: train loss 0.5581, val loss 0.5591
# step 8600: train loss 0.5587, val loss 0.5590
# step 8700: train loss 0.5586, val loss 0.5593
# step 8800: train loss 0.5585, val loss 0.5589
# step 8900: train loss 0.5584, val loss 0.5586
# step 9000: train loss 0.5585, val loss 0.5592
# step 9100: train loss 0.5592, val loss 0.5595
# step 9200: train loss 0.5585, val loss 0.5587
# step 9300: train loss 0.5586, val loss 0.5599
# step 9400: train loss 0.5584, val loss 0.5598
# step 9500: train loss 0.5586, val loss 0.5589
# step 9600: train loss 0.5585, val loss 0.5594
# step 9700: train loss 0.5586, val loss 0.5584
# step 9800: train loss 0.5584, val loss 0.5586
# step 9900: train loss 0.5592, val loss 0.5592
# step 9999: train loss 0.5584, val loss 0.5585

# %%
base_path = Path("models")
base_path.mkdir(exist_ok=True)
# convert and save
serializable_models = tensor_to_serializable(my_models)
filename = f"my_models_saved.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(serializable_models, f, indent=2)

print(f"Saved models to {filepath}")
# Out:
# Saved models to models2/my_models_saved2.json

# %% [markdown]
# Order 5:

# %%
n_head = 1
n_layer = 3
n_embd = 64
sequence_length = 2000
num_sequences = 2000
num_iterations = 15000
seeds = [107, 108, 109, 110, 111]
idx = 0
for number in range(1, 6): # 5 models per order
    try:
        print(f"Training model order=5 number={number}")
        model_info = train_model(5, number, num_iterations, seeds[idx], sequence_length, num_sequences)
        my_models.append(model_info)
        idx += 1
        
        if device.type == "mps":
            torch.mps.empty_cache() # cleanup
            
    except Exception as e:
        print(f"Failed training model number={number}: {e}")
        continue
# Out:
# Training model order=5 number=1
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.4786, 0.5214],
#         [0.4535, 0.5465],
#         [0.2829, 0.7171],
#         [0.6684, 0.3316],
#         [0.3589, 0.6411],
#         [0.0818, 0.9182],
#         [0.3591, 0.6409],
#         [0.9840, 0.0160],
#         [0.6488, 0.3512],
#         [0.3760, 0.6240],
#         [0.4755, 0.5245],
#         [0.8907, 0.1093],
#         [0.9958, 0.0042],
#         [0.9909, 0.0091],
#         [0.9526, 0.0474],
#         [0.5505, 0.4495],
#         [0.1753, 0.8247],
#         [0.5390, 0.4610],
#         [0.8194, 0.1806],
#         [0.1969, 0.8031],
#         [0.6243, 0.3757],
#         [0.4714, 0.5286],
#         [0.7115, 0.2885],
#         [0.6734, 0.3266],
#         [0.6348, 0.3652],
#         [0.2588, 0.7412],
#         [0.3997, 0.6003],
#         [0.0488, 0.9512],
#         [0.6354, 0.3646],
#         [0.7367, 0.2633],
#         [0.7870, 0.2130],
#         [0.4704, 0.5296]])
# step 0: train loss 0.7408, val loss 0.7417
# step 100: train loss 0.6831, val loss 0.6831
# step 200: train loss 0.6825, val loss 0.6827
# step 300: train loss 0.6812, val loss 0.6811
# step 400: train loss 0.6789, val loss 0.6788
# step 500: train loss 0.6745, val loss 0.6744
# step 600: train loss 0.6679, val loss 0.6677
# step 700: train loss 0.6628, val loss 0.6621
# step 800: train loss 0.6504, val loss 0.6507
# step 900: train loss 0.6389, val loss 0.6387
# step 1000: train loss 0.6269, val loss 0.6261
# step 1100: train loss 0.6164, val loss 0.6156
# step 1200: train loss 0.6100, val loss 0.6094
# step 1300: train loss 0.5999, val loss 0.5991
# step 1400: train loss 0.6034, val loss 0.6024
# step 1500: train loss 0.5855, val loss 0.5848
# step 1600: train loss 0.5790, val loss 0.5782
# step 1700: train loss 0.5766, val loss 0.5753
# step 1800: train loss 0.5705, val loss 0.5691
# step 1900: train loss 0.5705, val loss 0.5690
# step 2000: train loss 0.5561, val loss 0.5551
# step 2100: train loss 0.5520, val loss 0.5523
# step 2200: train loss 0.5453, val loss 0.5448
# step 2300: train loss 0.5492, val loss 0.5488
# step 2400: train loss 0.5382, val loss 0.5374
# step 2500: train loss 0.5377, val loss 0.5382
# step 2600: train loss 0.5325, val loss 0.5331
# step 2700: train loss 0.5312, val loss 0.5306
# step 2800: train loss 0.5281, val loss 0.5279
# step 2900: train loss 0.5274, val loss 0.5269
# step 3000: train loss 0.5287, val loss 0.5276
# step 3100: train loss 0.5264, val loss 0.5258
# step 3200: train loss 0.5253, val loss 0.5249
# step 3300: train loss 0.5228, val loss 0.5225
# step 3400: train loss 0.5220, val loss 0.5222
# step 3500: train loss 0.5226, val loss 0.5215
# step 3600: train loss 0.5210, val loss 0.5208
# step 3700: train loss 0.5210, val loss 0.5201
# step 3800: train loss 0.5203, val loss 0.5195
# step 3900: train loss 0.5203, val loss 0.5199
# step 4000: train loss 0.5197, val loss 0.5191
# step 4100: train loss 0.5199, val loss 0.5203
# step 4200: train loss 0.5185, val loss 0.5188
# step 4300: train loss 0.5198, val loss 0.5202
# step 4400: train loss 0.5191, val loss 0.5186
# step 4500: train loss 0.5191, val loss 0.5185
# step 4600: train loss 0.5196, val loss 0.5192
# step 4700: train loss 0.5192, val loss 0.5189
# step 4800: train loss 0.5181, val loss 0.5176
# step 4900: train loss 0.5175, val loss 0.5178
# step 5000: train loss 0.5195, val loss 0.5189
# step 5100: train loss 0.5167, val loss 0.5170
# step 5200: train loss 0.5174, val loss 0.5173
# step 5300: train loss 0.5159, val loss 0.5158
# step 5400: train loss 0.5174, val loss 0.5167
# step 5500: train loss 0.5168, val loss 0.5167
# step 5600: train loss 0.5165, val loss 0.5172
# step 5700: train loss 0.5167, val loss 0.5171
# step 5800: train loss 0.5159, val loss 0.5161
# step 5900: train loss 0.5174, val loss 0.5165
# step 6000: train loss 0.5174, val loss 0.5160
# step 6100: train loss 0.5160, val loss 0.5166
# step 6200: train loss 0.5158, val loss 0.5162
# step 6300: train loss 0.5165, val loss 0.5165
# step 6400: train loss 0.5153, val loss 0.5154
# step 6500: train loss 0.5155, val loss 0.5158
# step 6600: train loss 0.5153, val loss 0.5160
# step 6700: train loss 0.5155, val loss 0.5152
# step 6800: train loss 0.5137, val loss 0.5144
# step 6900: train loss 0.5157, val loss 0.5153
# step 7000: train loss 0.5147, val loss 0.5150
# step 7100: train loss 0.5147, val loss 0.5148
# step 7200: train loss 0.5144, val loss 0.5152
# step 7300: train loss 0.5143, val loss 0.5150
# step 7400: train loss 0.5151, val loss 0.5147
# step 7500: train loss 0.5142, val loss 0.5140
# step 7600: train loss 0.5141, val loss 0.5148
# step 7700: train loss 0.5147, val loss 0.5135
# step 7800: train loss 0.5150, val loss 0.5147
# step 7900: train loss 0.5142, val loss 0.5138
# step 8000: train loss 0.5162, val loss 0.5152
# step 8100: train loss 0.5149, val loss 0.5154
# step 8200: train loss 0.5145, val loss 0.5136
# step 8300: train loss 0.5135, val loss 0.5141
# step 8400: train loss 0.5138, val loss 0.5142
# step 8500: train loss 0.5152, val loss 0.5150
# step 8600: train loss 0.5144, val loss 0.5137
# step 8700: train loss 0.5143, val loss 0.5142
# step 8800: train loss 0.5139, val loss 0.5144
# step 8900: train loss 0.5145, val loss 0.5138
# step 9000: train loss 0.5147, val loss 0.5145
# step 9100: train loss 0.5142, val loss 0.5142
# step 9200: train loss 0.5144, val loss 0.5143
# step 9300: train loss 0.5139, val loss 0.5135
# step 9400: train loss 0.5131, val loss 0.5135
# step 9500: train loss 0.5141, val loss 0.5140
# step 9600: train loss 0.5140, val loss 0.5133
# step 9700: train loss 0.5137, val loss 0.5137
# step 9800: train loss 0.5136, val loss 0.5138
# step 9900: train loss 0.5137, val loss 0.5135
# step 10000: train loss 0.5129, val loss 0.5135
# step 10100: train loss 0.5132, val loss 0.5133
# step 10200: train loss 0.5135, val loss 0.5135
# step 10300: train loss 0.5135, val loss 0.5133
# step 10400: train loss 0.5134, val loss 0.5136
# step 10500: train loss 0.5134, val loss 0.5129
# step 10600: train loss 0.5123, val loss 0.5132
# step 10700: train loss 0.5137, val loss 0.5128
# step 10800: train loss 0.5138, val loss 0.5132
# step 10900: train loss 0.5131, val loss 0.5136
# step 11000: train loss 0.5134, val loss 0.5134
# step 11100: train loss 0.5133, val loss 0.5126
# step 11200: train loss 0.5127, val loss 0.5132
# step 11300: train loss 0.5130, val loss 0.5127
# step 11400: train loss 0.5133, val loss 0.5135
# step 11500: train loss 0.5128, val loss 0.5136
# step 11600: train loss 0.5134, val loss 0.5130
# step 11700: train loss 0.5137, val loss 0.5129
# step 11800: train loss 0.5123, val loss 0.5128
# step 11900: train loss 0.5124, val loss 0.5130
# step 12000: train loss 0.5134, val loss 0.5128
# step 12100: train loss 0.5124, val loss 0.5125
# step 12200: train loss 0.5126, val loss 0.5129
# step 12300: train loss 0.5134, val loss 0.5131
# step 12400: train loss 0.5126, val loss 0.5120
# step 12500: train loss 0.5127, val loss 0.5127
# step 12600: train loss 0.5121, val loss 0.5126
# step 12700: train loss 0.5131, val loss 0.5121
# step 12800: train loss 0.5130, val loss 0.5125
# step 12900: train loss 0.5128, val loss 0.5129
# step 13000: train loss 0.5128, val loss 0.5123
# step 13100: train loss 0.5130, val loss 0.5126
# step 13200: train loss 0.5131, val loss 0.5120
# step 13300: train loss 0.5131, val loss 0.5122
# step 13400: train loss 0.5126, val loss 0.5124
# step 13500: train loss 0.5128, val loss 0.5125
# step 13600: train loss 0.5126, val loss 0.5125
# step 13700: train loss 0.5123, val loss 0.5130
# step 13800: train loss 0.5123, val loss 0.5126
# step 13900: train loss 0.5120, val loss 0.5133
# step 14000: train loss 0.5123, val loss 0.5129
# step 14100: train loss 0.5128, val loss 0.5125
# step 14200: train loss 0.5127, val loss 0.5129
# step 14300: train loss 0.5124, val loss 0.5127
# step 14400: train loss 0.5130, val loss 0.5123
# step 14500: train loss 0.5129, val loss 0.5125
# step 14600: train loss 0.5130, val loss 0.5123
# step 14700: train loss 0.5126, val loss 0.5119
# step 14800: train loss 0.5131, val loss 0.5128
# step 14900: train loss 0.5128, val loss 0.5118
# step 14999: train loss 0.5127, val loss 0.5125
# Training model order=5 number=2
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.7644, 0.2356],
#         [0.5870, 0.4130],
#         [0.4428, 0.5572],
#         [0.1057, 0.8943],
#         [0.5804, 0.4196],
#         [0.0651, 0.9349],
#         [0.5055, 0.4945],
#         [0.3817, 0.6183],
#         [0.6754, 0.3246],
#         [0.4313, 0.5687],
#         [0.7635, 0.2365],
#         [0.5875, 0.4125],
#         [0.5978, 0.4022],
#         [0.7958, 0.2042],
#         [0.5494, 0.4506],
#         [0.9203, 0.0797],
#         [0.5362, 0.4638],
#         [0.3425, 0.6575],
#         [0.2151, 0.7849],
#         [0.6726, 0.3274],
#         [0.8919, 0.1081],
#         [0.4653, 0.5347],
#         [0.5444, 0.4556],
#         [0.1851, 0.8149],
#         [0.5315, 0.4685],
#         [0.4541, 0.5459],
#         [0.8278, 0.1722],
#         [0.4095, 0.5905],
#         [0.3557, 0.6443],
#         [0.5754, 0.4246],
#         [0.6489, 0.3511],
#         [0.3946, 0.6054]])
# step 0: train loss 0.7480, val loss 0.7486
# step 100: train loss 0.6796, val loss 0.6794
# step 200: train loss 0.6792, val loss 0.6793
# step 300: train loss 0.6800, val loss 0.6798
# step 400: train loss 0.6793, val loss 0.6790
# step 500: train loss 0.6794, val loss 0.6788
# step 600: train loss 0.6791, val loss 0.6788
# step 700: train loss 0.6789, val loss 0.6791
# step 800: train loss 0.6792, val loss 0.6787
# step 900: train loss 0.6791, val loss 0.6791
# step 1000: train loss 0.6789, val loss 0.6789
# step 1100: train loss 0.6786, val loss 0.6783
# step 1200: train loss 0.6782, val loss 0.6780
# step 1300: train loss 0.6776, val loss 0.6775
# step 1400: train loss 0.6769, val loss 0.6767
# step 1500: train loss 0.6752, val loss 0.6750
# step 1600: train loss 0.6740, val loss 0.6734
# step 1700: train loss 0.6711, val loss 0.6711
# step 1800: train loss 0.6707, val loss 0.6704
# step 1900: train loss 0.6684, val loss 0.6682
# step 2000: train loss 0.6655, val loss 0.6648
# step 2100: train loss 0.6627, val loss 0.6628
# step 2200: train loss 0.6612, val loss 0.6608
# step 2300: train loss 0.6588, val loss 0.6580
# step 2400: train loss 0.6554, val loss 0.6552
# step 2500: train loss 0.6519, val loss 0.6517
# step 2600: train loss 0.6468, val loss 0.6469
# step 2700: train loss 0.6440, val loss 0.6430
# step 2800: train loss 0.6377, val loss 0.6380
# step 2900: train loss 0.6322, val loss 0.6325
# step 3000: train loss 0.6287, val loss 0.6285
# step 3100: train loss 0.6243, val loss 0.6243
# step 3200: train loss 0.6217, val loss 0.6213
# step 3300: train loss 0.6212, val loss 0.6217
# step 3400: train loss 0.6188, val loss 0.6183
# step 3500: train loss 0.6188, val loss 0.6189
# step 3600: train loss 0.6168, val loss 0.6169
# step 3700: train loss 0.6160, val loss 0.6155
# step 3800: train loss 0.6148, val loss 0.6149
# step 3900: train loss 0.6147, val loss 0.6143
# step 4000: train loss 0.6136, val loss 0.6132
# step 4100: train loss 0.6122, val loss 0.6122
# step 4200: train loss 0.6122, val loss 0.6125
# step 4300: train loss 0.6118, val loss 0.6115
# step 4400: train loss 0.6116, val loss 0.6110
# step 4500: train loss 0.6110, val loss 0.6109
# step 4600: train loss 0.6099, val loss 0.6100
# step 4700: train loss 0.6095, val loss 0.6100
# step 4800: train loss 0.6096, val loss 0.6093
# step 4900: train loss 0.6098, val loss 0.6097
# step 5000: train loss 0.6093, val loss 0.6092
# step 5100: train loss 0.6079, val loss 0.6082
# step 5200: train loss 0.6074, val loss 0.6076
# step 5300: train loss 0.6072, val loss 0.6070
# step 5400: train loss 0.6076, val loss 0.6070
# step 5500: train loss 0.6066, val loss 0.6067
# step 5600: train loss 0.6070, val loss 0.6071
# step 5700: train loss 0.6066, val loss 0.6068
# step 5800: train loss 0.6061, val loss 0.6061
# step 5900: train loss 0.6058, val loss 0.6050
# step 6000: train loss 0.6056, val loss 0.6053
# step 6100: train loss 0.6046, val loss 0.6047
# step 6200: train loss 0.6048, val loss 0.6047
# step 6300: train loss 0.6050, val loss 0.6047
# step 6400: train loss 0.6052, val loss 0.6045
# step 6500: train loss 0.6040, val loss 0.6042
# step 6600: train loss 0.6037, val loss 0.6042
# step 6700: train loss 0.6041, val loss 0.6038
# step 6800: train loss 0.6029, val loss 0.6043
# step 6900: train loss 0.6033, val loss 0.6038
# step 7000: train loss 0.6030, val loss 0.6032
# step 7100: train loss 0.6033, val loss 0.6036
# step 7200: train loss 0.6024, val loss 0.6029
# step 7300: train loss 0.6026, val loss 0.6031
# step 7400: train loss 0.6027, val loss 0.6027
# step 7500: train loss 0.6028, val loss 0.6024
# step 7600: train loss 0.6025, val loss 0.6031
# step 7700: train loss 0.6020, val loss 0.6018
# step 7800: train loss 0.6023, val loss 0.6021
# step 7900: train loss 0.6016, val loss 0.6016
# step 8000: train loss 0.6022, val loss 0.6021
# step 8100: train loss 0.6019, val loss 0.6018
# step 8200: train loss 0.6013, val loss 0.6016
# step 8300: train loss 0.6015, val loss 0.6014
# step 8400: train loss 0.6010, val loss 0.6012
# step 8500: train loss 0.6010, val loss 0.6009
# step 8600: train loss 0.6018, val loss 0.6016
# step 8700: train loss 0.6007, val loss 0.6006
# step 8800: train loss 0.6006, val loss 0.6006
# step 8900: train loss 0.6005, val loss 0.6010
# step 9000: train loss 0.6007, val loss 0.6007
# step 9100: train loss 0.6006, val loss 0.6002
# step 9200: train loss 0.6004, val loss 0.6011
# step 9300: train loss 0.6000, val loss 0.6003
# step 9400: train loss 0.6004, val loss 0.6004
# step 9500: train loss 0.5998, val loss 0.6008
# step 9600: train loss 0.5999, val loss 0.6000
# step 9700: train loss 0.5999, val loss 0.6001
# step 9800: train loss 0.6001, val loss 0.6001
# step 9900: train loss 0.6000, val loss 0.5999
# step 10000: train loss 0.5998, val loss 0.6004
# step 10100: train loss 0.5997, val loss 0.5995
# step 10200: train loss 0.5998, val loss 0.5999
# step 10300: train loss 0.5997, val loss 0.6000
# step 10400: train loss 0.5995, val loss 0.5997
# step 10500: train loss 0.5997, val loss 0.5995
# step 10600: train loss 0.5994, val loss 0.6003
# step 10700: train loss 0.5996, val loss 0.5993
# step 10800: train loss 0.5997, val loss 0.5991
# step 10900: train loss 0.5993, val loss 0.5992
# step 11000: train loss 0.5987, val loss 0.5991
# step 11100: train loss 0.5990, val loss 0.5992
# step 11200: train loss 0.5987, val loss 0.5994
# step 11300: train loss 0.5994, val loss 0.5986
# step 11400: train loss 0.5990, val loss 0.5994
# step 11500: train loss 0.5991, val loss 0.5991
# step 11600: train loss 0.5988, val loss 0.5989
# step 11700: train loss 0.5996, val loss 0.5991
# step 11800: train loss 0.5983, val loss 0.5994
# step 11900: train loss 0.5983, val loss 0.5989
# step 12000: train loss 0.5984, val loss 0.5993
# step 12100: train loss 0.5984, val loss 0.5991
# step 12200: train loss 0.5987, val loss 0.5985
# step 12300: train loss 0.5986, val loss 0.5995
# step 12400: train loss 0.5980, val loss 0.5985
# step 12500: train loss 0.5985, val loss 0.5987
# step 12600: train loss 0.5991, val loss 0.5982
# step 12700: train loss 0.5980, val loss 0.5984
# step 12800: train loss 0.5982, val loss 0.5986
# step 12900: train loss 0.5983, val loss 0.5985
# step 13000: train loss 0.5988, val loss 0.5985
# step 13100: train loss 0.5986, val loss 0.5987
# step 13200: train loss 0.5984, val loss 0.5978
# step 13300: train loss 0.5984, val loss 0.5985
# step 13400: train loss 0.5982, val loss 0.5979
# step 13500: train loss 0.5978, val loss 0.5989
# step 13600: train loss 0.5981, val loss 0.5986
# step 13700: train loss 0.5980, val loss 0.5987
# step 13800: train loss 0.5985, val loss 0.5987
# step 13900: train loss 0.5983, val loss 0.5987
# step 14000: train loss 0.5988, val loss 0.5989
# step 14100: train loss 0.5980, val loss 0.5987
# step 14200: train loss 0.5981, val loss 0.5987
# step 14300: train loss 0.5984, val loss 0.5990
# step 14400: train loss 0.5987, val loss 0.5989
# step 14500: train loss 0.5982, val loss 0.5986
# step 14600: train loss 0.5982, val loss 0.5982
# step 14700: train loss 0.5980, val loss 0.5984
# step 14800: train loss 0.5983, val loss 0.5982
# step 14900: train loss 0.5983, val loss 0.5983
# step 14999: train loss 0.5981, val loss 0.5982
# Training model order=5 number=3
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.4482, 0.5518],
#         [0.5968, 0.4032],
#         [0.0266, 0.9734],
#         [0.4979, 0.5021],
#         [0.3651, 0.6349],
#         [0.3580, 0.6420],
#         [0.4701, 0.5299],
#         [0.7679, 0.2321],
#         [0.7691, 0.2309],
#         [0.6607, 0.3393],
#         [0.4761, 0.5239],
#         [0.5031, 0.4969],
#         [0.8940, 0.1060],
#         [0.6271, 0.3729],
#         [0.5644, 0.4356],
#         [0.7970, 0.2030],
#         [0.5941, 0.4059],
#         [0.4155, 0.5845],
#         [0.3837, 0.6163],
#         [0.4546, 0.5454],
#         [0.8193, 0.1807],
#         [0.7117, 0.2883],
#         [0.7302, 0.2698],
#         [0.6032, 0.3968],
#         [0.4353, 0.5647],
#         [0.6018, 0.3982],
#         [0.1382, 0.8618],
#         [0.5097, 0.4903],
#         [0.9175, 0.0825],
#         [0.8812, 0.1188],
#         [0.4948, 0.5052],
#         [0.7994, 0.2006]])
# step 0: train loss 0.7202, val loss 0.7200
# step 100: train loss 0.6863, val loss 0.6863
# step 200: train loss 0.6860, val loss 0.6859
# step 300: train loss 0.6858, val loss 0.6859
# step 400: train loss 0.6857, val loss 0.6857
# step 500: train loss 0.6858, val loss 0.6856
# step 600: train loss 0.6848, val loss 0.6848
# step 700: train loss 0.6841, val loss 0.6843
# step 800: train loss 0.6830, val loss 0.6828
# step 900: train loss 0.6807, val loss 0.6805
# step 1000: train loss 0.6790, val loss 0.6789
# step 1100: train loss 0.6774, val loss 0.6772
# step 1200: train loss 0.6743, val loss 0.6740
# step 1300: train loss 0.6717, val loss 0.6714
# step 1400: train loss 0.6697, val loss 0.6694
# step 1500: train loss 0.6672, val loss 0.6671
# step 1600: train loss 0.6663, val loss 0.6658
# step 1700: train loss 0.6637, val loss 0.6636
# step 1800: train loss 0.6623, val loss 0.6617
# step 1900: train loss 0.6604, val loss 0.6601
# step 2000: train loss 0.6596, val loss 0.6589
# step 2100: train loss 0.6577, val loss 0.6572
# step 2200: train loss 0.6555, val loss 0.6554
# step 2300: train loss 0.6549, val loss 0.6543
# step 2400: train loss 0.6538, val loss 0.6538
# step 2500: train loss 0.6511, val loss 0.6508
# step 2600: train loss 0.6496, val loss 0.6485
# step 2700: train loss 0.6467, val loss 0.6464
# step 2800: train loss 0.6455, val loss 0.6450
# step 2900: train loss 0.6436, val loss 0.6427
# step 3000: train loss 0.6410, val loss 0.6406
# step 3100: train loss 0.6394, val loss 0.6393
# step 3200: train loss 0.6378, val loss 0.6376
# step 3300: train loss 0.6368, val loss 0.6362
# step 3400: train loss 0.6353, val loss 0.6348
# step 3500: train loss 0.6345, val loss 0.6347
# step 3600: train loss 0.6334, val loss 0.6320
# step 3700: train loss 0.6316, val loss 0.6310
# step 3800: train loss 0.6309, val loss 0.6305
# step 3900: train loss 0.6299, val loss 0.6296
# step 4000: train loss 0.6290, val loss 0.6283
# step 4100: train loss 0.6262, val loss 0.6256
# step 4200: train loss 0.6261, val loss 0.6259
# step 4300: train loss 0.6241, val loss 0.6234
# step 4400: train loss 0.6229, val loss 0.6218
# step 4500: train loss 0.6210, val loss 0.6203
# step 4600: train loss 0.6204, val loss 0.6196
# step 4700: train loss 0.6178, val loss 0.6179
# step 4800: train loss 0.6168, val loss 0.6163
# step 4900: train loss 0.6155, val loss 0.6150
# step 5000: train loss 0.6150, val loss 0.6143
# step 5100: train loss 0.6136, val loss 0.6132
# step 5200: train loss 0.6123, val loss 0.6121
# step 5300: train loss 0.6112, val loss 0.6113
# step 5400: train loss 0.6109, val loss 0.6103
# step 5500: train loss 0.6098, val loss 0.6095
# step 5600: train loss 0.6097, val loss 0.6098
# step 5700: train loss 0.6090, val loss 0.6080
# step 5800: train loss 0.6079, val loss 0.6080
# step 5900: train loss 0.6077, val loss 0.6073
# step 6000: train loss 0.6074, val loss 0.6070
# step 6100: train loss 0.6064, val loss 0.6059
# step 6200: train loss 0.6058, val loss 0.6050
# step 6300: train loss 0.6052, val loss 0.6051
# step 6400: train loss 0.6049, val loss 0.6042
# step 6500: train loss 0.6040, val loss 0.6035
# step 6600: train loss 0.6038, val loss 0.6038
# step 6700: train loss 0.6039, val loss 0.6032
# step 6800: train loss 0.6035, val loss 0.6028
# step 6900: train loss 0.6021, val loss 0.6017
# step 7000: train loss 0.6023, val loss 0.6017
# step 7100: train loss 0.6016, val loss 0.6012
# step 7200: train loss 0.6009, val loss 0.6004
# step 7300: train loss 0.6010, val loss 0.6008
# step 7400: train loss 0.6009, val loss 0.6002
# step 7500: train loss 0.6005, val loss 0.5994
# step 7600: train loss 0.6009, val loss 0.6000
# step 7700: train loss 0.6001, val loss 0.5997
# step 7800: train loss 0.5996, val loss 0.5992
# step 7900: train loss 0.5992, val loss 0.5988
# step 8000: train loss 0.5995, val loss 0.5988
# step 8100: train loss 0.5989, val loss 0.5981
# step 8200: train loss 0.5988, val loss 0.5982
# step 8300: train loss 0.5990, val loss 0.5978
# step 8400: train loss 0.5978, val loss 0.5978
# step 8500: train loss 0.5980, val loss 0.5974
# step 8600: train loss 0.5979, val loss 0.5970
# step 8700: train loss 0.5973, val loss 0.5968
# step 8800: train loss 0.5978, val loss 0.5962
# step 8900: train loss 0.5978, val loss 0.5969
# step 9000: train loss 0.5979, val loss 0.5967
# step 9100: train loss 0.5969, val loss 0.5965
# step 9200: train loss 0.5968, val loss 0.5967
# step 9300: train loss 0.5964, val loss 0.5965
# step 9400: train loss 0.5966, val loss 0.5960
# step 9500: train loss 0.5965, val loss 0.5959
# step 9600: train loss 0.5962, val loss 0.5953
# step 9700: train loss 0.5968, val loss 0.5958
# step 9800: train loss 0.5961, val loss 0.5953
# step 9900: train loss 0.5957, val loss 0.5959
# step 10000: train loss 0.5956, val loss 0.5959
# step 10100: train loss 0.5961, val loss 0.5952
# step 10200: train loss 0.5961, val loss 0.5953
# step 10300: train loss 0.5957, val loss 0.5949
# step 10400: train loss 0.5954, val loss 0.5950
# step 10500: train loss 0.5954, val loss 0.5952
# step 10600: train loss 0.5953, val loss 0.5950
# step 10700: train loss 0.5949, val loss 0.5942
# step 10800: train loss 0.5947, val loss 0.5945
# step 10900: train loss 0.5951, val loss 0.5942
# step 11000: train loss 0.5949, val loss 0.5941
# step 11100: train loss 0.5947, val loss 0.5940
# step 11200: train loss 0.5948, val loss 0.5937
# step 11300: train loss 0.5941, val loss 0.5934
# step 11400: train loss 0.5947, val loss 0.5942
# step 11500: train loss 0.5941, val loss 0.5942
# step 11600: train loss 0.5944, val loss 0.5937
# step 11700: train loss 0.5944, val loss 0.5939
# step 11800: train loss 0.5946, val loss 0.5937
# step 11900: train loss 0.5940, val loss 0.5937
# step 12000: train loss 0.5940, val loss 0.5934
# step 12100: train loss 0.5935, val loss 0.5934
# step 12200: train loss 0.5942, val loss 0.5935
# step 12300: train loss 0.5941, val loss 0.5939
# step 12400: train loss 0.5937, val loss 0.5933
# step 12500: train loss 0.5942, val loss 0.5934
# step 12600: train loss 0.5935, val loss 0.5936
# step 12700: train loss 0.5941, val loss 0.5931
# step 12800: train loss 0.5937, val loss 0.5926
# step 12900: train loss 0.5935, val loss 0.5929
# step 13000: train loss 0.5935, val loss 0.5934
# step 13100: train loss 0.5935, val loss 0.5931
# step 13200: train loss 0.5938, val loss 0.5925
# step 13300: train loss 0.5935, val loss 0.5922
# step 13400: train loss 0.5936, val loss 0.5932
# step 13500: train loss 0.5933, val loss 0.5932
# step 13600: train loss 0.5932, val loss 0.5931
# step 13700: train loss 0.5935, val loss 0.5933
# step 13800: train loss 0.5935, val loss 0.5932
# step 13900: train loss 0.5933, val loss 0.5926
# step 14000: train loss 0.5934, val loss 0.5931
# step 14100: train loss 0.5934, val loss 0.5925
# step 14200: train loss 0.5939, val loss 0.5929
# step 14300: train loss 0.5935, val loss 0.5926
# step 14400: train loss 0.5937, val loss 0.5932
# step 14500: train loss 0.5934, val loss 0.5930
# step 14600: train loss 0.5932, val loss 0.5930
# step 14700: train loss 0.5935, val loss 0.5925
# step 14800: train loss 0.5936, val loss 0.5924
# step 14900: train loss 0.5941, val loss 0.5927
# step 14999: train loss 0.5930, val loss 0.5925
# Training model order=5 number=4
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.8872, 0.1128],
#         [0.4139, 0.5861],
#         [0.1922, 0.8078],
#         [0.5516, 0.4484],
#         [0.8802, 0.1198],
#         [0.4426, 0.5574],
#         [0.3348, 0.6652],
#         [0.1802, 0.8198],
#         [0.3069, 0.6931],
#         [0.0800, 0.9200],
#         [0.5019, 0.4981],
#         [0.9364, 0.0636],
#         [0.5549, 0.4451],
#         [0.6305, 0.3695],
#         [0.4551, 0.5449],
#         [0.2822, 0.7178],
#         [0.4178, 0.5822],
#         [0.3263, 0.6737],
#         [0.7434, 0.2566],
#         [0.4181, 0.5819],
#         [0.7336, 0.2664],
#         [0.6879, 0.3121],
#         [0.8966, 0.1034],
#         [0.5857, 0.4143],
#         [0.7862, 0.2138],
#         [0.7513, 0.2487],
#         [0.5205, 0.4795],
#         [0.8992, 0.1008],
#         [0.9947, 0.0053],
#         [0.6672, 0.3328],
#         [0.9461, 0.0539],
#         [0.2761, 0.7239]])
# step 0: train loss 0.7577, val loss 0.7575
# step 100: train loss 0.6499, val loss 0.6500
# step 200: train loss 0.6489, val loss 0.6499
# step 300: train loss 0.6495, val loss 0.6496
# step 400: train loss 0.6494, val loss 0.6495
# step 500: train loss 0.6498, val loss 0.6494
# step 600: train loss 0.6494, val loss 0.6506
# step 700: train loss 0.6488, val loss 0.6500
# step 800: train loss 0.6469, val loss 0.6469
# step 900: train loss 0.6454, val loss 0.6461
# step 1000: train loss 0.6360, val loss 0.6381
# step 1100: train loss 0.6292, val loss 0.6290
# step 1200: train loss 0.6222, val loss 0.6224
# step 1300: train loss 0.6156, val loss 0.6168
# step 1400: train loss 0.6126, val loss 0.6117
# step 1500: train loss 0.6069, val loss 0.6066
# step 1600: train loss 0.6042, val loss 0.6035
# step 1700: train loss 0.5994, val loss 0.6009
# step 1800: train loss 0.5985, val loss 0.5987
# step 1900: train loss 0.5960, val loss 0.5966
# step 2000: train loss 0.5972, val loss 0.5959
# step 2100: train loss 0.5905, val loss 0.5909
# step 2200: train loss 0.5861, val loss 0.5852
# step 2300: train loss 0.5884, val loss 0.5887
# step 2400: train loss 0.5795, val loss 0.5806
# step 2500: train loss 0.5767, val loss 0.5767
# step 2600: train loss 0.5758, val loss 0.5771
# step 2700: train loss 0.5731, val loss 0.5740
# step 2800: train loss 0.5727, val loss 0.5740
# step 2900: train loss 0.5723, val loss 0.5720
# step 3000: train loss 0.5674, val loss 0.5677
# step 3100: train loss 0.5677, val loss 0.5686
# step 3200: train loss 0.5656, val loss 0.5651
# step 3300: train loss 0.5622, val loss 0.5619
# step 3400: train loss 0.5595, val loss 0.5596
# step 3500: train loss 0.5623, val loss 0.5614
# step 3600: train loss 0.5581, val loss 0.5565
# step 3700: train loss 0.5566, val loss 0.5563
# step 3800: train loss 0.5544, val loss 0.5555
# step 3900: train loss 0.5642, val loss 0.5643
# step 4000: train loss 0.5506, val loss 0.5509
# step 4100: train loss 0.5533, val loss 0.5528
# step 4200: train loss 0.5505, val loss 0.5509
# step 4300: train loss 0.5497, val loss 0.5499
# step 4400: train loss 0.5477, val loss 0.5484
# step 4500: train loss 0.5476, val loss 0.5475
# step 4600: train loss 0.5481, val loss 0.5473
# step 4700: train loss 0.5448, val loss 0.5455
# step 4800: train loss 0.5434, val loss 0.5452
# step 4900: train loss 0.5441, val loss 0.5449
# step 5000: train loss 0.5417, val loss 0.5412
# step 5100: train loss 0.5419, val loss 0.5429
# step 5200: train loss 0.5419, val loss 0.5423
# step 5300: train loss 0.5405, val loss 0.5404
# step 5400: train loss 0.5405, val loss 0.5398
# step 5500: train loss 0.5413, val loss 0.5412
# step 5600: train loss 0.5406, val loss 0.5409
# step 5700: train loss 0.5391, val loss 0.5405
# step 5800: train loss 0.5409, val loss 0.5415
# step 5900: train loss 0.5385, val loss 0.5386
# step 6000: train loss 0.5375, val loss 0.5373
# step 6100: train loss 0.5377, val loss 0.5370
# step 6200: train loss 0.5363, val loss 0.5357
# step 6300: train loss 0.5374, val loss 0.5367
# step 6400: train loss 0.5349, val loss 0.5350
# step 6500: train loss 0.5350, val loss 0.5356
# step 6600: train loss 0.5346, val loss 0.5351
# step 6700: train loss 0.5357, val loss 0.5361
# step 6800: train loss 0.5345, val loss 0.5355
# step 6900: train loss 0.5336, val loss 0.5341
# step 7000: train loss 0.5333, val loss 0.5338
# step 7100: train loss 0.5338, val loss 0.5345
# step 7200: train loss 0.5352, val loss 0.5344
# step 7300: train loss 0.5336, val loss 0.5342
# step 7400: train loss 0.5347, val loss 0.5351
# step 7500: train loss 0.5332, val loss 0.5338
# step 7600: train loss 0.5331, val loss 0.5333
# step 7700: train loss 0.5329, val loss 0.5326
# step 7800: train loss 0.5323, val loss 0.5317
# step 7900: train loss 0.5318, val loss 0.5327
# step 8000: train loss 0.5320, val loss 0.5323
# step 8100: train loss 0.5317, val loss 0.5319
# step 8200: train loss 0.5309, val loss 0.5314
# step 8300: train loss 0.5308, val loss 0.5310
# step 8400: train loss 0.5306, val loss 0.5315
# step 8500: train loss 0.5319, val loss 0.5307
# step 8600: train loss 0.5325, val loss 0.5312
# step 8700: train loss 0.5304, val loss 0.5306
# step 8800: train loss 0.5321, val loss 0.5320
# step 8900: train loss 0.5323, val loss 0.5327
# step 9000: train loss 0.5311, val loss 0.5297
# step 9100: train loss 0.5304, val loss 0.5303
# step 9200: train loss 0.5303, val loss 0.5307
# step 9300: train loss 0.5298, val loss 0.5295
# step 9400: train loss 0.5296, val loss 0.5290
# step 9500: train loss 0.5306, val loss 0.5316
# step 9600: train loss 0.5298, val loss 0.5295
# step 9700: train loss 0.5304, val loss 0.5290
# step 9800: train loss 0.5297, val loss 0.5296
# step 9900: train loss 0.5287, val loss 0.5286
# step 10000: train loss 0.5290, val loss 0.5291
# step 10100: train loss 0.5284, val loss 0.5279
# step 10200: train loss 0.5291, val loss 0.5287
# step 10300: train loss 0.5293, val loss 0.5283
# step 10400: train loss 0.5281, val loss 0.5288
# step 10500: train loss 0.5271, val loss 0.5293
# step 10600: train loss 0.5272, val loss 0.5283
# step 10700: train loss 0.5279, val loss 0.5274
# step 10800: train loss 0.5275, val loss 0.5281
# step 10900: train loss 0.5278, val loss 0.5270
# step 11000: train loss 0.5287, val loss 0.5273
# step 11100: train loss 0.5267, val loss 0.5270
# step 11200: train loss 0.5265, val loss 0.5282
# step 11300: train loss 0.5271, val loss 0.5282
# step 11400: train loss 0.5273, val loss 0.5276
# step 11500: train loss 0.5274, val loss 0.5271
# step 11600: train loss 0.5275, val loss 0.5264
# step 11700: train loss 0.5279, val loss 0.5286
# step 11800: train loss 0.5269, val loss 0.5270
# step 11900: train loss 0.5270, val loss 0.5262
# step 12000: train loss 0.5267, val loss 0.5265
# step 12100: train loss 0.5264, val loss 0.5273
# step 12200: train loss 0.5268, val loss 0.5268
# step 12300: train loss 0.5264, val loss 0.5271
# step 12400: train loss 0.5256, val loss 0.5272
# step 12500: train loss 0.5262, val loss 0.5268
# step 12600: train loss 0.5252, val loss 0.5259
# step 12700: train loss 0.5271, val loss 0.5266
# step 12800: train loss 0.5263, val loss 0.5268
# step 12900: train loss 0.5263, val loss 0.5259
# step 13000: train loss 0.5263, val loss 0.5248
# step 13100: train loss 0.5270, val loss 0.5261
# step 13200: train loss 0.5265, val loss 0.5266
# step 13300: train loss 0.5263, val loss 0.5246
# step 13400: train loss 0.5253, val loss 0.5264
# step 13500: train loss 0.5259, val loss 0.5261
# step 13600: train loss 0.5255, val loss 0.5261
# step 13700: train loss 0.5257, val loss 0.5265
# step 13800: train loss 0.5259, val loss 0.5268
# step 13900: train loss 0.5253, val loss 0.5249
# step 14000: train loss 0.5259, val loss 0.5260
# step 14100: train loss 0.5252, val loss 0.5263
# step 14200: train loss 0.5255, val loss 0.5261
# step 14300: train loss 0.5254, val loss 0.5256
# step 14400: train loss 0.5259, val loss 0.5262
# step 14500: train loss 0.5265, val loss 0.5258
# step 14600: train loss 0.5249, val loss 0.5251
# step 14700: train loss 0.5253, val loss 0.5255
# step 14800: train loss 0.5251, val loss 0.5259
# step 14900: train loss 0.5262, val loss 0.5261
# step 14999: train loss 0.5262, val loss 0.5248
# Training model order=5 number=5
# 0.18253 M parameters
# Transition Matrix:
#  tensor([[0.4391, 0.5609],
#         [0.5220, 0.4780],
#         [0.5126, 0.4874],
#         [0.8122, 0.1878],
#         [0.4515, 0.5485],
#         [0.2669, 0.7331],
#         [0.7235, 0.2765],
#         [0.9416, 0.0584],
#         [0.2309, 0.7691],
#         [0.4096, 0.5904],
#         [0.4956, 0.5044],
#         [0.8452, 0.1548],
#         [0.8435, 0.1565],
#         [0.5782, 0.4218],
#         [0.0617, 0.9383],
#         [0.3451, 0.6549],
#         [0.3901, 0.6099],
#         [0.2730, 0.7270],
#         [0.7598, 0.2402],
#         [0.4947, 0.5053],
#         [0.7905, 0.2095],
#         [0.4284, 0.5716],
#         [0.4886, 0.5114],
#         [0.7625, 0.2375],
#         [0.9833, 0.0167],
#         [0.2633, 0.7367],
#         [0.8122, 0.1878],
#         [0.0283, 0.9717],
#         [0.5120, 0.4880],
#         [0.5616, 0.4384],
#         [0.6537, 0.3463],
#         [0.4349, 0.5651]])
# step 0: train loss 0.7344, val loss 0.7344
# step 100: train loss 0.6879, val loss 0.6877
# step 200: train loss 0.6871, val loss 0.6868
# step 300: train loss 0.6869, val loss 0.6869
# step 400: train loss 0.6872, val loss 0.6871
# step 500: train loss 0.6871, val loss 0.6867
# step 600: train loss 0.6870, val loss 0.6868
# step 700: train loss 0.6870, val loss 0.6870
# step 800: train loss 0.6871, val loss 0.6872
# step 900: train loss 0.6873, val loss 0.6871
# step 1000: train loss 0.6869, val loss 0.6869
# step 1100: train loss 0.6870, val loss 0.6868
# step 1200: train loss 0.6871, val loss 0.6869
# step 1300: train loss 0.6870, val loss 0.6868
# step 1400: train loss 0.6872, val loss 0.6867
# step 1500: train loss 0.6868, val loss 0.6867
# step 1600: train loss 0.6870, val loss 0.6868
# step 1700: train loss 0.6870, val loss 0.6867
# step 1800: train loss 0.6873, val loss 0.6867
# step 1900: train loss 0.6869, val loss 0.6868
# step 2000: train loss 0.6874, val loss 0.6872
# step 2100: train loss 0.6869, val loss 0.6868
# step 2200: train loss 0.6869, val loss 0.6867
# step 2300: train loss 0.6866, val loss 0.6866
# step 2400: train loss 0.6867, val loss 0.6867
# step 2500: train loss 0.6861, val loss 0.6862
# step 2600: train loss 0.6856, val loss 0.6856
# step 2700: train loss 0.6855, val loss 0.6851
# step 2800: train loss 0.6851, val loss 0.6851
# step 2900: train loss 0.6846, val loss 0.6843
# step 3000: train loss 0.6842, val loss 0.6839
# step 3100: train loss 0.6835, val loss 0.6833
# step 3200: train loss 0.6830, val loss 0.6825
# step 3300: train loss 0.6822, val loss 0.6821
# step 3400: train loss 0.6820, val loss 0.6817
# step 3500: train loss 0.6809, val loss 0.6807
# step 3600: train loss 0.6800, val loss 0.6794
# step 3700: train loss 0.6790, val loss 0.6786
# step 3800: train loss 0.6777, val loss 0.6778
# step 3900: train loss 0.6755, val loss 0.6752
# step 4000: train loss 0.6729, val loss 0.6727
# step 4100: train loss 0.6709, val loss 0.6702
# step 4200: train loss 0.6691, val loss 0.6692
# step 4300: train loss 0.6687, val loss 0.6682
# step 4400: train loss 0.6669, val loss 0.6666
# step 4500: train loss 0.6648, val loss 0.6646
# step 4600: train loss 0.6641, val loss 0.6641
# step 4700: train loss 0.6632, val loss 0.6632
# step 4800: train loss 0.6617, val loss 0.6615
# step 4900: train loss 0.6614, val loss 0.6613
# step 5000: train loss 0.6606, val loss 0.6605
# step 5100: train loss 0.6602, val loss 0.6601
# step 5200: train loss 0.6590, val loss 0.6583
# step 5300: train loss 0.6584, val loss 0.6580
# step 5400: train loss 0.6580, val loss 0.6574
# step 5500: train loss 0.6565, val loss 0.6566
# step 5600: train loss 0.6563, val loss 0.6565
# step 5700: train loss 0.6559, val loss 0.6557
# step 5800: train loss 0.6542, val loss 0.6547
# step 5900: train loss 0.6539, val loss 0.6540
# step 6000: train loss 0.6540, val loss 0.6537
# step 6100: train loss 0.6526, val loss 0.6525
# step 6200: train loss 0.6527, val loss 0.6527
# step 6300: train loss 0.6524, val loss 0.6516
# step 6400: train loss 0.6517, val loss 0.6514
# step 6500: train loss 0.6509, val loss 0.6508
# step 6600: train loss 0.6501, val loss 0.6502
# step 6700: train loss 0.6501, val loss 0.6498
# step 6800: train loss 0.6495, val loss 0.6494
# step 6900: train loss 0.6495, val loss 0.6493
# step 7000: train loss 0.6487, val loss 0.6484
# step 7100: train loss 0.6482, val loss 0.6484
# step 7200: train loss 0.6480, val loss 0.6478
# step 7300: train loss 0.6473, val loss 0.6470
# step 7400: train loss 0.6464, val loss 0.6462
# step 7500: train loss 0.6459, val loss 0.6454
# step 7600: train loss 0.6456, val loss 0.6458
# step 7700: train loss 0.6454, val loss 0.6448
# step 7800: train loss 0.6445, val loss 0.6446
# step 7900: train loss 0.6440, val loss 0.6437
# step 8000: train loss 0.6441, val loss 0.6437
# step 8100: train loss 0.6434, val loss 0.6434
# step 8200: train loss 0.6426, val loss 0.6420
# step 8300: train loss 0.6421, val loss 0.6425
# step 8400: train loss 0.6418, val loss 0.6415
# step 8500: train loss 0.6409, val loss 0.6411
# step 8600: train loss 0.6406, val loss 0.6409
# step 8700: train loss 0.6403, val loss 0.6401
# step 8800: train loss 0.6401, val loss 0.6399
# step 8900: train loss 0.6395, val loss 0.6397
# step 9000: train loss 0.6399, val loss 0.6395
# step 9100: train loss 0.6392, val loss 0.6388
# step 9200: train loss 0.6388, val loss 0.6385
# step 9300: train loss 0.6388, val loss 0.6388
# step 9400: train loss 0.6380, val loss 0.6376
# step 9500: train loss 0.6378, val loss 0.6381
# step 9600: train loss 0.6376, val loss 0.6369
# step 9700: train loss 0.6368, val loss 0.6371
# step 9800: train loss 0.6370, val loss 0.6365
# step 9900: train loss 0.6363, val loss 0.6366
# step 10000: train loss 0.6359, val loss 0.6362
# step 10100: train loss 0.6359, val loss 0.6362
# step 10200: train loss 0.6355, val loss 0.6353
# step 10300: train loss 0.6354, val loss 0.6348
# step 10400: train loss 0.6350, val loss 0.6349
# step 10500: train loss 0.6345, val loss 0.6345
# step 10600: train loss 0.6351, val loss 0.6341
# step 10700: train loss 0.6340, val loss 0.6339
# step 10800: train loss 0.6338, val loss 0.6336
# step 10900: train loss 0.6333, val loss 0.6338
# step 11000: train loss 0.6334, val loss 0.6334
# step 11100: train loss 0.6327, val loss 0.6332
# step 11200: train loss 0.6336, val loss 0.6325
# step 11300: train loss 0.6328, val loss 0.6328
# step 11400: train loss 0.6326, val loss 0.6325
# step 11500: train loss 0.6325, val loss 0.6323
# step 11600: train loss 0.6316, val loss 0.6318
# step 11700: train loss 0.6319, val loss 0.6315
# step 11800: train loss 0.6315, val loss 0.6316
# step 11900: train loss 0.6315, val loss 0.6314
# step 12000: train loss 0.6309, val loss 0.6309
# step 12100: train loss 0.6307, val loss 0.6310
# step 12200: train loss 0.6309, val loss 0.6308
# step 12300: train loss 0.6313, val loss 0.6306
# step 12400: train loss 0.6304, val loss 0.6306
# step 12500: train loss 0.6309, val loss 0.6302
# step 12600: train loss 0.6305, val loss 0.6303
# step 12700: train loss 0.6302, val loss 0.6302
# step 12800: train loss 0.6304, val loss 0.6299
# step 12900: train loss 0.6297, val loss 0.6300
# step 13000: train loss 0.6302, val loss 0.6298
# step 13100: train loss 0.6302, val loss 0.6297
# step 13200: train loss 0.6299, val loss 0.6296
# step 13300: train loss 0.6293, val loss 0.6293
# step 13400: train loss 0.6296, val loss 0.6294
# step 13500: train loss 0.6295, val loss 0.6294
# step 13600: train loss 0.6300, val loss 0.6298
# step 13700: train loss 0.6296, val loss 0.6292
# step 13800: train loss 0.6293, val loss 0.6295
# step 13900: train loss 0.6293, val loss 0.6294
# step 14000: train loss 0.6293, val loss 0.6296
# step 14100: train loss 0.6295, val loss 0.6295
# step 14200: train loss 0.6295, val loss 0.6293
# step 14300: train loss 0.6296, val loss 0.6294
# step 14400: train loss 0.6296, val loss 0.6290
# step 14500: train loss 0.6290, val loss 0.6292
# step 14600: train loss 0.6294, val loss 0.6291
# step 14700: train loss 0.6296, val loss 0.6292
# step 14800: train loss 0.6295, val loss 0.6287
# step 14900: train loss 0.6293, val loss 0.6290
# step 14999: train loss 0.6296, val loss 0.6291

# %%
base_path = Path("models")
base_path.mkdir(exist_ok=True)
# convert and save
serializable_models = tensor_to_serializable(my_models)
filename = f"my_models_saved.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(serializable_models, f, indent=2)

print(f"Saved models to {filepath}")
# Out:
# Saved models to models2/my_models_saved2.json

# %% [markdown]
# Order 6:

# %%
n_head = 1
n_layer = 4
n_embd = 64
sequence_length = 2000
num_sequences = 2000
num_iterations = 15000
seeds = [112, 113, 114, 115, 116] # 114, 116 length variieren
idx = 0
for number in range(1, 6): # 5 models per order
    try:
        print(f"Training model order=6 number={number}")
        model_info = train_model(6, number, num_iterations, seeds[idx], sequence_length, num_sequences)
        my_models.append(model_info)
        idx += 1
        
        if device.type == "mps":
            torch.mps.empty_cache() # cleanup
            
    except Exception as e:
        print(f"Failed training model number={number}: {e}")
        continue
# Out:
# Training model order=6 number=1
# 0.232322 M parameters
# Transition Matrix:
#  tensor([[9.4984e-02, 9.0502e-01],
#         [7.1621e-01, 2.8379e-01],
#         [2.4665e-01, 7.5335e-01],
#         [2.7498e-01, 7.2502e-01],
#         [4.9996e-01, 5.0004e-01],
#         [2.1048e-01, 7.8952e-01],
#         [1.5258e-01, 8.4742e-01],
#         [2.5055e-01, 7.4945e-01],
#         [8.5798e-01, 1.4202e-01],
#         [7.1078e-01, 2.8922e-01],
#         [7.0453e-01, 2.9547e-01],
#         [3.4466e-01, 6.5534e-01],
#         [5.5391e-01, 4.4609e-01],
#         [3.3408e-01, 6.6592e-01],
#         [6.2882e-02, 9.3712e-01],
#         [2.5419e-01, 7.4581e-01],
#         [3.9826e-01, 6.0174e-01],
#         [4.4364e-01, 5.5636e-01],
#         [9.8209e-02, 9.0179e-01],
#         [2.5315e-01, 7.4685e-01],
#         [5.1722e-01, 4.8278e-01],
#         [9.0810e-01, 9.1898e-02],
#         [6.3782e-01, 3.6218e-01],
#         [6.5414e-01, 3.4586e-01],
#         [4.6645e-01, 5.3355e-01],
#         [4.9828e-01, 5.0172e-01],
#         [4.6347e-01, 5.3653e-01],
#         [4.2199e-02, 9.5780e-01],
#         [6.0100e-01, 3.9900e-01],
#         [7.6125e-01, 2.3875e-01],
#         [5.9605e-01, 4.0395e-01],
#         [1.8952e-01, 8.1048e-01],
#         [6.6791e-01, 3.3209e-01],
#         [4.7740e-01, 5.2260e-01],
#         [5.7765e-01, 4.2235e-01],
#         [5.2991e-01, 4.7009e-01],
#         [6.1203e-02, 9.3880e-01],
#         [4.9637e-01, 5.0363e-01],
#         [5.7533e-01, 4.2467e-01],
#         [7.7132e-01, 2.2868e-01],
#         [2.1140e-01, 7.8860e-01],
#         [8.8657e-01, 1.1343e-01],
#         [5.9750e-01, 4.0250e-01],
#         [5.8362e-01, 4.1638e-01],
#         [4.7275e-01, 5.2725e-01],
#         [4.6709e-01, 5.3291e-01],
#         [6.1956e-01, 3.8044e-01],
#         [5.4795e-01, 4.5205e-01],
#         [5.8165e-01, 4.1835e-01],
#         [6.3559e-01, 3.6441e-01],
#         [3.0199e-01, 6.9801e-01],
#         [1.3960e-01, 8.6040e-01],
#         [3.8788e-01, 6.1212e-01],
#         [9.5031e-01, 4.9686e-02],
#         [5.1788e-01, 4.8212e-01],
#         [4.7168e-01, 5.2832e-01],
#         [9.6367e-01, 3.6327e-02],
#         [5.4593e-01, 4.5407e-01],
#         [5.7579e-01, 4.2421e-01],
#         [9.9957e-01, 4.3087e-04],
#         [3.3549e-01, 6.6451e-01],
#         [3.7798e-01, 6.2202e-01],
#         [7.1516e-01, 2.8484e-01],
#         [6.7311e-01, 3.2689e-01]])
# step 0: train loss 0.7680, val loss 0.7673
# step 100: train loss 0.6914, val loss 0.6913
# step 200: train loss 0.6913, val loss 0.6913
# step 300: train loss 0.6914, val loss 0.6912
# step 400: train loss 0.6915, val loss 0.6915
# step 500: train loss 0.6912, val loss 0.6913
# step 600: train loss 0.6911, val loss 0.6910
# step 700: train loss 0.6913, val loss 0.6912
# step 800: train loss 0.6913, val loss 0.6914
# step 900: train loss 0.6910, val loss 0.6909
# step 1000: train loss 0.6910, val loss 0.6909
# step 1100: train loss 0.6909, val loss 0.6910
# step 1200: train loss 0.6908, val loss 0.6907
# step 1300: train loss 0.6906, val loss 0.6904
# step 1400: train loss 0.6903, val loss 0.6904
# step 1500: train loss 0.6902, val loss 0.6901
# step 1600: train loss 0.6900, val loss 0.6900
# step 1700: train loss 0.6899, val loss 0.6897
# step 1800: train loss 0.6895, val loss 0.6895
# step 1900: train loss 0.6891, val loss 0.6889
# step 2000: train loss 0.6886, val loss 0.6887
# step 2100: train loss 0.6887, val loss 0.6883
# step 2200: train loss 0.6878, val loss 0.6877
# step 2300: train loss 0.6874, val loss 0.6873
# step 2400: train loss 0.6873, val loss 0.6870
# step 2500: train loss 0.6864, val loss 0.6863
# step 2600: train loss 0.6861, val loss 0.6859
# step 2700: train loss 0.6856, val loss 0.6853
# step 2800: train loss 0.6859, val loss 0.6855
# step 2900: train loss 0.6844, val loss 0.6842
# step 3000: train loss 0.6841, val loss 0.6840
# step 3100: train loss 0.6836, val loss 0.6833
# step 3200: train loss 0.6830, val loss 0.6827
# step 3300: train loss 0.6823, val loss 0.6820
# step 3400: train loss 0.6814, val loss 0.6811
# step 3500: train loss 0.6816, val loss 0.6814
# step 3600: train loss 0.6806, val loss 0.6804
# step 3700: train loss 0.6803, val loss 0.6802
# step 3800: train loss 0.6796, val loss 0.6794
# step 3900: train loss 0.6790, val loss 0.6786
# step 4000: train loss 0.6783, val loss 0.6783
# step 4100: train loss 0.6775, val loss 0.6773
# step 4200: train loss 0.6765, val loss 0.6763
# step 4300: train loss 0.6754, val loss 0.6753
# step 4400: train loss 0.6747, val loss 0.6749
# step 4500: train loss 0.6738, val loss 0.6737
# step 4600: train loss 0.6726, val loss 0.6721
# step 4700: train loss 0.6707, val loss 0.6708
# step 4800: train loss 0.6701, val loss 0.6701
# step 4900: train loss 0.6682, val loss 0.6679
# step 5000: train loss 0.6671, val loss 0.6668
# step 5100: train loss 0.6661, val loss 0.6651
# step 5200: train loss 0.6641, val loss 0.6643
# step 5300: train loss 0.6631, val loss 0.6630
# step 5400: train loss 0.6617, val loss 0.6614
# step 5500: train loss 0.6602, val loss 0.6600
# step 5600: train loss 0.6583, val loss 0.6582
# step 5700: train loss 0.6571, val loss 0.6571
# step 5800: train loss 0.6564, val loss 0.6563
# step 5900: train loss 0.6541, val loss 0.6543
# step 6000: train loss 0.6533, val loss 0.6531
# step 6100: train loss 0.6512, val loss 0.6510
# step 6200: train loss 0.6500, val loss 0.6504
# step 6300: train loss 0.6484, val loss 0.6485
# step 6400: train loss 0.6476, val loss 0.6472
# step 6500: train loss 0.6456, val loss 0.6458
# step 6600: train loss 0.6439, val loss 0.6442
# step 6700: train loss 0.6421, val loss 0.6420
# step 6800: train loss 0.6423, val loss 0.6422
# step 6900: train loss 0.6392, val loss 0.6388
# step 7000: train loss 0.6383, val loss 0.6381
# step 7100: train loss 0.6370, val loss 0.6369
# step 7200: train loss 0.6343, val loss 0.6349
# step 7300: train loss 0.6339, val loss 0.6335
# step 7400: train loss 0.6317, val loss 0.6322
# step 7500: train loss 0.6310, val loss 0.6309
# step 7600: train loss 0.6290, val loss 0.6293
# step 7700: train loss 0.6277, val loss 0.6275
# step 7800: train loss 0.6258, val loss 0.6256
# step 7900: train loss 0.6240, val loss 0.6239
# step 8000: train loss 0.6225, val loss 0.6224
# step 8100: train loss 0.6205, val loss 0.6212
# step 8200: train loss 0.6190, val loss 0.6192
# step 8300: train loss 0.6173, val loss 0.6175
# step 8400: train loss 0.6166, val loss 0.6172
# step 8500: train loss 0.6147, val loss 0.6149
# step 8600: train loss 0.6149, val loss 0.6144
# step 8700: train loss 0.6134, val loss 0.6131
# step 8800: train loss 0.6117, val loss 0.6120
# step 8900: train loss 0.6111, val loss 0.6116
# step 9000: train loss 0.6106, val loss 0.6102
# step 9100: train loss 0.6098, val loss 0.6093
# step 9200: train loss 0.6089, val loss 0.6093
# step 9300: train loss 0.6081, val loss 0.6082
# step 9400: train loss 0.6073, val loss 0.6075
# step 9500: train loss 0.6063, val loss 0.6071
# step 9600: train loss 0.6058, val loss 0.6063
# step 9700: train loss 0.6052, val loss 0.6055
# step 9800: train loss 0.6044, val loss 0.6050
# step 9900: train loss 0.6038, val loss 0.6040
# step 10000: train loss 0.6030, val loss 0.6036
# step 10100: train loss 0.6035, val loss 0.6033
# step 10200: train loss 0.6033, val loss 0.6026
# step 10300: train loss 0.6023, val loss 0.6024
# step 10400: train loss 0.6021, val loss 0.6011
# step 10500: train loss 0.6018, val loss 0.6022
# step 10600: train loss 0.6011, val loss 0.6012
# step 10700: train loss 0.6011, val loss 0.6009
# step 10800: train loss 0.5995, val loss 0.6005
# step 10900: train loss 0.5997, val loss 0.5998
# step 11000: train loss 0.5994, val loss 0.6001
# step 11100: train loss 0.5992, val loss 0.5993
# step 11200: train loss 0.5992, val loss 0.5992
# step 11300: train loss 0.5982, val loss 0.5985
# step 11400: train loss 0.5981, val loss 0.5987
# step 11500: train loss 0.5989, val loss 0.5988
# step 11600: train loss 0.5978, val loss 0.5981
# step 11700: train loss 0.5974, val loss 0.5979
# step 11800: train loss 0.5973, val loss 0.5975
# step 11900: train loss 0.5971, val loss 0.5978
# step 12000: train loss 0.5971, val loss 0.5968
# step 12100: train loss 0.5963, val loss 0.5971
# step 12200: train loss 0.5964, val loss 0.5968
# step 12300: train loss 0.5962, val loss 0.5966
# step 12400: train loss 0.5953, val loss 0.5963
# step 12500: train loss 0.5963, val loss 0.5964
# step 12600: train loss 0.5957, val loss 0.5958
# step 12700: train loss 0.5961, val loss 0.5956
# step 12800: train loss 0.5952, val loss 0.5961
# step 12900: train loss 0.5955, val loss 0.5963
# step 13000: train loss 0.5957, val loss 0.5952
# step 13100: train loss 0.5954, val loss 0.5954
# step 13200: train loss 0.5949, val loss 0.5951
# step 13300: train loss 0.5954, val loss 0.5950
# step 13400: train loss 0.5945, val loss 0.5947
# step 13500: train loss 0.5946, val loss 0.5957
# step 13600: train loss 0.5946, val loss 0.5952
# step 13700: train loss 0.5950, val loss 0.5952
# step 13800: train loss 0.5946, val loss 0.5953
# step 13900: train loss 0.5942, val loss 0.5950
# step 14000: train loss 0.5945, val loss 0.5951
# step 14100: train loss 0.5944, val loss 0.5953
# step 14200: train loss 0.5943, val loss 0.5945
# step 14300: train loss 0.5940, val loss 0.5940
# step 14400: train loss 0.5944, val loss 0.5953
# step 14500: train loss 0.5950, val loss 0.5948
# step 14600: train loss 0.5947, val loss 0.5955
# step 14700: train loss 0.5947, val loss 0.5945
# step 14800: train loss 0.5944, val loss 0.5946
# step 14900: train loss 0.5948, val loss 0.5947
# step 14999: train loss 0.5946, val loss 0.5943
# Training model order=6 number=2
# 0.232322 M parameters
# Transition Matrix:
#  tensor([[0.1677, 0.8323],
#         [0.5771, 0.4229],
#         [0.1601, 0.8399],
#         [0.8597, 0.1403],
#         [0.5011, 0.4989],
#         [0.5162, 0.4838],
#         [0.1637, 0.8363],
#         [0.6292, 0.3708],
#         [0.4565, 0.5435],
#         [0.5807, 0.4193],
#         [0.5012, 0.4988],
#         [0.4869, 0.5131],
#         [0.4117, 0.5883],
#         [0.2423, 0.7577],
#         [0.5527, 0.4473],
#         [0.4735, 0.5265],
#         [0.1261, 0.8739],
#         [0.8507, 0.1493],
#         [0.1875, 0.8125],
#         [0.2221, 0.7779],
#         [0.4161, 0.5839],
#         [0.7042, 0.2958],
#         [0.3552, 0.6448],
#         [0.4557, 0.5443],
#         [0.4423, 0.5577],
#         [0.4419, 0.5581],
#         [0.4464, 0.5536],
#         [0.8747, 0.1253],
#         [0.6348, 0.3652],
#         [0.5208, 0.4792],
#         [0.4755, 0.5245],
#         [0.7740, 0.2260],
#         [0.8558, 0.1442],
#         [0.4568, 0.5432],
#         [0.7324, 0.2676],
#         [0.5672, 0.4328],
#         [0.8168, 0.1832],
#         [0.5896, 0.4104],
#         [0.1509, 0.8491],
#         [0.6059, 0.3941],
#         [0.3605, 0.6395],
#         [0.6232, 0.3768],
#         [0.5784, 0.4216],
#         [0.6360, 0.3640],
#         [0.6997, 0.3003],
#         [0.0992, 0.9008],
#         [0.3956, 0.6044],
#         [0.4418, 0.5582],
#         [0.3566, 0.6434],
#         [0.6924, 0.3076],
#         [0.5538, 0.4462],
#         [0.8257, 0.1743],
#         [0.2623, 0.7377],
#         [0.4884, 0.5116],
#         [0.6290, 0.3710],
#         [0.3065, 0.6935],
#         [0.5789, 0.4211],
#         [0.9040, 0.0960],
#         [0.3285, 0.6715],
#         [0.2704, 0.7296],
#         [0.4616, 0.5384],
#         [0.4262, 0.5738],
#         [0.6489, 0.3511],
#         [0.2861, 0.7139]])
# step 0: train loss 0.7595, val loss 0.7589
# step 100: train loss 0.6901, val loss 0.6901
# step 200: train loss 0.6902, val loss 0.6901
# step 300: train loss 0.6899, val loss 0.6900
# step 400: train loss 0.6897, val loss 0.6897
# step 500: train loss 0.6899, val loss 0.6897
# step 600: train loss 0.6901, val loss 0.6898
# step 700: train loss 0.6897, val loss 0.6896
# step 800: train loss 0.6895, val loss 0.6895
# step 900: train loss 0.6898, val loss 0.6896
# step 1000: train loss 0.6896, val loss 0.6894
# step 1100: train loss 0.6893, val loss 0.6892
# step 1200: train loss 0.6886, val loss 0.6886
# step 1300: train loss 0.6883, val loss 0.6882
# step 1400: train loss 0.6877, val loss 0.6877
# step 1500: train loss 0.6871, val loss 0.6872
# step 1600: train loss 0.6861, val loss 0.6860
# step 1700: train loss 0.6854, val loss 0.6852
# step 1800: train loss 0.6842, val loss 0.6843
# step 1900: train loss 0.6829, val loss 0.6831
# step 2000: train loss 0.6817, val loss 0.6817
# step 2100: train loss 0.6804, val loss 0.6804
# step 2200: train loss 0.6791, val loss 0.6787
# step 2300: train loss 0.6772, val loss 0.6770
# step 2400: train loss 0.6756, val loss 0.6752
# step 2500: train loss 0.6742, val loss 0.6739
# step 2600: train loss 0.6731, val loss 0.6732
# step 2700: train loss 0.6717, val loss 0.6710
# step 2800: train loss 0.6694, val loss 0.6692
# step 2900: train loss 0.6685, val loss 0.6679
# step 3000: train loss 0.6666, val loss 0.6667
# step 3100: train loss 0.6658, val loss 0.6656
# step 3200: train loss 0.6652, val loss 0.6652
# step 3300: train loss 0.6640, val loss 0.6636
# step 3400: train loss 0.6638, val loss 0.6632
# step 3500: train loss 0.6625, val loss 0.6624
# step 3600: train loss 0.6623, val loss 0.6616
# step 3700: train loss 0.6616, val loss 0.6610
# step 3800: train loss 0.6608, val loss 0.6606
# step 3900: train loss 0.6602, val loss 0.6606
# step 4000: train loss 0.6595, val loss 0.6589
# step 4100: train loss 0.6587, val loss 0.6580
# step 4200: train loss 0.6580, val loss 0.6578
# step 4300: train loss 0.6576, val loss 0.6569
# step 4400: train loss 0.6568, val loss 0.6562
# step 4500: train loss 0.6564, val loss 0.6557
# step 4600: train loss 0.6553, val loss 0.6553
# step 4700: train loss 0.6543, val loss 0.6543
# step 4800: train loss 0.6540, val loss 0.6534
# step 4900: train loss 0.6529, val loss 0.6525
# step 5000: train loss 0.6503, val loss 0.6499
# step 5100: train loss 0.6487, val loss 0.6487
# step 5200: train loss 0.6473, val loss 0.6467
# step 5300: train loss 0.6455, val loss 0.6444
# step 5400: train loss 0.6435, val loss 0.6436
# step 5500: train loss 0.6412, val loss 0.6412
# step 5600: train loss 0.6398, val loss 0.6392
# step 5700: train loss 0.6386, val loss 0.6381
# step 5800: train loss 0.6365, val loss 0.6365
# step 5900: train loss 0.6345, val loss 0.6346
# step 6000: train loss 0.6332, val loss 0.6330
# step 6100: train loss 0.6326, val loss 0.6319
# step 6200: train loss 0.6310, val loss 0.6303
# step 6300: train loss 0.6294, val loss 0.6288
# step 6400: train loss 0.6276, val loss 0.6270
# step 6500: train loss 0.6262, val loss 0.6260
# step 6600: train loss 0.6245, val loss 0.6238
# step 6700: train loss 0.6222, val loss 0.6215
# step 6800: train loss 0.6212, val loss 0.6211
# step 6900: train loss 0.6194, val loss 0.6187
# step 7000: train loss 0.6187, val loss 0.6180
# step 7100: train loss 0.6173, val loss 0.6172
# step 7200: train loss 0.6168, val loss 0.6165
# step 7300: train loss 0.6149, val loss 0.6148
# step 7400: train loss 0.6138, val loss 0.6136
# step 7500: train loss 0.6140, val loss 0.6131
# step 7600: train loss 0.6122, val loss 0.6127
# step 7700: train loss 0.6117, val loss 0.6113
# step 7800: train loss 0.6109, val loss 0.6104
# step 7900: train loss 0.6100, val loss 0.6102
# step 8000: train loss 0.6098, val loss 0.6089
# step 8100: train loss 0.6091, val loss 0.6089
# step 8200: train loss 0.6081, val loss 0.6085
# step 8300: train loss 0.6085, val loss 0.6081
# step 8400: train loss 0.6075, val loss 0.6072
# step 8500: train loss 0.6078, val loss 0.6067
# step 8600: train loss 0.6075, val loss 0.6065
# step 8700: train loss 0.6068, val loss 0.6061
# step 8800: train loss 0.6066, val loss 0.6061
# step 8900: train loss 0.6069, val loss 0.6061
# step 9000: train loss 0.6062, val loss 0.6057
# step 9100: train loss 0.6057, val loss 0.6053
# step 9200: train loss 0.6056, val loss 0.6054
# step 9300: train loss 0.6054, val loss 0.6051
# step 9400: train loss 0.6056, val loss 0.6053
# step 9500: train loss 0.6053, val loss 0.6047
# step 9600: train loss 0.6052, val loss 0.6046
# step 9700: train loss 0.6053, val loss 0.6046
# step 9800: train loss 0.6050, val loss 0.6041
# step 9900: train loss 0.6041, val loss 0.6037
# step 10000: train loss 0.6045, val loss 0.6039
# step 10100: train loss 0.6042, val loss 0.6038
# step 10200: train loss 0.6045, val loss 0.6039
# step 10300: train loss 0.6046, val loss 0.6030
# step 10400: train loss 0.6029, val loss 0.6033
# step 10500: train loss 0.6041, val loss 0.6040
# step 10600: train loss 0.6037, val loss 0.6032
# step 10700: train loss 0.6032, val loss 0.6030
# step 10800: train loss 0.6035, val loss 0.6031
# step 10900: train loss 0.6035, val loss 0.6031
# step 11000: train loss 0.6040, val loss 0.6033
# step 11100: train loss 0.6036, val loss 0.6023
# step 11200: train loss 0.6032, val loss 0.6023
# step 11300: train loss 0.6034, val loss 0.6025
# step 11400: train loss 0.6032, val loss 0.6030
# step 11500: train loss 0.6032, val loss 0.6024
# step 11600: train loss 0.6033, val loss 0.6025
# step 11700: train loss 0.6032, val loss 0.6027
# step 11800: train loss 0.6034, val loss 0.6026
# step 11900: train loss 0.6024, val loss 0.6018
# step 12000: train loss 0.6027, val loss 0.6023
# step 12100: train loss 0.6031, val loss 0.6024
# step 12200: train loss 0.6034, val loss 0.6021
# step 12300: train loss 0.6027, val loss 0.6022
# step 12400: train loss 0.6023, val loss 0.6024
# step 12500: train loss 0.6026, val loss 0.6016
# step 12600: train loss 0.6023, val loss 0.6022
# step 12700: train loss 0.6026, val loss 0.6018
# step 12800: train loss 0.6021, val loss 0.6023
# step 12900: train loss 0.6022, val loss 0.6020
# step 13000: train loss 0.6028, val loss 0.6025
# step 13100: train loss 0.6019, val loss 0.6015
# step 13200: train loss 0.6030, val loss 0.6013
# step 13300: train loss 0.6026, val loss 0.6019
# step 13400: train loss 0.6022, val loss 0.6014
# step 13500: train loss 0.6019, val loss 0.6019
# step 13600: train loss 0.6021, val loss 0.6017
# step 13700: train loss 0.6027, val loss 0.6013
# step 13800: train loss 0.6018, val loss 0.6019
# step 13900: train loss 0.6017, val loss 0.6021
# step 14000: train loss 0.6022, val loss 0.6019
# step 14100: train loss 0.6022, val loss 0.6021
# step 14200: train loss 0.6023, val loss 0.6013
# step 14300: train loss 0.6021, val loss 0.6013
# step 14400: train loss 0.6026, val loss 0.6014
# step 14500: train loss 0.6020, val loss 0.6015
# step 14600: train loss 0.6017, val loss 0.6017
# step 14700: train loss 0.6022, val loss 0.6014
# step 14800: train loss 0.6023, val loss 0.6016
# step 14900: train loss 0.6024, val loss 0.6017
# step 14999: train loss 0.6017, val loss 0.6008
# Training model order=6 number=3
# 0.232322 M parameters
# Transition Matrix:
#  tensor([[0.6925, 0.3075],
#         [0.3609, 0.6391],
#         [0.0483, 0.9517],
#         [0.0569, 0.9431],
#         [0.7023, 0.2977],
#         [0.8544, 0.1456],
#         [0.1478, 0.8522],
#         [0.5703, 0.4297],
#         [0.4025, 0.5975],
#         [0.7184, 0.2816],
#         [0.5964, 0.4036],
#         [0.2232, 0.7768],
#         [0.2664, 0.7336],
#         [0.3751, 0.6249],
#         [0.2793, 0.7207],
#         [0.3327, 0.6673],
#         [0.4862, 0.5138],
#         [0.4401, 0.5599],
#         [0.9969, 0.0031],
#         [0.1770, 0.8230],
#         [0.6723, 0.3277],
#         [0.3074, 0.6926],
#         [0.6440, 0.3560],
#         [0.7685, 0.2315],
#         [0.4783, 0.5217],
#         [0.6366, 0.3634],
#         [0.2088, 0.7912],
#         [0.2176, 0.7824],
#         [0.8131, 0.1869],
#         [0.7335, 0.2665],
#         [0.4316, 0.5684],
#         [0.8440, 0.1560],
#         [0.5963, 0.4037],
#         [0.8846, 0.1154],
#         [0.5707, 0.4293],
#         [0.5431, 0.4569],
#         [0.3551, 0.6449],
#         [0.5572, 0.4428],
#         [0.5313, 0.4687],
#         [0.4276, 0.5724],
#         [0.4780, 0.5220],
#         [0.3596, 0.6404],
#         [0.9647, 0.0353],
#         [0.8525, 0.1475],
#         [0.1694, 0.8306],
#         [0.4589, 0.5411],
#         [0.6617, 0.3383],
#         [0.4173, 0.5827],
#         [0.5307, 0.4693],
#         [0.9114, 0.0886],
#         [0.4744, 0.5256],
#         [0.7236, 0.2764],
#         [0.2280, 0.7720],
#         [0.5137, 0.4863],
#         [0.0069, 0.9931],
#         [0.1131, 0.8869],
#         [0.3537, 0.6463],
#         [0.4494, 0.5506],
#         [0.6876, 0.3124],
#         [0.2223, 0.7777],
#         [0.8391, 0.1609],
#         [0.9848, 0.0152],
#         [0.5579, 0.4421],
#         [0.3013, 0.6987]])
# step 0: train loss 0.7441, val loss 0.7441
# step 100: train loss 0.6915, val loss 0.6915
# step 200: train loss 0.6916, val loss 0.6915
# step 300: train loss 0.6912, val loss 0.6912
# step 400: train loss 0.6913, val loss 0.6913
# step 500: train loss 0.6912, val loss 0.6912
# step 600: train loss 0.6912, val loss 0.6912
# step 700: train loss 0.6914, val loss 0.6915
# step 800: train loss 0.6914, val loss 0.6915
# step 900: train loss 0.6912, val loss 0.6912
# step 1000: train loss 0.6911, val loss 0.6913
# step 1100: train loss 0.6913, val loss 0.6913
# step 1200: train loss 0.6914, val loss 0.6914
# step 1300: train loss 0.6911, val loss 0.6911
# step 1400: train loss 0.6911, val loss 0.6910
# step 1500: train loss 0.6909, val loss 0.6910
# step 1600: train loss 0.6910, val loss 0.6910
# step 1700: train loss 0.6911, val loss 0.6911
# step 1800: train loss 0.6908, val loss 0.6908
# step 1900: train loss 0.6907, val loss 0.6909
# step 2000: train loss 0.6909, val loss 0.6909
# step 2100: train loss 0.6907, val loss 0.6906
# step 2200: train loss 0.6906, val loss 0.6907
# step 2300: train loss 0.6905, val loss 0.6907
# step 2400: train loss 0.6905, val loss 0.6905
# step 2500: train loss 0.6905, val loss 0.6905
# step 2600: train loss 0.6903, val loss 0.6904
# step 2700: train loss 0.6905, val loss 0.6905
# step 2800: train loss 0.6901, val loss 0.6903
# step 2900: train loss 0.6901, val loss 0.6900
# step 3000: train loss 0.6901, val loss 0.6901
# step 3100: train loss 0.6898, val loss 0.6897
# step 3200: train loss 0.6898, val loss 0.6898
# step 3300: train loss 0.6897, val loss 0.6898
# step 3400: train loss 0.6896, val loss 0.6895
# step 3500: train loss 0.6893, val loss 0.6893
# step 3600: train loss 0.6892, val loss 0.6891
# step 3700: train loss 0.6889, val loss 0.6889
# step 3800: train loss 0.6890, val loss 0.6890
# step 3900: train loss 0.6887, val loss 0.6888
# step 4000: train loss 0.6886, val loss 0.6886
# step 4100: train loss 0.6883, val loss 0.6881
# step 4200: train loss 0.6882, val loss 0.6882
# step 4300: train loss 0.6880, val loss 0.6881
# step 4400: train loss 0.6879, val loss 0.6876
# step 4500: train loss 0.6875, val loss 0.6876
# step 4600: train loss 0.6873, val loss 0.6875
# step 4700: train loss 0.6871, val loss 0.6872
# step 4800: train loss 0.6864, val loss 0.6865
# step 4900: train loss 0.6861, val loss 0.6862
# step 5000: train loss 0.6861, val loss 0.6862
# step 5100: train loss 0.6858, val loss 0.6858
# step 5200: train loss 0.6854, val loss 0.6854
# step 5300: train loss 0.6851, val loss 0.6852
# step 5400: train loss 0.6846, val loss 0.6848
# step 5500: train loss 0.6845, val loss 0.6846
# step 5600: train loss 0.6841, val loss 0.6842
# step 5700: train loss 0.6838, val loss 0.6838
# step 5800: train loss 0.6838, val loss 0.6838
# step 5900: train loss 0.6830, val loss 0.6834
# step 6000: train loss 0.6833, val loss 0.6834
# step 6100: train loss 0.6830, val loss 0.6831
# step 6200: train loss 0.6829, val loss 0.6828
# step 6300: train loss 0.6826, val loss 0.6827
# step 6400: train loss 0.6825, val loss 0.6823
# step 6500: train loss 0.6823, val loss 0.6825
# step 6600: train loss 0.6824, val loss 0.6823
# step 6700: train loss 0.6819, val loss 0.6822
# step 6800: train loss 0.6817, val loss 0.6820
# step 6900: train loss 0.6814, val loss 0.6816
# step 7000: train loss 0.6813, val loss 0.6815
# step 7100: train loss 0.6810, val loss 0.6810
# step 7200: train loss 0.6808, val loss 0.6809
# step 7300: train loss 0.6809, val loss 0.6809
# step 7400: train loss 0.6806, val loss 0.6804
# step 7500: train loss 0.6803, val loss 0.6803
# step 7600: train loss 0.6801, val loss 0.6804
# step 7700: train loss 0.6797, val loss 0.6799
# step 7800: train loss 0.6796, val loss 0.6798
# step 7900: train loss 0.6794, val loss 0.6795
# step 8000: train loss 0.6791, val loss 0.6791
# step 8100: train loss 0.6789, val loss 0.6790
# step 8200: train loss 0.6788, val loss 0.6788
# step 8300: train loss 0.6785, val loss 0.6787
# step 8400: train loss 0.6787, val loss 0.6788
# step 8500: train loss 0.6782, val loss 0.6782
# step 8600: train loss 0.6781, val loss 0.6781
# step 8700: train loss 0.6781, val loss 0.6783
# step 8800: train loss 0.6779, val loss 0.6781
# step 8900: train loss 0.6778, val loss 0.6779
# step 9000: train loss 0.6778, val loss 0.6777
# step 9100: train loss 0.6772, val loss 0.6774
# step 9200: train loss 0.6773, val loss 0.6774
# step 9300: train loss 0.6769, val loss 0.6774
# step 9400: train loss 0.6769, val loss 0.6770
# step 9500: train loss 0.6766, val loss 0.6770
# step 9600: train loss 0.6764, val loss 0.6766
# step 9700: train loss 0.6766, val loss 0.6766
# step 9800: train loss 0.6764, val loss 0.6763
# step 9900: train loss 0.6759, val loss 0.6761
# step 10000: train loss 0.6759, val loss 0.6761
# step 10100: train loss 0.6756, val loss 0.6758
# step 10200: train loss 0.6754, val loss 0.6756
# step 10300: train loss 0.6752, val loss 0.6754
# step 10400: train loss 0.6751, val loss 0.6753
# step 10500: train loss 0.6751, val loss 0.6755
# step 10600: train loss 0.6747, val loss 0.6750
# step 10700: train loss 0.6748, val loss 0.6748
# step 10800: train loss 0.6747, val loss 0.6748
# step 10900: train loss 0.6746, val loss 0.6746
# step 11000: train loss 0.6744, val loss 0.6743
# step 11100: train loss 0.6741, val loss 0.6741
# step 11200: train loss 0.6741, val loss 0.6742
# step 11300: train loss 0.6742, val loss 0.6738
# step 11400: train loss 0.6742, val loss 0.6740
# step 11500: train loss 0.6736, val loss 0.6739
# step 11600: train loss 0.6737, val loss 0.6736
# step 11700: train loss 0.6737, val loss 0.6740
# step 11800: train loss 0.6733, val loss 0.6737
# step 11900: train loss 0.6733, val loss 0.6734
# step 12000: train loss 0.6734, val loss 0.6735
# step 12100: train loss 0.6732, val loss 0.6732
# step 12200: train loss 0.6732, val loss 0.6734
# step 12300: train loss 0.6729, val loss 0.6733
# step 12400: train loss 0.6728, val loss 0.6732
# step 12500: train loss 0.6731, val loss 0.6731
# step 12600: train loss 0.6729, val loss 0.6731
# step 12700: train loss 0.6731, val loss 0.6729
# step 12800: train loss 0.6728, val loss 0.6728
# step 12900: train loss 0.6727, val loss 0.6730
# step 13000: train loss 0.6728, val loss 0.6727
# step 13100: train loss 0.6726, val loss 0.6727
# step 13200: train loss 0.6727, val loss 0.6728
# step 13300: train loss 0.6727, val loss 0.6729
# step 13400: train loss 0.6725, val loss 0.6727
# step 13500: train loss 0.6724, val loss 0.6726
# step 13600: train loss 0.6723, val loss 0.6726
# step 13700: train loss 0.6724, val loss 0.6727
# step 13800: train loss 0.6723, val loss 0.6726
# step 13900: train loss 0.6722, val loss 0.6723
# step 14000: train loss 0.6721, val loss 0.6724
# step 14100: train loss 0.6724, val loss 0.6726
# step 14200: train loss 0.6725, val loss 0.6725
# step 14300: train loss 0.6725, val loss 0.6726
# step 14400: train loss 0.6722, val loss 0.6724
# step 14500: train loss 0.6722, val loss 0.6724
# step 14600: train loss 0.6724, val loss 0.6725
# step 14700: train loss 0.6722, val loss 0.6725
# step 14800: train loss 0.6723, val loss 0.6720
# step 14900: train loss 0.6723, val loss 0.6725
# step 14999: train loss 0.6723, val loss 0.6723
# Training model order=6 number=4
# 0.232322 M parameters
# Transition Matrix:
#  tensor([[0.2374, 0.7626],
#         [0.9074, 0.0926],
#         [0.4818, 0.5182],
#         [0.4910, 0.5090],
#         [0.3471, 0.6529],
#         [0.8350, 0.1650],
#         [0.4715, 0.5285],
#         [0.4915, 0.5085],
#         [0.2908, 0.7092],
#         [0.6628, 0.3372],
#         [0.1447, 0.8553],
#         [0.6645, 0.3355],
#         [0.6034, 0.3966],
#         [0.2835, 0.7165],
#         [0.5585, 0.4415],
#         [0.3495, 0.6505],
#         [0.1923, 0.8077],
#         [0.4595, 0.5405],
#         [0.6296, 0.3704],
#         [0.3177, 0.6823],
#         [0.6260, 0.3740],
#         [0.4126, 0.5874],
#         [0.2541, 0.7459],
#         [0.4643, 0.5357],
#         [0.9082, 0.0918],
#         [0.4816, 0.5184],
#         [0.2397, 0.7603],
#         [0.6482, 0.3518],
#         [0.4540, 0.5460],
#         [0.1075, 0.8925],
#         [0.3771, 0.6229],
#         [0.4168, 0.5832],
#         [0.6051, 0.3949],
#         [0.7996, 0.2004],
#         [0.2215, 0.7785],
#         [0.4542, 0.5458],
#         [0.5794, 0.4206],
#         [0.4339, 0.5661],
#         [0.9699, 0.0301],
#         [0.6375, 0.3625],
#         [0.2663, 0.7337],
#         [0.8734, 0.1266],
#         [0.8404, 0.1596],
#         [0.2738, 0.7262],
#         [0.6987, 0.3013],
#         [0.7797, 0.2203],
#         [0.4481, 0.5519],
#         [0.7661, 0.2339],
#         [0.1124, 0.8876],
#         [0.5902, 0.4098],
#         [0.7460, 0.2540],
#         [0.3341, 0.6659],
#         [0.3560, 0.6440],
#         [0.3471, 0.6529],
#         [0.8431, 0.1569],
#         [0.0482, 0.9518],
#         [0.5043, 0.4957],
#         [0.4112, 0.5888],
#         [0.4857, 0.5143],
#         [0.7057, 0.2943],
#         [0.5873, 0.4127],
#         [0.7230, 0.2770],
#         [0.9168, 0.0832],
#         [0.7183, 0.2817]])
# step 0: train loss 0.7568, val loss 0.7570
# step 100: train loss 0.6915, val loss 0.6915
# step 200: train loss 0.6914, val loss 0.6913
# step 300: train loss 0.6916, val loss 0.6915
# step 400: train loss 0.6915, val loss 0.6914
# step 500: train loss 0.6917, val loss 0.6915
# step 600: train loss 0.6911, val loss 0.6910
# step 700: train loss 0.6909, val loss 0.6909
# step 800: train loss 0.6905, val loss 0.6906
# step 900: train loss 0.6907, val loss 0.6908
# step 1000: train loss 0.6897, val loss 0.6897
# step 1100: train loss 0.6894, val loss 0.6892
# step 1200: train loss 0.6877, val loss 0.6876
# step 1300: train loss 0.6864, val loss 0.6863
# step 1400: train loss 0.6833, val loss 0.6832
# step 1500: train loss 0.6810, val loss 0.6809
# step 1600: train loss 0.6793, val loss 0.6792
# step 1700: train loss 0.6778, val loss 0.6775
# step 1800: train loss 0.6775, val loss 0.6775
# step 1900: train loss 0.6756, val loss 0.6757
# step 2000: train loss 0.6746, val loss 0.6741
# step 2100: train loss 0.6711, val loss 0.6710
# step 2200: train loss 0.6704, val loss 0.6703
# step 2300: train loss 0.6673, val loss 0.6668
# step 2400: train loss 0.6665, val loss 0.6662
# step 2500: train loss 0.6649, val loss 0.6646
# step 2600: train loss 0.6613, val loss 0.6611
# step 2700: train loss 0.6646, val loss 0.6642
# step 2800: train loss 0.6627, val loss 0.6624
# step 2900: train loss 0.6578, val loss 0.6570
# step 3000: train loss 0.6583, val loss 0.6583
# step 3100: train loss 0.6558, val loss 0.6554
# step 3200: train loss 0.6573, val loss 0.6565
# step 3300: train loss 0.6527, val loss 0.6526
# step 3400: train loss 0.6507, val loss 0.6504
# step 3500: train loss 0.6498, val loss 0.6494
# step 3600: train loss 0.6514, val loss 0.6509
# step 3700: train loss 0.6446, val loss 0.6440
# step 3800: train loss 0.6487, val loss 0.6487
# step 3900: train loss 0.6401, val loss 0.6399
# step 4000: train loss 0.6458, val loss 0.6461
# step 4100: train loss 0.6398, val loss 0.6390
# step 4200: train loss 0.6369, val loss 0.6369
# step 4300: train loss 0.6364, val loss 0.6362
# step 4400: train loss 0.6365, val loss 0.6365
# step 4500: train loss 0.6330, val loss 0.6330
# step 4600: train loss 0.6337, val loss 0.6337
# step 4700: train loss 0.6345, val loss 0.6347
# step 4800: train loss 0.6271, val loss 0.6270
# step 4900: train loss 0.6267, val loss 0.6270
# step 5000: train loss 0.6241, val loss 0.6239
# step 5100: train loss 0.6211, val loss 0.6215
# step 5200: train loss 0.6252, val loss 0.6256
# step 5300: train loss 0.6197, val loss 0.6196
# step 5400: train loss 0.6175, val loss 0.6176
# step 5500: train loss 0.6182, val loss 0.6182
# step 5600: train loss 0.6204, val loss 0.6209
# step 5700: train loss 0.6141, val loss 0.6137
# step 5800: train loss 0.6144, val loss 0.6146
# step 5900: train loss 0.6171, val loss 0.6173
# step 6000: train loss 0.6135, val loss 0.6136
# step 6100: train loss 0.6100, val loss 0.6097
# step 6200: train loss 0.6135, val loss 0.6131
# step 6300: train loss 0.6095, val loss 0.6095
# step 6400: train loss 0.6129, val loss 0.6123
# step 6500: train loss 0.6082, val loss 0.6086
# step 6600: train loss 0.6092, val loss 0.6093
# step 6700: train loss 0.6076, val loss 0.6085
# step 6800: train loss 0.6089, val loss 0.6090
# step 6900: train loss 0.6064, val loss 0.6055
# step 7000: train loss 0.6057, val loss 0.6053
# step 7100: train loss 0.6070, val loss 0.6070
# step 7200: train loss 0.6040, val loss 0.6045
# step 7300: train loss 0.6034, val loss 0.6031
# step 7400: train loss 0.6029, val loss 0.6028
# step 7500: train loss 0.6039, val loss 0.6042
# step 7600: train loss 0.6030, val loss 0.6036
# step 7700: train loss 0.6019, val loss 0.6018
# step 7800: train loss 0.6009, val loss 0.6017
# step 7900: train loss 0.6020, val loss 0.6019
# step 8000: train loss 0.6036, val loss 0.6021
# step 8100: train loss 0.6028, val loss 0.6034
# step 8200: train loss 0.6031, val loss 0.6026
# step 8300: train loss 0.5997, val loss 0.5991
# step 8400: train loss 0.5999, val loss 0.5999
# step 8500: train loss 0.6009, val loss 0.6007
# step 8600: train loss 0.5997, val loss 0.5996
# step 8700: train loss 0.5983, val loss 0.5989
# step 8800: train loss 0.5989, val loss 0.5991
# step 8900: train loss 0.5975, val loss 0.5982
# step 9000: train loss 0.5988, val loss 0.5983
# step 9100: train loss 0.5972, val loss 0.5974
# step 9200: train loss 0.5972, val loss 0.5974
# step 9300: train loss 0.5971, val loss 0.5969
# step 9400: train loss 0.5959, val loss 0.5965
# step 9500: train loss 0.5954, val loss 0.5960
# step 9600: train loss 0.5956, val loss 0.5965
# step 9700: train loss 0.5957, val loss 0.5963
# step 9800: train loss 0.5955, val loss 0.5954
# step 9900: train loss 0.5949, val loss 0.5959
# step 10000: train loss 0.5941, val loss 0.5947
# step 10100: train loss 0.5986, val loss 0.5991
# step 10200: train loss 0.5950, val loss 0.5953
# step 10300: train loss 0.5943, val loss 0.5953
# step 10400: train loss 0.5960, val loss 0.5962
# step 10500: train loss 0.5947, val loss 0.5950
# step 10600: train loss 0.5931, val loss 0.5936
# step 10700: train loss 0.5931, val loss 0.5927
# step 10800: train loss 0.5928, val loss 0.5933
# step 10900: train loss 0.5932, val loss 0.5931
# step 11000: train loss 0.5926, val loss 0.5927
# step 11100: train loss 0.5927, val loss 0.5926
# step 11200: train loss 0.5931, val loss 0.5928
# step 11300: train loss 0.5937, val loss 0.5934
# step 11400: train loss 0.5920, val loss 0.5920
# step 11500: train loss 0.5923, val loss 0.5927
# step 11600: train loss 0.5914, val loss 0.5920
# step 11700: train loss 0.5915, val loss 0.5916
# step 11800: train loss 0.5920, val loss 0.5922
# step 11900: train loss 0.5918, val loss 0.5917
# step 12000: train loss 0.5914, val loss 0.5914
# step 12100: train loss 0.5915, val loss 0.5919
# step 12200: train loss 0.5917, val loss 0.5915
# step 12300: train loss 0.5912, val loss 0.5923
# step 12400: train loss 0.5902, val loss 0.5910
# step 12500: train loss 0.5915, val loss 0.5915
# step 12600: train loss 0.5911, val loss 0.5914
# step 12700: train loss 0.5904, val loss 0.5911
# step 12800: train loss 0.5903, val loss 0.5907
# step 12900: train loss 0.5901, val loss 0.5910
# step 13000: train loss 0.5903, val loss 0.5899
# step 13100: train loss 0.5900, val loss 0.5904
# step 13200: train loss 0.5906, val loss 0.5907
# step 13300: train loss 0.5898, val loss 0.5911
# step 13400: train loss 0.5905, val loss 0.5905
# step 13500: train loss 0.5897, val loss 0.5901
# step 13600: train loss 0.5900, val loss 0.5900
# step 13700: train loss 0.5896, val loss 0.5901
# step 13800: train loss 0.5896, val loss 0.5899
# step 13900: train loss 0.5897, val loss 0.5898
# step 14000: train loss 0.5898, val loss 0.5899
# step 14100: train loss 0.5894, val loss 0.5898
# step 14200: train loss 0.5899, val loss 0.5900
# step 14300: train loss 0.5901, val loss 0.5900
# step 14400: train loss 0.5901, val loss 0.5904
# step 14500: train loss 0.5896, val loss 0.5899
# step 14600: train loss 0.5894, val loss 0.5903
# step 14700: train loss 0.5890, val loss 0.5899
# step 14800: train loss 0.5904, val loss 0.5894
# step 14900: train loss 0.5893, val loss 0.5895
# step 14999: train loss 0.5894, val loss 0.5894
# Training model order=6 number=5
# 0.232322 M parameters
# Transition Matrix:
#  tensor([[0.0595, 0.9405],
#         [0.2774, 0.7226],
#         [0.4825, 0.5175],
#         [0.7877, 0.2123],
#         [0.4464, 0.5536],
#         [0.4649, 0.5351],
#         [0.4711, 0.5289],
#         [0.6607, 0.3393],
#         [0.5154, 0.4846],
#         [0.5640, 0.4360],
#         [0.3512, 0.6488],
#         [0.5079, 0.4921],
#         [0.0021, 0.9979],
#         [0.4616, 0.5384],
#         [0.4520, 0.5480],
#         [0.1358, 0.8642],
#         [0.8296, 0.1704],
#         [0.2138, 0.7862],
#         [0.7946, 0.2054],
#         [0.2598, 0.7402],
#         [0.8633, 0.1367],
#         [0.6114, 0.3886],
#         [0.6210, 0.3790],
#         [0.2542, 0.7458],
#         [0.5260, 0.4740],
#         [0.5506, 0.4494],
#         [0.2120, 0.7880],
#         [0.0245, 0.9755],
#         [0.3129, 0.6871],
#         [0.6650, 0.3350],
#         [0.1400, 0.8600],
#         [0.6125, 0.3875],
#         [0.7192, 0.2808],
#         [0.1221, 0.8779],
#         [0.0713, 0.9287],
#         [0.3024, 0.6976],
#         [0.2991, 0.7009],
#         [0.3573, 0.6427],
#         [0.4452, 0.5548],
#         [0.0861, 0.9139],
#         [0.6841, 0.3159],
#         [0.6330, 0.3670],
#         [0.5926, 0.4074],
#         [0.5030, 0.4970],
#         [0.5315, 0.4685],
#         [0.6619, 0.3381],
#         [0.3337, 0.6663],
#         [0.0527, 0.9473],
#         [0.6276, 0.3724],
#         [0.2789, 0.7211],
#         [0.6275, 0.3725],
#         [0.8370, 0.1630],
#         [0.7758, 0.2242],
#         [0.5102, 0.4898],
#         [0.4579, 0.5421],
#         [0.5071, 0.4929],
#         [0.3011, 0.6989],
#         [0.4143, 0.5857],
#         [0.6936, 0.3064],
#         [0.4995, 0.5005],
#         [0.1971, 0.8029],
#         [0.5313, 0.4687],
#         [0.7623, 0.2377],
#         [0.3392, 0.6608]])
# step 0: train loss 0.7801, val loss 0.7802
# step 100: train loss 0.6901, val loss 0.6901
# step 200: train loss 0.6901, val loss 0.6903
# step 300: train loss 0.6898, val loss 0.6901
# step 400: train loss 0.6901, val loss 0.6903
# step 500: train loss 0.6900, val loss 0.6901
# step 600: train loss 0.6898, val loss 0.6901
# step 700: train loss 0.6898, val loss 0.6901
# step 800: train loss 0.6899, val loss 0.6900
# step 900: train loss 0.6899, val loss 0.6902
# step 1000: train loss 0.6901, val loss 0.6902
# step 1100: train loss 0.6900, val loss 0.6901
# step 1200: train loss 0.6900, val loss 0.6902
# step 1300: train loss 0.6898, val loss 0.6899
# step 1400: train loss 0.6901, val loss 0.6902
# step 1500: train loss 0.6899, val loss 0.6900
# step 1600: train loss 0.6899, val loss 0.6901
# step 1700: train loss 0.6896, val loss 0.6899
# step 1800: train loss 0.6898, val loss 0.6900
# step 1900: train loss 0.6900, val loss 0.6900
# step 2000: train loss 0.6896, val loss 0.6899
# step 2100: train loss 0.6897, val loss 0.6900
# step 2200: train loss 0.6897, val loss 0.6897
# step 2300: train loss 0.6897, val loss 0.6899
# step 2400: train loss 0.6897, val loss 0.6898
# step 2500: train loss 0.6896, val loss 0.6899
# step 2600: train loss 0.6897, val loss 0.6898
# step 2700: train loss 0.6895, val loss 0.6900
# step 2800: train loss 0.6896, val loss 0.6898
# step 2900: train loss 0.6895, val loss 0.6897
# step 3000: train loss 0.6897, val loss 0.6898
# step 3100: train loss 0.6897, val loss 0.6898
# step 3200: train loss 0.6895, val loss 0.6898
# step 3300: train loss 0.6895, val loss 0.6896
# step 3400: train loss 0.6895, val loss 0.6896
# step 3500: train loss 0.6895, val loss 0.6897
# step 3600: train loss 0.6894, val loss 0.6898
# step 3700: train loss 0.6894, val loss 0.6897
# step 3800: train loss 0.6897, val loss 0.6898
# step 3900: train loss 0.6894, val loss 0.6896
# step 4000: train loss 0.6893, val loss 0.6895
# step 4100: train loss 0.6895, val loss 0.6898
# step 4200: train loss 0.6894, val loss 0.6895
# step 4300: train loss 0.6895, val loss 0.6895
# step 4400: train loss 0.6892, val loss 0.6896
# step 4500: train loss 0.6892, val loss 0.6894
# step 4600: train loss 0.6890, val loss 0.6893
# step 4700: train loss 0.6890, val loss 0.6893
# step 4800: train loss 0.6891, val loss 0.6892
# step 4900: train loss 0.6892, val loss 0.6895
# step 5000: train loss 0.6892, val loss 0.6893
# step 5100: train loss 0.6892, val loss 0.6893
# step 5200: train loss 0.6889, val loss 0.6892
# step 5300: train loss 0.6889, val loss 0.6892
# step 5400: train loss 0.6891, val loss 0.6892
# step 5500: train loss 0.6891, val loss 0.6891
# step 5600: train loss 0.6889, val loss 0.6890
# step 5700: train loss 0.6888, val loss 0.6891
# step 5800: train loss 0.6888, val loss 0.6890
# step 5900: train loss 0.6891, val loss 0.6891
# step 6000: train loss 0.6889, val loss 0.6891
# step 6100: train loss 0.6889, val loss 0.6891
# step 6200: train loss 0.6887, val loss 0.6889
# step 6300: train loss 0.6886, val loss 0.6889
# step 6400: train loss 0.6890, val loss 0.6892
# step 6500: train loss 0.6888, val loss 0.6889
# step 6600: train loss 0.6885, val loss 0.6887
# step 6700: train loss 0.6886, val loss 0.6888
# step 6800: train loss 0.6887, val loss 0.6889
# step 6900: train loss 0.6885, val loss 0.6888
# step 7000: train loss 0.6884, val loss 0.6886
# step 7100: train loss 0.6884, val loss 0.6887
# step 7200: train loss 0.6884, val loss 0.6886
# step 7300: train loss 0.6883, val loss 0.6883
# step 7400: train loss 0.6882, val loss 0.6886
# step 7500: train loss 0.6883, val loss 0.6885
# step 7600: train loss 0.6884, val loss 0.6884
# step 7700: train loss 0.6883, val loss 0.6883
# step 7800: train loss 0.6883, val loss 0.6883
# step 7900: train loss 0.6882, val loss 0.6884
# step 8000: train loss 0.6880, val loss 0.6883
# step 8100: train loss 0.6881, val loss 0.6884
# step 8200: train loss 0.6881, val loss 0.6881
# step 8300: train loss 0.6881, val loss 0.6881
# step 8400: train loss 0.6881, val loss 0.6883
# step 8500: train loss 0.6880, val loss 0.6880
# step 8600: train loss 0.6879, val loss 0.6881
# step 8700: train loss 0.6879, val loss 0.6881
# step 8800: train loss 0.6877, val loss 0.6880
# step 8900: train loss 0.6878, val loss 0.6881
# step 9000: train loss 0.6878, val loss 0.6879
# step 9100: train loss 0.6878, val loss 0.6881
# step 9200: train loss 0.6877, val loss 0.6879
# step 9300: train loss 0.6876, val loss 0.6877
# step 9400: train loss 0.6877, val loss 0.6876
# step 9500: train loss 0.6876, val loss 0.6877
# step 9600: train loss 0.6876, val loss 0.6878
# step 9700: train loss 0.6875, val loss 0.6878
# step 9800: train loss 0.6873, val loss 0.6876
# step 9900: train loss 0.6873, val loss 0.6875
# step 10000: train loss 0.6873, val loss 0.6875
# step 10100: train loss 0.6873, val loss 0.6872
# step 10200: train loss 0.6871, val loss 0.6873
# step 10300: train loss 0.6874, val loss 0.6872
# step 10400: train loss 0.6871, val loss 0.6872
# step 10500: train loss 0.6869, val loss 0.6872
# step 10600: train loss 0.6868, val loss 0.6870
# step 10700: train loss 0.6869, val loss 0.6873
# step 10800: train loss 0.6869, val loss 0.6869
# step 10900: train loss 0.6868, val loss 0.6870
# step 11000: train loss 0.6868, val loss 0.6869
# step 11100: train loss 0.6867, val loss 0.6869
# step 11200: train loss 0.6866, val loss 0.6868
# step 11300: train loss 0.6867, val loss 0.6869
# step 11400: train loss 0.6866, val loss 0.6867
# step 11500: train loss 0.6864, val loss 0.6866
# step 11600: train loss 0.6865, val loss 0.6868
# step 11700: train loss 0.6865, val loss 0.6868
# step 11800: train loss 0.6865, val loss 0.6867
# step 11900: train loss 0.6865, val loss 0.6867
# step 12000: train loss 0.6864, val loss 0.6866
# step 12100: train loss 0.6866, val loss 0.6866
# step 12200: train loss 0.6863, val loss 0.6864
# step 12300: train loss 0.6864, val loss 0.6864
# step 12400: train loss 0.6861, val loss 0.6865
# step 12500: train loss 0.6862, val loss 0.6864
# step 12600: train loss 0.6863, val loss 0.6865
# step 12700: train loss 0.6863, val loss 0.6865
# step 12800: train loss 0.6862, val loss 0.6865
# step 12900: train loss 0.6862, val loss 0.6863
# step 13000: train loss 0.6862, val loss 0.6864
# step 13100: train loss 0.6862, val loss 0.6864
# step 13200: train loss 0.6861, val loss 0.6864
# step 13300: train loss 0.6864, val loss 0.6862
# step 13400: train loss 0.6862, val loss 0.6862
# step 13500: train loss 0.6862, val loss 0.6861
# step 13600: train loss 0.6862, val loss 0.6862
# step 13700: train loss 0.6860, val loss 0.6862
# step 13800: train loss 0.6861, val loss 0.6861
# step 13900: train loss 0.6862, val loss 0.6863
# step 14000: train loss 0.6862, val loss 0.6863
# step 14100: train loss 0.6862, val loss 0.6861
# step 14200: train loss 0.6859, val loss 0.6863
# step 14300: train loss 0.6860, val loss 0.6861
# step 14400: train loss 0.6860, val loss 0.6862
# step 14500: train loss 0.6860, val loss 0.6861
# step 14600: train loss 0.6862, val loss 0.6862
# step 14700: train loss 0.6861, val loss 0.6862
# step 14800: train loss 0.6861, val loss 0.6862
# step 14900: train loss 0.6860, val loss 0.6863
# step 14999: train loss 0.6861, val loss 0.6862

# %%
base_path = Path("models")
base_path.mkdir(exist_ok=True)
# convert and save
serializable_models = tensor_to_serializable(my_models)
filename = f"my_models_saved.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(serializable_models, f, indent=2)

print(f"Saved models to {filepath}")
# Out:
# Saved models to models2/my_models_saved2.json

# %% [markdown]
# ## Loss curves
# We can plot the loss curves of the training process to get insights into:
# 1. If and when the curves converge.
# 2. Wether the models achieve a loss close to the optimal loss value.
# 3. How the chain's order and the complexity affect the loss.

# %%
def calculate_optimal_loss(transition_matrix, order):
    """
    Calculate the optimal (theoretical minimum) cross-entropy loss for a Markov chain of order k.
    """
    # Convert to numpy array if not already
    P_next = np.array(transition_matrix)
    n_states = 2**order
    
    # Create the state transition matrix
    P = np.zeros((n_states, n_states))
    
    # Fill the state transition matrix
    for state in range(n_states):
        for next_bit in [0, 1]:
            # Calculate next state by shifting left and adding new bit
            next_state = (state << 1) & (n_states - 1) | next_bit
            # Add transition probability
            P[state, next_state] = P_next[state, next_bit]
    
    # Find stationary distribution using power iteration
    pi = np.ones(n_states) / n_states  # Start with uniform distribution
    
    # Power iteration
    for _ in range(100):  # Usually converges much faster
        pi_next = pi @ P
        if np.allclose(pi, pi_next, rtol=1e-8):
            break
        pi = pi_next
    
    # Calculate entropy rate
    entropy_rate = 0.0
    eps = 1e-10  # Small constant to avoid log(0)
    
    for state in range(n_states):
        for next_bit in [0, 1]:
            p = P_next[state, next_bit]
            if p > eps:
                entropy_rate -= pi[state] * p * np.log(p)
    
    return float(entropy_rate)

# %%
def plot_loss_curves():
    """
    Plots the training history for every model relative to optimal loss
    """
    with open('models/my_models_saved.json', 'r') as f:
        models = json.load(f)
    
    fig, axes = plt.subplots(2, 3, figsize=(20, 12))
    axes = axes.flatten()
    
    for order in range(1, 7):
        order_models = [m for m in models if m['order'] == order]
        ax = axes[order-1]
        
        for model in order_models:
            # Convert transition matrix from list to numpy array
            transition_matrix = np.array(model['transition_matrix'])
            optimal_loss = calculate_optimal_loss(transition_matrix, model['order'])
            
            train_losses = np.array(model['training_history']['train_losses'])
            val_losses = np.array(model['training_history']['val_losses'])
            iterations = model['training_history']['iterations']
            
            # Plot absolute difference from optimal
            train_diff = train_losses - optimal_loss
            val_diff = val_losses - optimal_loss
            
            ax.plot(iterations, train_diff, 
                   label=f'Train (Chain={model["order"]}.{model["number"]})')
            ax.plot(iterations, val_diff, 
                   linestyle='--', label=f'Val (Chain={model["order"]}.{model["number"]})')
            
        ax.set_title(f'Order {order}')
        ax.set_xlabel('Iterations')
        ax.set_ylabel('Loss Difference from Optimal')
        ax.grid(True, alpha=0.3)
        ax.legend()
    
    plt.tight_layout()
    plt.savefig('plots/loss_curves.png', dpi=300, bbox_inches='tight')
    plt.close()

plot_loss_curves()

# %%
def plot_combined_loss_curves():
    """
    Plots the combined training history for every model relative to optimal loss,
    including variance as shaded regions.
    """
    with open('models/my_models_saved.json', 'r') as f:
        models = json.load(f)
    
    plt.figure(figsize=(10, 6))
    
    for order in range(1, 7):
        order_models = [m for m in models if m['order'] == order]
        
        # Initialize lists to store loss differences
        all_train_diff = []
        all_val_diff = []
        iterations = None
        
        for model in order_models:
            # Convert transition matrix from list to numpy array
            transition_matrix = np.array(model['transition_matrix'])
            optimal_loss = calculate_optimal_loss(transition_matrix, model['order'])
            
            train_losses = np.array(model['training_history']['train_losses'])
            val_losses = np.array(model['training_history']['val_losses'])
            iterations = model['training_history']['iterations']
            
            # Calculate absolute difference from optimal
            train_diff = train_losses - optimal_loss
            val_diff = val_losses - optimal_loss
            
            all_train_diff.append(train_diff)
            all_val_diff.append(val_diff)
        
        # Convert to numpy arrays for easier computation
        all_train_diff = np.array(all_train_diff)
        all_val_diff = np.array(all_val_diff)
        
        # Calculate mean and standard deviation
        mean_train_diff = np.mean(all_train_diff, axis=0)
        std_train_diff = np.std(all_train_diff, axis=0)
        
        mean_val_diff = np.mean(all_val_diff, axis=0)
        std_val_diff = np.std(all_val_diff, axis=0)
        
        # Plot mean with shaded variance
        plt.plot(iterations, mean_train_diff, label=f'order = {order}')
        plt.fill_between(iterations, 
                         mean_train_diff - std_train_diff, 
                         mean_train_diff + std_train_diff, 
                         alpha=0.2)
    
    plt.title('Test Loss Gap from the Optimal')
    plt.xlabel('Iteration')
    plt.ylabel('Test Loss Gap from the Optimal')
    plt.grid(True, alpha=0.3)
    plt.legend()
    
    plt.savefig('plots/combined_loss_curves', dpi=300, bbox_inches='tight')
    plt.close()

plot_combined_loss_curves()

# %% [markdown]
# ## Convergence
# We can identify the average points of training convergence for each order:

# %%
def calculate_convergence_point(loss_history, threshold=0.01, window_size=10):
    """
    Calculate the point of convergence for a loss curve
    """
    final_loss = np.mean(loss_history[-window_size:])  # Average of last window
    
    for i in range(len(loss_history) - window_size):
        window_mean = np.mean(loss_history[i:i+window_size])
        relative_change = abs(window_mean - final_loss) / final_loss
        
        if relative_change < threshold:
            return i * 100  # multiply by 100 since eval_iter is 100
    
    return len(loss_history) * 100

def analyze_order_convergence(all_loss_histories):
    """
    Analyze convergence for all chains of a specific order
    """
    convergence_points = []
    final_losses = []
    
    for chain_losses in all_loss_histories:
        conv_point = calculate_convergence_point(chain_losses)
        final_loss = np.mean(chain_losses[-10:])  # Average of last 10 points
        
        convergence_points.append(conv_point)
        final_losses.append(final_loss)
    
    results = {
        'convergence_mean': np.mean(convergence_points),
        'convergence_std': np.std(convergence_points),
        'final_loss_mean': np.mean(final_losses),
        'final_loss_std': np.std(final_losses)
    }
    
    return results

with open('models/my_models_saved.json', 'r') as m:
    models = json.load(m)

for order in range(1, 7): 
    histories = []  
    for model in models:
        if model['order'] == order:
            histories.append(model['training_history']['train_losses'])
    print(analyze_order_convergence(histories))
# Out:
# {'convergence_mean': 80.0, 'convergence_std': 40.0, 'final_loss_mean': 0.6032889360189437, 'final_loss_std': 0.06878144836785413}
# {'convergence_mean': 1320.0, 'convergence_std': 1066.5833300778706, 'final_loss_mean': 0.4284674080833793, 'final_loss_std': 0.21281476684534775}
# {'convergence_mean': 2760.0, 'convergence_std': 826.0750571225353, 'final_loss_mean': 0.5204345923662186, 'final_loss_std': 0.09792156646814257}
# {'convergence_mean': 3320.0, 'convergence_std': 832.8265125462806, 'final_loss_mean': 0.5500198811292648, 'final_loss_std': 0.0726387712344261}
# {'convergence_mean': 7320.0, 'convergence_std': 1815.9295140505867, 'final_loss_mean': 0.5719257605075837, 'final_loss_std': 0.04497018930392192}
# {'convergence_mean': 7120.0, 'convergence_std': 3642.7462167985295, 'final_loss_mean': 0.628945450782776, 'final_loss_std': 0.041451449633561385}

# %% [markdown]
# ## Testing
# After the models are trained and stored the testing can begin. It has been observed that the context has only an insignificant importance here since the models are trained on sequences of the same Markov chain. The context will have the length 50 for every experiment.

# %%
device ="cpu"

# %%
def model_output(model_info, max_new_tokens, seed):
    """
    Takes a model and generates output based on a context
    """
    order = model_info['order']
    number = model_info['number']
    
    transition_matrix = torch.tensor(model_info['transition_matrix'])
    
    # Initialize model with same parameters as training
    model = BinaryTransformer().to(device)
    model.eval()
    
    # Load checkpoint
    checkpoint = torch.load(f'models/model{order}_{number}.pt')
    model.load_state_dict(checkpoint['model_state_dict'])

    # Generate context
    context = torch.tensor(generate_sequence(transition_matrix, order, 50, seed))
    context = context.unsqueeze(0).to(device)  # Add batch dimension
    
    # Generate prediction
    with torch.no_grad():
        output = model.generate(context, max_new_tokens)
        
    return output.tolist()[0][50:]

# %% [markdown]
# ## Metrics
# The chosen metrics for this approach are the Kullback-Leibler Divergence (kld) and the Mean Absolute Error (mae).

# %%
def kl_divergence(chain1, chain2, epsilon=1e-10):
    """
    Calculate the KL-Divergence from two markov chains, ignoring undefined states in chain2
    """
    # identify defined states in chain2 (sum of probabilities > 0)
    defined_states = torch.sum(chain2, dim=1) > 0
    
    # extract only the defined states and their corresponding states in chain1
    p = chain1[defined_states]
    q = chain2[defined_states]
    
    # Add epsilon to p and q to avoid log(0)
    p = p + epsilon
    q = q + epsilon
    
    # normalize both distributions
    p = p / p.sum(dim=1, keepdim=True)
    q = q / q.sum(dim=1, keepdim=True)
    
    # calculate the KL-Divergence only for defined states
    kl_div = torch.sum(p * torch.log(p / q))
    
    return kl_div.item()


def mean_error(chain1, chain2):
    """
    Calculate the mean absolute error of two Markov chains, ignoring undefined states in chain2
    """
    # identify defined states in chain2 (sum of probabilities > 0)
    defined_states = torch.sum(chain2, dim=1) > 0
    
    # extract only the defined states and their corresponding states in chain1
    p = chain1[defined_states]
    q = chain2[defined_states]
    
    # Calculate the absolute differences for defined states
    abs_diff = torch.abs(p - q)
        
    # Calculate the mean error across all defined states
    mean_error = torch.mean(abs_diff).item()
    
    return mean_error

# %%
with open('models/my_models_saved.json', 'r') as m:
        models = json.load(m)

# let's test the model outputs one these lengths
output_lengths = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 3000, 4000, 5000]
seeds = [111,112,113,114,115,116,117,118,119,120] # every model output_length is tested 100 times on different contexts
results = []
n_head = 1
n_layer = 2
n_embd = 16
for model in models:
        order = model['order']
        number = model['number']
        if order == 2:
               n_embd = 64
        if order == 3:
               n_layer = 3
        if order == 6:
               n_layer = 4
        print(f"Testing model{order}_{number}")
        transition_matrix = torch.tensor(model['transition_matrix'])
        for output_length in output_lengths:
                print(f"Testing output length {output_length}")
                for seed in seeds:
                        output = model_output(model, output_length, seed) # generate output_length new tokens
                        estimated_matrix = estimate_matrix(output, order) # estimate a Markov chain for the output
                        kld = kl_divergence(transition_matrix, estimated_matrix)
                        mae = mean_error(transition_matrix, estimated_matrix)
                        results.append({'order': order, 'number': number, 'output_length': output_length, 'seed':seed, 'kld': kld, 'mae': mae})

base_path = Path("results")
base_path.mkdir(exist_ok=True)

filename = f"model_results.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(results, f, indent=2)
print(f"Saved results to {filepath}")
# Out:
# Testing model1_1
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model1_2
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model1_3
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model1_4
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model1_5
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model2_1
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model2_2
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model2_3
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model2_4
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model2_5
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model3_1
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model3_2
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model3_3
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model3_4
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model3_5
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model4_1
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model4_2
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model4_3
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model4_4
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model4_5
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model5_1
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model5_2
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model5_3
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model5_4
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model5_5
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model6_1
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model6_2
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model6_3
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model6_4
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Testing model6_5
# Testing output length 100
# Testing output length 200
# Testing output length 300
# Testing output length 400
# Testing output length 500
# Testing output length 600
# Testing output length 700
# Testing output length 800
# Testing output length 900
# Testing output length 1000
# Testing output length 2000
# Testing output length 3000
# Testing output length 4000
# Testing output length 5000
# Saved results to results/model_results.json

# %% [markdown]
# ## Random Process
# To evaluate how precise the Transformer model is in predicting next tokens in a Markov sequence we can compare it to a random process.

# %%
with open('models/my_models_saved.json', 'r') as m:
        models = json.load(m)

# let's look what the scores for a completely random process (balanced chain) look like
results = []
output_lengths = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 3000, 4000, 5000]
seeds = [111, 112, 113, 114, 115, 116, 117, 118, 119, 120] # the sequences are generated across 10 seeds
for model in models:
        order = model['order']
        number = model['number']
        transition_matrix = torch.tensor(model['transition_matrix'])
        print(f"Testing chain{order}_{number}")
        for output_length in output_lengths:
               for seed in seeds:
                np.random.seed(seed)
                rand_sequence = np.random.randint(0, 2, output_length) # generates a random array of 0s and 1s with length output_length
                estimated_matrix = estimate_matrix(rand_sequence, order)
                kld = kl_divergence(transition_matrix, estimated_matrix)
                mae = mean_error(transition_matrix, estimated_matrix)
                results.append({'order': order, 'number': number, 'output_length': output_length, 'seed': seed, 'kld': kld, 'mae': mae})

base_path = Path("results")
base_path.mkdir(exist_ok=True)

filename = f"random_results.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(results, f, indent=2)

print(f"Saved models to {filepath}")
# Out:
# Testing chain1_1
# Testing chain1_2
# Testing chain1_3
# Testing chain1_4
# Testing chain1_5
# Testing chain2_1
# Testing chain2_2
# Testing chain2_3
# Testing chain2_4
# Testing chain2_5
# Testing chain3_1
# Testing chain3_2
# Testing chain3_3
# Testing chain3_4
# Testing chain3_5
# Testing chain4_1
# Testing chain4_2
# Testing chain4_3
# Testing chain4_4
# Testing chain4_5
# Testing chain5_1
# Testing chain5_2
# Testing chain5_3
# Testing chain5_4
# Testing chain5_5
# Testing chain6_1
# Testing chain6_2
# Testing chain6_3
# Testing chain6_4
# Testing chain6_5
# Saved models to results/random_results.json

# %% [markdown]
# ## Lower Bound Score
# As a second comparison, we can generate a sequence for every output_length that minimizes the KL-Divergence. The sequence is chosen as one of 100 sequences (each generated with the transition probabilities of the underlying Markov chain). It serves as an orientation to evaluate the model's precision.

# %%
def search_sequence(transition_matrix, k, m, num_candidates=500):
    """
    Generate a near-optimal sequence of length m for a kth-order Markov chain. Sampled from num_candidates sequences.
    """

    min_kl_div = float('inf')
    best_sequence = None

    for i in range(num_candidates):
        sequence = generate_sequence(transition_matrix, k, m, i)
        seq_matrix = estimate_matrix(sequence, k)
        kl_div = kl_divergence(transition_matrix, seq_matrix)
        if kl_div < min_kl_div:
            min_kl_div = kl_div
            best_sequence = sequence
            
    return best_sequence

# %%
with open('models/my_models_saved.json', 'r') as m:
        models = json.load(m)
        
output_lengths = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 3000, 4000, 5000]
results = []

for model in models:
    order = model['order']
    number = model['number']
    print(f"Sampling for chain{order}_{number}")
    transition_matrix = torch.tensor(model['transition_matrix'])
    for output_length in output_lengths:
        best = search_sequence(transition_matrix, order, output_length)
        estimated_matrix = estimate_matrix(best, order) # estimate a Markov chain for the best sequence
        kld = kl_divergence(transition_matrix, estimated_matrix)
        mae = mean_error(transition_matrix, estimated_matrix)
        results.append({'order': order, 'number': number, 'output_length': output_length, 'kld': kld, 'mae': mae})

base_path = Path("results")
base_path.mkdir(exist_ok=True)

filename = f"lower_bound.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(results, f, indent=2)
print(f"Saved results to {filepath}")

# %% [markdown]
# ## Evaluate Results
# The results are now evaluated and tested on significance by the use of confidence intervals.

# %%
from scipy import stats

def analyze_test_results(results_path):
    with open(results_path, 'r') as f:
        results = json.load(f)
    
    analysis_results = []
    for order in range(1, 7):
        order_results = [r for r in results if r['order'] == order]
        
        # get unique seeds
        seeds = list(set(r['seed'] for r in order_results))
        
        # calculate statistics across seeds
        kld_values = [r['kld'] for r in order_results]
        mae_values = [r['mae'] for r in order_results]
        
        # calculate mean, std, and confidence intervals
        kld_mean = np.mean(kld_values)
        kld_std = np.std(kld_values)
        mae_mean = np.mean(mae_values)
        mae_std = np.std(mae_values)
        
        # 95% confidence intervals
        kld_ci = tuple(round(x, 3) for x in stats.t.interval(0.95, len(kld_values)-1, 
                                                    loc=kld_mean, 
                                                    scale=stats.sem(kld_values)))
        mae_ci = tuple(round(x, 3) for x in stats.t.interval(0.95, len(mae_values)-1, 
                                                    loc=mae_mean, 
                                                    scale=stats.sem(mae_values)))
        
        analysis_results.append({'order': order, 'kld_mean': kld_mean, 'kld_std': kld_std, 'kld_ci':kld_ci, 'mae_mean': mae_mean, 'mae_std': mae_std,
                                  'mae_ci':mae_ci, 'n_samples': len(kld_values)})
        
        print()
        print(order)
        print(f"kld_mean': {round(kld_mean, 3)}")
        print(f"kld_std': {round(kld_std, 3)}")
        print(f"kld_ci': {kld_ci}")
        print(f"mae_mean': {round(mae_mean, 3)}")
        print(f"mae_std': {round(mae_std, 3)}")
        print(f"mae_ci': {mae_ci}")
        print(f"n_samples': {len(kld_values)}")
    
    return analysis_results

analysis = analyze_test_results('results/model_results.json')

base_path = Path("results")
base_path.mkdir(exist_ok=True)

filename = f"results_analysis.json"
filepath = base_path / filename
with open(filepath, 'w') as f:
    json.dump(analysis, f, indent=2)
print(f"Saved results to {filepath}")
# Out:
# 1
# kld_mean': 0.01
# kld_std': 0.021
# kld_ci': (0.009, 0.012)
# mae_mean': 0.019
# mae_std': 0.018
# mae_ci': (0.018, 0.021)
# n_samples': 700
#
# 2
# kld_mean': 1.322
# kld_std': 3.582
# kld_ci': (1.056, 1.588)
# mae_mean': 0.09
# mae_std': 0.056
# mae_ci': (0.086, 0.094)
# n_samples': 700
#
# 3
# kld_mean': 0.612
# kld_std': 2.249
# kld_ci': (0.445, 0.779)
# mae_mean': 0.064
# mae_std': 0.043
# mae_ci': (0.061, 0.068)
# n_samples': 700
#
# 4
# kld_mean': 3.494
# kld_std': 8.25
# kld_ci': (2.882, 4.107)
# mae_mean': 0.077
# mae_std': 0.045
# mae_ci': (0.074, 0.08)
# n_samples': 700
#
# 5
# kld_mean': 19.213
# kld_std': 26.727
# kld_ci': (17.228, 21.198)
# mae_mean': 0.143
# mae_std': 0.046
# mae_ci': (0.139, 0.146)
# n_samples': 700
#
# 6
# kld_mean': 65.063
# kld_std': 89.822
# kld_ci': (58.392, 71.733)
# mae_mean': 0.188
# mae_std': 0.077
# mae_ci': (0.182, 0.194)
# n_samples': 700
# Saved results to results/results_analysis.json

# %% [markdown]
# ## Plot Results
# Now that all results are calculated and stored, these results can be plotted. We can plot a heatmap and a line chart to visualize the output length vs. the metric accuracy for the model outputs and the lower bound sequences. Furthermore, a comparison of the two - including the random process as orientation - visualizes how good the Transformer models work as compressors.
# First, let's plot the model results:

# %%
def plot_model_results(results_file):
    
    with open(results_file, 'r') as f:
        results = json.load(f)
    
    plt.style.use('classic')
    sns.set_palette("husl")
    
    # Create figure with two subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # Extract unique values
    orders = sorted(list(set(r['order'] for r in results)))
    lengths = sorted(list(set(r['output_length'] for r in results)))
    numbers = sorted(list(set(r['number'] for r in results)))
    
    # Prepare data structures for plotting
    metrics = {
        'kld': {'name': 'KL Divergence', 'data': {}},
        'mae': {'name': 'Mean Absolute Error', 'data': {}}
    }
    
    for order in orders:
        metrics['kld']['data'][order] = {'means': [], 'stds': []}
        metrics['mae']['data'][order] = {'means': [], 'stds': []}
        
        for length in lengths:
            kld_averages = []
            mae_averages = []
            
            # First average across seeds for each number
            for number in numbers:
                # Get results for this order, length, and number (across all seeds)
                values = [r for r in results if r['order'] == order and 
                         r['output_length'] == length and 
                         r['number'] == number]
                
                # Calculate average across seeds for this combination
                if values:
                    kld_averages.append(np.mean([v['kld'] for v in values]))
                    mae_averages.append(np.mean([v['mae'] for v in values]))
            
            # Calculate final statistics across numbers (after seed averaging)
            metrics['kld']['data'][order]['means'].append(np.mean(kld_averages))
            metrics['kld']['data'][order]['stds'].append(np.std(kld_averages))
            metrics['mae']['data'][order]['means'].append(np.mean(mae_averages))
            metrics['mae']['data'][order]['stds'].append(np.std(mae_averages))
    
    # KL-Divergence
    for order in orders:
        ax1.errorbar(lengths, 
                    metrics['kld']['data'][order]['means'],
                    yerr=metrics['kld']['data'][order]['stds'],
                    label=f'Order {order}',
                    marker='o',
                    capsize=3,
                    markersize=4)
    
    ax1.set_xlabel('Output Length')
    ax1.set_ylabel('KL Divergence')
    ax1.set_title('KL Divergence vs Output Length\n(Averaged over seeds)')
    ax1.set_xscale('log')
    #ax1.set_yscale('log')
    ax1.grid(True, which="both", ls="-", alpha=0.2)
    ax1.legend()
    
    # MAE
    for order in orders:
        ax2.errorbar(lengths,
                    metrics['mae']['data'][order]['means'],
                    yerr=metrics['mae']['data'][order]['stds'],
                    label=f'Order {order}',
                    marker='o',
                    capsize=3,
                    markersize=4)
    
    ax2.set_xlabel('Output Length')
    ax2.set_ylabel('Mean Absolute Error')
    ax2.set_title('MAE vs Output Length\n(Averaged over seeds)')
    ax2.set_xscale('log')
    ax2.grid(True, which="both", ls="-", alpha=0.2)
    ax2.legend()
        
    plt.tight_layout()
    plt.savefig('plots/model_line_chart.png', dpi=300, bbox_inches='tight')
    plt.close()

    # Create heatmap visualization with seed-averaged data
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    heatmap_data = {
        'kld': np.zeros((len(orders), len(lengths))),
        'mae': np.zeros((len(orders), len(lengths)))
    }
    
    for i, order in enumerate(orders):
        for j, length in enumerate(lengths):
            kld_averages = []
            mae_averages = []
            
            for number in numbers:
                values = [r for r in results if r['order'] == order and 
                         r['output_length'] == length and 
                         r['number'] == number]
                if values:
                    kld_averages.append(np.mean([v['kld'] for v in values]))
                    mae_averages.append(np.mean([v['mae'] for v in values]))
            
            heatmap_data['kld'][i,j] = np.mean(kld_averages)
            heatmap_data['mae'][i,j] = np.mean(mae_averages)
    
    sns.heatmap(heatmap_data['kld'], ax=ax1,
                xticklabels=lengths,
                yticklabels=orders,
                cmap='viridis',
                norm='log')
    ax1.set_title('KL Divergence\n(Averaged over seeds)')
    ax1.set_xlabel('Output Length')
    ax1.set_ylabel('Markov Order')
    
    sns.heatmap(heatmap_data['mae'], ax=ax2,
                xticklabels=lengths,
                yticklabels=orders,
                cmap='viridis')
    ax2.set_title('Mean Absolute Error\n(Averaged over seeds)')
    ax2.set_xlabel('Output Length')
    ax2.set_ylabel('Markov Order')
    
    plt.tight_layout()
    plt.savefig('plots/model_heatmap.png', dpi=300, bbox_inches='tight')
    plt.close()

plot_model_results("results/model_results.json", )

# %% [markdown]
# The same is done for the lower bound results:

# %%
def plot_best_results(results_file):
    """
    Create plots showing how metrics vary with output length for different orders
    """
    with open(results_file, 'r') as f:
        results = json.load(f)
    
    plt.style.use('classic')
    sns.set_palette("husl")
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    orders = sorted(list(set(r['order'] for r in results)))
    lengths = sorted(list(set(r['output_length'] for r in results)))
    
    metrics = {
        'kld': {'name': 'KL Divergence', 'data': {}},
        'mae': {'name': 'Mean Absolute Error', 'data': {}}
    }
    
    # Process data for each order
    for order in orders:
        metrics['kld']['data'][order] = {'means': [], 'stds': []}
        metrics['mae']['data'][order] = {'means': [], 'stds': []}
        
        for length in lengths:
            # Get results for this order and length
            values = [r for r in results if r['order'] == order and r['output_length'] == length]
            
            # Calculate statistics
            for metric in ['kld', 'mae']:
                values_metric = [v[metric] for v in values]
                metrics[metric]['data'][order]['means'].append(np.mean(values_metric))
                metrics[metric]['data'][order]['stds'].append(np.std(values_metric))
    
    # KL-Divergence
    for order in orders:
        ax1.errorbar(lengths, 
                    metrics['kld']['data'][order]['means'],
                    yerr=metrics['kld']['data'][order]['stds'],
                    label=f'Order {order}',
                    marker='o',
                    capsize=3,
                    markersize=4)
    
    ax1.set_xlabel('Output Length')
    ax1.set_ylabel('KL Divergence')
    ax1.set_title('KL Divergence vs Output Length')
    ax1.set_xscale('log')
    #ax1.set_yscale('log')
    ax1.grid(True, which="both", ls="-", alpha=0.2)
    ax1.legend()

    
    # MAE
    for order in orders:
        ax2.errorbar(lengths,
                    metrics['mae']['data'][order]['means'],
                    yerr=metrics['mae']['data'][order]['stds'],
                    label=f'Order {order}',
                    marker='o',
                    capsize=3,
                    markersize=4)
    
    ax2.set_xlabel('Output Length')
    ax2.set_ylabel('Mean Absolute Error')
    ax2.set_title('MAE vs Output Length')
    ax2.set_xscale('log')
    ax2.grid(True, which="both", ls="-", alpha=0.2)
    ax2.legend()
        
    plt.tight_layout()
    plt.savefig('plots/lower_bound_line_chart.png', dpi=300, bbox_inches='tight')
    plt.close()

    # Create heatmap visualization
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    heatmap_data = {
        'kld': np.zeros((len(orders), len(lengths))),
        'mae': np.zeros((len(orders), len(lengths)))
    }
    
    for i, order in enumerate(orders):
        for j, length in enumerate(lengths):
            values = [r for r in results if r['order'] == order and r['output_length'] == length]
            heatmap_data['kld'][i,j] = np.mean([v['kld'] for v in values])
            heatmap_data['mae'][i,j] = np.mean([v['mae'] for v in values])
    
    # Plot heatmaps
    sns.heatmap(heatmap_data['kld'], ax=ax1,
                xticklabels=lengths,
                yticklabels=orders,
                cmap='viridis',
                norm='log')
    ax1.set_title('KL Divergence')
    ax1.set_xlabel('Output Length')
    ax1.set_ylabel('Markov Order')
    
    sns.heatmap(heatmap_data['mae'], ax=ax2,
                xticklabels=lengths,
                yticklabels=orders,
                cmap='viridis')
    ax2.set_title('Mean Absolute Error')
    ax2.set_xlabel('Output Length')
    ax2.set_ylabel('Markov Order')
    
    plt.tight_layout()
    plt.savefig('plots/lower_bound_heatmap.png', dpi=300, bbox_inches='tight')
    plt.close()

plot_best_results("results/lower_bound.json")

# %% [markdown]
# Now, we create a comparison plot on output length vs metric score for both metrics to compare how the models perform (across all orders) vs the ideal results. We include the random results as an orientation.

# %%
def create_comparison_plots(model_path, best_path, random_path):
    with open(model_path, 'r') as f:
        model_results = json.load(f)
    with open(best_path, 'r') as f:
        ideal_results = json.load(f)
    with open(random_path, 'r') as f:
        random_results = json.load(f)
    
    # Extract unique output lengths
    lengths = sorted(list(set(r['output_length'] for r in ideal_results)))
    
    ideal_metrics = {'kld': [], 'mae': []}
    model_metrics = {'kld': [], 'mae': []}
    random_metrics = {'kld': [], 'mae': []}
    
    for length in lengths:
        ideal_length = [r for r in ideal_results if r['output_length'] == length]
        model_length = [r for r in model_results if r['output_length'] == length]
        random_length = [r for r in random_results if r['output_length'] == length]
        
        ideal_metrics['kld'].append(np.mean([r['kld'] for r in ideal_length]))
        ideal_metrics['mae'].append(np.mean([r['mae'] for r in ideal_length]))
        model_metrics['kld'].append(np.mean([r['kld'] for r in model_length]))
        model_metrics['mae'].append(np.mean([r['mae'] for r in model_length]))
        random_metrics['kld'].append(np.mean([r['kld'] for r in random_length]))
        random_metrics['mae'].append(np.mean([r['mae'] for r in random_length]))
    
    # Create figure with two subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    width = 0.35
    x = np.arange(len(lengths))
    
    # KLD
    ax1.bar(x - width/2, ideal_metrics['kld'], width, label='Lower Bound', color='skyblue')
    ax1.bar(x + width/2, model_metrics['kld'], width, label='Transformer', color='lightcoral')
    ax1.plot(x, random_metrics['kld'], color='green', linestyle='--', label='Random')
    ax1.set_ylabel('KL Divergence')
    ax1.set_title('Average KL Divergence by Output Length')
    ax1.set_xticks(x)
    ax1.set_xticklabels(lengths, rotation=45)
    ax1.legend()
    ax1.grid(True, alpha=0.2)
    
    # MAE
    ax2.bar(x - width/2, ideal_metrics['mae'], width, label='Lower Bound', color='skyblue')
    ax2.bar(x + width/2, model_metrics['mae'], width, label='Transformer', color='lightcoral')
    ax2.plot(x, random_metrics['mae'], color='green', linestyle='--', label='Random')
    ax2.set_ylabel('Mean Absolute Error')
    ax2.set_title('Average MAE by Output Length')
    ax2.set_xticks(x)
    ax2.set_xticklabels(lengths, rotation=45)
    ax2.legend()
    ax2.grid(True, alpha=0.2)
    
    plt.tight_layout()
    plt.savefig('plots/comparison_total.png', dpi=300, bbox_inches='tight')
    plt.close()

create_comparison_plots('results/model_results.json', 'results/lower_bound.json', 'results/random_results.json')

# %% [markdown]
# Finally, we can compare how these results appear under the different Markov orders:

# %%
def create_comparison_by_order(model_path, ideal_path, random_path):
    with open(model_path, 'r') as f:
        model_results = json.load(f)
    with open(ideal_path, 'r') as f:
        ideal_results = json.load(f)
    with open(random_path, 'r') as f:
        random_results = json.load(f)
    
    for order in range(1, 7):
        # Create figure with two subplots
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
        
        # Filter results for this order
        order_ideal = [r for r in ideal_results if r['order'] == order]
        order_model = [r for r in model_results if r['order'] == order]
        order_random = [r for r in random_results if r['order'] == order]
        
        lengths = sorted(list(set(r['output_length'] for r in order_ideal)))
        
        ideal_metrics = {'kld': [], 'mae': []}
        model_metrics = {'kld': [], 'mae': []}
        random_metrics = {'kld': [], 'mae': []}
        
        for length in lengths:
            ideal_length = [r for r in order_ideal if r['output_length'] == length]
            model_length = [r for r in order_model if r['output_length'] == length]
            random_length = [r for r in order_random if r['output_length'] == length]
            
            ideal_metrics['kld'].append(np.mean([r['kld'] for r in ideal_length]))
            ideal_metrics['mae'].append(np.mean([r['mae'] for r in ideal_length]))
            model_metrics['kld'].append(np.mean([r['kld'] for r in model_length]))
            model_metrics['mae'].append(np.mean([r['mae'] for r in model_length]))
            random_metrics['kld'].append(np.mean([r['kld'] for r in random_length]))
            random_metrics['mae'].append(np.mean([r['mae'] for r in random_length]))
        
        width = 0.35
        x = np.arange(len(lengths))
        
        # Plot KLD (left plot)
        ax1.bar(x - width/2, ideal_metrics['kld'], width, label='Lower Bound', color='skyblue')
        ax1.bar(x + width/2, model_metrics['kld'], width, label='Transformer', color='lightcoral')
        ax1.plot(x, random_metrics['kld'], color='green', linestyle='--', label='Random')
        ax1.set_title(f'Order {order} - KL Divergence')
        ax1.set_xticks(x)
        ax1.set_xticklabels(lengths, rotation=45)
        ax1.set_xlabel('Output Length')
        ax1.set_ylabel('KL Divergence')
        ax1.legend()
        ax1.grid(True, alpha=0.2)
        
        # Plot MAE (right plot)
        ax2.bar(x - width/2, ideal_metrics['mae'], width, label='Lower Bound', color='skyblue')
        ax2.bar(x + width/2, model_metrics['mae'], width, label='Transformer', color='lightcoral')
        ax2.plot(x, random_metrics['mae'], color='green', linestyle='--', label='Random')
        ax2.set_title(f'Order {order} - Mean Absolute Error')
        ax2.set_xticks(x)
        ax2.set_xticklabels(lengths, rotation=45)
        ax2.set_xlabel('Output Length')
        ax2.set_ylabel('Mean Absolute Error')
        ax2.legend()
        ax2.grid(True, alpha=0.2)
        
        plt.tight_layout()
        plt.savefig(f'plots/order_{order}_comparison.png', dpi=300, bbox_inches='tight')
        plt.close()


create_comparison_by_order('results/model_results.json', 'results/lower_bound.json', 'results/random_results.json')

# %% [markdown]
# We can also plot the error distribution across Markov orders:

# %%
plt.style.use('classic')
sns.set_palette("husl")

orders = range(1, 7)
kld_means = [0.001, 0.894, 0.154, 0.203, 3.068, 5.158]
kld_stds = [0.001, 2.088, 0.286, 0.302, 2.655, 3.632]
mae_means = [0.006, 0.128, 0.056, 0.045, 0.132, 0.043]
mae_stds = [0.004, 0.055, 0.015, 0.039, 0.043, 0.071]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# KLD
ax1.errorbar(orders, kld_means, yerr=kld_stds, 
            fmt='o-', capsize=3, capthick=1, 
            color='skyblue', label='KLD',
            markersize=6, linewidth=1.5)
ax1.set_xlabel('Markov Order')
ax1.set_ylabel('KLD')
ax1.grid(True, linestyle='-', alpha=0.7)
ax1.set_title('Kullback-Leibler Divergence')

# MAE
ax2.errorbar(orders, mae_means, yerr=mae_stds, 
            fmt='s-', capsize=3, capthick=1,
            color='lightcoral', label='MAE',
            markersize=6, linewidth=1.5)
ax2.set_xlabel('Markov Order')
ax2.set_ylabel('MAE')
ax2.grid(True, linestyle='-', alpha=0.7)
ax2.set_title('Mean Absolute Error')

ax1.legend()
ax2.legend()

plt.tight_layout()

plt.savefig('plots/error_distribution.png', dpi=300, bbox_inches='tight')
plt.close()
